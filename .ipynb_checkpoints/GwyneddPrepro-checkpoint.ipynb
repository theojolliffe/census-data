# %%
import pandas as pd
import json
import networkx as nx
from networkx_query import search_nodes, search_edges
import numpy as np

# %%
options = pd.read_csv('./csv/lists/places_2020.csv')
areaType = pd.read_csv('/Users/theojolliffe/Documents/Census Data/censusAreaLookup.csv')
tfidf = pd.read_csv('/Users/theojolliffe/Documents/Wayback BBC/BBCRegionalTFIDF.csv')
typeLookup = {}
for i in areaType.index:
    typeLookup[areaType.iloc[i]['Name']]=areaType.iloc[i]['Group name']

# %%
areas = []
for i in options["code"]:
    try:
        areas.append(json.load(open(f'/Users/theojolliffe/Documents/Census Data/census-data-main/json/place/{i}.json', 'rb')))
    except FileNotFoundError:
        print(i)
        pass
    
for area in areas:
    area['data']['agemed']['value']['change']['all'] = area['data']['agemed']['value']['2011']['all']-area['data']['agemed']['value']['2001']['all']
# Out:
# E05009289
# E05009290
# E05009293
# E05009294
# E05009295
# E05009297
# E05009298
# E05009299
# E05009300
# E05009301
# E05009303
# E05009306
# E05009307
# E05009312
# E05011090

# %%
# Seperate the areas by area type
regions = []
for i in areas:
    if i['type']=='rgn':
        regions.append(i)
        
lads = []
for i in areas:
    if i['type']=='lad':
        lads.append(i)
        
countries = []
for i in areas:
    if (i['type']=='ew')|(i['type']=='ctry'):
        countries.append(i)

# %%
# Find each LAD local and national ranks and put in prioirity order
for thisLad in lads:
    
    # Empty array will be populted with ranks for each variable
    ranks = []

    # Filter areas with same parent
    sister_lads = []
    lad_code = thisLad['parents'][0]['code']
    for i in range(len(lads)):
        if  lad_code == lads[i]['parents'][0]['code']:
            sister_lads.append(lads[i])

    # Loop through the various data variables
    for a in thisLad['data']:
        if a in ['population', 'density', 'agemed']:
            b = 'value'
        else:
            b = 'perc'
        # Create nested object with localised rank
        thisLad['data'][a][b+"_rank_local"] = {}    
        for c in ['2011', 'change']:
            thisLad['data'][a][b+"_rank_local"][c] = {}
            for d in thisLad['data'][a][b][c]:
                vari = thisLad['data'][a][b][c][d]

                # Create sorted list of values from sister areas
                group_values = []
                for lad in sister_lads:
                    group_values.append(lad['data'][a][b][c][d])
                    group_values = [x if (type(x) == float) | (type(x) == int) else np.nan for x in group_values]
                group_values.sort(reverse=True)

                # Find index of value of area of interest
                varRank = group_values.index(vari) + 1

                # Convert bottom half rankings into negative values
                if varRank>len(group_values)/2:
                    varRank = varRank-len(group_values)-1
                    
                natRank = thisLad['data'][a][b+"_rank"][c][d]
                if natRank > 168:
                    natRank = natRank-336-1

                thisLad['data'][a][b+"_rank_local"][c][d] = varRank

                # Append ranking data to original array
                ranks.append({
                    'label': a+'_'+b+'_'+c+'_'+d, 
                    'locRank': varRank, 
                    'natRank': natRank, 
                    'value': vari})

    # Sort in rank order
    ranks = sorted(ranks, key=lambda x: (abs(x['locRank']), -abs(x['value'])))
    thisLad["Priorities"] = ranks

# %%
topics = [{1: 'population', 2: 'value', 3: 'all'}, 
          {1: 'health', 2: 'perc', 3: 'good'},
          {1: 'travel', 2: 'perc', 3: 'car_van'},
          {1: 'agemed', 2: 'value', 3: 'all'},
          {1: 'economic', 2: 'perc', 3: 'employee'},
          {1: 'health', 2: 'perc', 3: 'bad'},
          {1: 'ethnicity', 2: 'perc', 3: 'black'},
          {1: 'economic', 2: 'perc', 3: 'student'},
          {1: 'economic', 2: 'perc', 3: 'self-employed'}]

ladCodes = []
for lad in lads:
    ladCodes.append(lad['code'])
    
    
df = pd.DataFrame(columns=
                  ['lad', '2001',  '2011',  'change', 'natRank', 'localRank', 'topic', 'parent'])
for j in range(len(topics)):
    df1 = pd.DataFrame(index=ladCodes, columns=
                      ['lad', '2001',  '2011',  'change', 'natRank', 'localRank', 'topic', 'parent'])
    for i in range(len(lads)):
        df1['lad'].iloc[i] = lads[i]['name']
        df1['2001'].iloc[i] = lads[i]['data'][topics[j][1]][topics[j][2]]['2001'][topics[j][3]]
        df1['2011'].iloc[i] = lads[i]['data'][topics[j][1]][topics[j][2]]['2011'][topics[j][3]]    
        df1['change'].iloc[i] = lads[i]['data'][topics[j][1]][topics[j][2]]['change'][topics[j][3]]
        df1['natRank'].iloc[i] = lads[i]['data'][topics[j][1]][topics[j][2]+"_rank"]['change'][topics[j][3]]    
        df1['localRank'].iloc[i] = lads[i]['data'][topics[j][1]][topics[j][2]+"_rank_local"]['change'][topics[j][3]]    
        df1['topic'].iloc[i] = topics[j][1]+"_"+topics[j][3]
        df1['parent'].iloc[i] = lads[i]['parents'][0]['name']
    df = pd.concat([df,df1])
df['natRank'] = np.where(df['natRank'] > 168, df['natRank']-337,df['natRank'])



for topic in topics:
    for lad in lads:
        
#       Find the areas that this area has overtaken
        v2001 = lad['data'][topic[1]][topic[2]]['2001'][topic[3]]
        v2011 = lad['data'][topic[1]][topic[2]]['2011'][topic[3]]
        dfT = df[(df['topic']==topic[1]+"_"+topic[3])&(df['2001']>v2001)&(df['2011']<v2011)]
        obje = []
        for i in range(dfT.shape[0]):
            obje.append(dfT.iloc[i]['lad'])

        lad['data'][topic[1]][topic[2]+"_rank"]['overtake'] = {}
        lad['data'][topic[1]][topic[2]+"_rank"]['overtake'][topic[3]] = obje
        
#       Find the area immediatly above or below
        below = lad['data'][topic[1]][topic[2]+'_rank_local']['2011'][topic[3]]
        above = lad['data'][topic[1]][topic[2]+'_rank_local']['2011'][topic[3]]-2
        if below<0:
            below=below+1
            above=above+1
        reg = lad['parents'][0]['name']
        name_above = df[(df['parent']==reg)&(df['topic']==topic[1]+"_"+topic[3])].sort_values('2011', ascending=False).iloc[above]['lad']
        name_below = df[(df['parent']==reg)&(df['topic']==topic[1]+"_"+topic[3])].sort_values('2011', ascending=False).iloc[below]['lad']
        if above>0:
            area_above = {'name': name_above,
                         'value': df[(df['lad']==name_above)&(df['topic']==topic[1]+"_"+topic[3])]['2011'].iloc[0]}
        else:
            area_above = 'NaN'
        if below<len(df[(df['parent']==reg)&(df['topic']==topic[1]+"_"+topic[3])]):
            area_below = {'name': name_below,
                          'value': df[(df['lad']==name_below)&(df['topic']==topic[1]+"_"+topic[3])]['2011'].iloc[0]}
        else:
            area_below = 'NaN'
        
        if 'above_below' not in lad['data'][topic[1]][topic[2]+'_rank_local'].keys():
            lad['data'][topic[1]][topic[2]+'_rank_local']['above_below'] = {}

        if topic[3] not in lad['data'][topic[1]][topic[2]+'_rank_local']['above_below'].keys():
            lad['data'][topic[1]][topic[2]+'_rank_local']['above_below'][topic[3]] = {}
        
        lad['data'][topic[1]][topic[2]+'_rank_local']['above_below'][topic[3]]["above"] = area_above
        lad['data'][topic[1]][topic[2]+'_rank_local']['above_below'][topic[3]]["below"] = area_below
            
        # Add top and bottom three biggest movers for each subject to every area
        df_topic = df[(df['topic']==topic[1]+"_"+topic[3])&(abs(df['natRank'])<4)]
        ob = {}
        for index, row in df_topic.iterrows():
            ob[row['natRank']]= {row['lad']: row['change']}
        if 'top_bottom' not in lad['data'][topic[1]][topic[2]+'_rank'].keys():
            lad['data'][topic[1]][topic[2]+'_rank']['top_bottom'] = {}
        lad['data'][topic[1]][topic[2]+'_rank']['top_bottom'][topic[3]]=ob

# %%
# Filter out priority list by subject
for lad in lads:
    subjectList = ["fair", "rent_free", "shared_ownership", "bicycle", "taxi", "moto", "bus", "other", "female", "male"]
    priorities = []
    priorities2011 = []
    for rank in lad['Priorities']:
        s=rank['label'].split("_")
        if len(s)>4:
            s[3] = s[3] + "_" + s[4]
        if ((s[2] == "change") & (s[3] not in subjectList)):
            priorities.append(rank)
        if (s[2]!="change"):
            priorities2011.append(rank)
    lad['pri'] = priorities
    lad['pri2011'] = priorities2011

# %%
# Create triple data for areas of closest proximity
geogTriples = []
for lad in lads:
    list1 = lad['bounds'][0]+lad['bounds'][1]
    for lad2 in lads:
        list2 = lad2['bounds'][0]+lad2['bounds'][1]
        listDif = [abs(list1[i]-list2[i]) for i in [0,1,2,3]]
        listDif.sort()
        if (sum(listDif[:3]) < 0.3) & (lad!=lad2):
            geogTriples.append([lad['name'], lad2['name'], ("near", round(sum(listDif[:3]), 2))])

# %%
for thisLad in lads:

    # Find nearby area of same area type
    nearSimilar = []
    for i in geogTriples:
        try:
            if ((i[0]==thisLad['name'])&(typeLookup[i[1]]==typeLookup[thisLad['name']])):
                nearSimilar.append([i[0], i[1], ('near_similar', i[2][1])])
        except:
            pass

    if len(nearSimilar)==0:
        nearSimilar = [i for i in geogTriples if i[0]==thisLad['name']]

    nearSimilar = sorted(nearSimilar, key=lambda x: x[2][1])


    # Find and refine stories
    stories = []
    stories=stories+[i for i in thisLad['pri'] if abs(i['locRank']) <= 5]
    stories=stories+[i for i in thisLad['pri'] if (abs(i['natRank']) <= 10)&(abs(i['locRank']) > 5)]

    change = sorted(thisLad['pri'], reverse=True, key=lambda x: abs(x['value']))

    bigchange = [i for i in change if abs(i['value'])>4.5]
    for i in range(len(bigchange)):
        if len(stories)<4:
            stories=stories+[bigchange[i]]

    smallchange = sorted([i for i in change if abs(i['value'])<1], reverse=False, key=lambda x: abs(x['value']))
    for i in range(len(smallchange)):
        if len(stories)<5:
            stories=stories+[smallchange[i]]

    stories = sorted(stories, key=lambda x: (abs(x['locRank']), abs(x['natRank']), -abs(x['value'])))
    stories = sorted(stories, reverse=True, key=lambda x: x['label']=='population_value_change_all')

    storiesRefined =[]
    notInc = ['density', 'age10yr']
    for i in stories:
        if i['label'].split("_")[0] not in notInc:
            storiesRefined.append(i)
            notInc.append(i['label'].split("_")[0])
    storiesRefined

    
    #Find differences in data
    if thisLad['parents'][0]['name']=='Wales':
        region=[i for i in countries if i['name']=="Wales"][0]
        country=[i for i in countries if i['name']=="Wales"][0]
    else:
        region=[i for i in regions if i['name']==thisLad['parents'][0]['name']][0]
        country=[i for i in countries if i['name']==thisLad['parents'][1]['name']][0]

    def reg(i):
        s=i['label'].split("_")
        if len(s)>4:
            s[3] = s[3] + "_" + s[4]
        return region['data'][s[0]][s[1]][s[2]][s[3]]
    regDiff = [(i['label'], i['value']-reg(i)) for i in change]
    regDiff = sorted(regDiff, reverse=True, key=lambda x: abs(x[1]))

    def cou(i):
        s=i['label'].split("_")
        if len(s)>4:
            s[3] = s[3] + "_" + s[4]
        return countries[1]['data'][s[0]][s[1]][s[2]][s[3]]
    couDiff = [(i['label'], i['value']-cou(i)) for i in change]
    couDiff = sorted(couDiff, reverse=True, key=lambda x: abs(x[1]))
    
    try:
        nearSimilarData = {}
        nearSimilarData['name'] = nearSimilar[0][1]
        nearSimilarData['data'] = [lad for lad in lads if lad['name']==nearSimilar[0][1]][0]['data']
    except:
        nearSimilarData = []

    def near(i):
        s=i['label'].split("_")
        if len(s)>4:
            s[3] = s[3] + "_" + s[4]
        return nearSimilarData['data'][s[0]][s[1]][s[2]][s[3]]
    if len(nearSimilarData)>0:
        nearDiff = [(i['label'], i['value']-near(i)) for i in change]
        nearDiff = sorted(nearDiff, reverse=True, key=lambda x: abs(x[1]))

    nearTops = sorted([(lad['name'], lad['pri'][0]) for lad in lads if lad['name'] in [i[1] for i in nearSimilar if i[0]==thisLad['name']]], key=lambda x: abs(x[1]['locRank']))

    ageBandChange = sorted([(i, thisLad['data']['age10yr']['value']['2011'][i]-thisLad['data']['age10yr']['value']['2001'][i]) for i in thisLad['data']['age10yr']['value']['2001'].keys()], 
           reverse=True, key=lambda x: x[1])

    equalAgeChange = [lad['name'] for 
     lad in lads if (lad['parents'][0]['name'] == thisLad['parents'][0]['name']) 
     & (lad['data']['agemed']['value']['change']['all']==thisLad['data']['agemed']['value']['change']['all'])]
    len(equalAgeChange)

    # Add data to object
    thisLad['stories'] = storiesRefined
    thisLad['nearSimilar'] = {}
    thisLad['nearSimilar']['triples'] = nearSimilar
    thisLad['nearSimilar']['nearTops'] = nearTops
    thisLad['nearSimilar']['nearTops'] = nearSimilarData
    thisLad['differences'] = {}
    thisLad['differences']['country'] = couDiff
    thisLad['differences']['region'] = regDiff
    thisLad['differences']['near'] = nearDiff
    thisLad['data']['age10yr']['absChange'] = ageBandChange
    thisLad['data']['agemed']['value_rank_local']['equalAgeChange]'] = len(equalAgeChange)

# %%
for lad in lads:
    try:
        with open('/Users/theojolliffe/Documents/census-data-transformed/json/place/'+lad['code']+'.json', 'w') as outfile:
            json.dump(lad, outfile)
        print("Worked: ", lad['name'])

    except:
        print("Failed: ", lad['name'])
# Out:
# Worked:  Hartlepool
# Worked:  Middlesbrough
# Worked:  Redcar and Cleveland
# Worked:  Stockton-on-Tees
# Worked:  Darlington
# Worked:  Halton
# Worked:  Warrington
# Worked:  Blackburn with Darwen
# Worked:  Blackpool
# Worked:  Kingston upon Hull, City of
# Worked:  East Riding of Yorkshire
# Worked:  North East Lincolnshire
# Worked:  North Lincolnshire
# Worked:  York
# Worked:  Derby
# Worked:  Leicester
# Worked:  Rutland
# Worked:  Nottingham
# Worked:  Herefordshire, County of
# Worked:  Telford and Wrekin
# Worked:  Stoke-on-Trent
# Worked:  Bath and North East Somerset
# Worked:  Bristol, City of
# Worked:  North Somerset
# Worked:  South Gloucestershire
# Worked:  Plymouth
# Worked:  Torbay
# Worked:  Swindon
# Worked:  Peterborough
# Worked:  Luton
# Worked:  Southend-on-Sea
# Worked:  Thurrock
# Worked:  Medway
# Worked:  Bracknell Forest
# Worked:  West Berkshire
# Worked:  Reading
# Worked:  Slough
# Worked:  Windsor and Maidenhead
# Worked:  Wokingham
# Worked:  Milton Keynes
# Worked:  Brighton and Hove
# Worked:  Portsmouth
# Worked:  Southampton
# Worked:  Isle of Wight
# Worked:  County Durham
# Worked:  Cheshire East
# Worked:  Cheshire West and Chester
# Worked:  Shropshire
# Worked:  Cornwall
# Worked:  Isles of Scilly
# Worked:  Wiltshire
# Worked:  Bedford
# Worked:  Central Bedfordshire
# Worked:  Northumberland
# Worked:  Bournemouth, Christchurch and Poole
# Worked:  Dorset
# Worked:  Buckinghamshire
# Worked:  Cambridge
# Worked:  East Cambridgeshire
# Worked:  Fenland
# Worked:  Huntingdonshire
# Worked:  South Cambridgeshire
# Worked:  Allerdale
# Worked:  Barrow-in-Furness
# Worked:  Carlisle
# Worked:  Copeland
# Worked:  Eden
# Worked:  South Lakeland
# Worked:  Amber Valley
# Worked:  Bolsover
# Worked:  Chesterfield
# Worked:  Derbyshire Dales
# Worked:  Erewash
# Worked:  High Peak
# Worked:  North East Derbyshire
# Worked:  South Derbyshire
# Worked:  East Devon
# Worked:  Exeter
# Worked:  Mid Devon
# Worked:  North Devon
# Worked:  South Hams
# Worked:  Teignbridge
# Worked:  Torridge
# Worked:  West Devon
# Worked:  Eastbourne
# Worked:  Hastings
# Worked:  Lewes
# Worked:  Rother
# Worked:  Wealden
# Worked:  Basildon
# Worked:  Braintree
# Worked:  Brentwood
# Worked:  Castle Point
# Worked:  Chelmsford
# Worked:  Colchester
# Worked:  Epping Forest
# Worked:  Harlow
# Worked:  Maldon
# Worked:  Rochford
# Worked:  Tendring
# Worked:  Uttlesford
# Worked:  Cheltenham
# Worked:  Cotswold
# Worked:  Forest of Dean
# Worked:  Gloucester
# Worked:  Stroud
# Worked:  Tewkesbury
# Worked:  Basingstoke and Deane
# Worked:  East Hampshire
# Worked:  Eastleigh
# Worked:  Fareham
# Worked:  Gosport
# Worked:  Hart
# Worked:  Havant
# Worked:  New Forest
# Worked:  Rushmoor
# Worked:  Test Valley
# Worked:  Winchester
# Worked:  Broxbourne
# Worked:  Dacorum
# Worked:  Hertsmere
# Worked:  North Hertfordshire
# Worked:  Three Rivers
# Worked:  Watford
# Worked:  Ashford
# Worked:  Canterbury
# Worked:  Dartford
# Worked:  Dover
# Worked:  Gravesham
# Worked:  Maidstone
# Worked:  Sevenoaks
# Worked:  Folkestone and Hythe
# Worked:  Swale
# Worked:  Thanet
# Worked:  Tonbridge and Malling
# Worked:  Tunbridge Wells
# Worked:  Burnley
# Worked:  Chorley
# Worked:  Fylde
# Worked:  Hyndburn
# Worked:  Lancaster
# Worked:  Pendle
# Worked:  Preston
# Worked:  Ribble Valley
# Worked:  Rossendale
# Worked:  South Ribble
# Worked:  West Lancashire
# Worked:  Wyre
# Worked:  Blaby
# Worked:  Charnwood
# Worked:  Harborough
# Worked:  Hinckley and Bosworth
# Worked:  Melton
# Worked:  North West Leicestershire
# Worked:  Oadby and Wigston
# Worked:  Boston
# Worked:  East Lindsey
# Worked:  Lincoln
# Worked:  North Kesteven
# Worked:  South Holland
# Worked:  South Kesteven
# Worked:  West Lindsey
# Worked:  Breckland
# Worked:  Broadland
# Worked:  Great Yarmouth
# Worked:  King's Lynn and West Norfolk
# Worked:  North Norfolk
# Worked:  Norwich
# Worked:  South Norfolk
# Worked:  Corby
# Worked:  Daventry
# Worked:  East Northamptonshire
# Worked:  Kettering
# Worked:  Northampton
# Worked:  South Northamptonshire
# Worked:  Wellingborough
# Worked:  Craven
# Worked:  Hambleton
# Worked:  Harrogate
# Worked:  Richmondshire
# Worked:  Ryedale
# Worked:  Scarborough
# Worked:  Selby
# Worked:  Ashfield
# Worked:  Bassetlaw
# Worked:  Broxtowe
# Worked:  Gedling
# Worked:  Mansfield
# Worked:  Newark and Sherwood
# Worked:  Rushcliffe
# Worked:  Cherwell
# Worked:  Oxford
# Worked:  South Oxfordshire
# Worked:  Vale of White Horse
# Worked:  West Oxfordshire
# Worked:  Mendip
# Worked:  Sedgemoor
# Worked:  South Somerset
# Worked:  Cannock Chase
# Worked:  East Staffordshire
# Worked:  Lichfield
# Worked:  Newcastle-under-Lyme
# Worked:  South Staffordshire
# Worked:  Stafford
# Worked:  Staffordshire Moorlands
# Worked:  Tamworth
# Worked:  Babergh
# Worked:  Ipswich
# Worked:  Mid Suffolk
# Worked:  Elmbridge
# Worked:  Epsom and Ewell
# Worked:  Guildford
# Worked:  Mole Valley
# Worked:  Reigate and Banstead
# Worked:  Runnymede
# Worked:  Spelthorne
# Worked:  Surrey Heath
# Worked:  Tandridge
# Worked:  Waverley
# Worked:  Woking
# Worked:  North Warwickshire
# Worked:  Nuneaton and Bedworth
# Worked:  Rugby
# Worked:  Stratford-on-Avon
# Worked:  Warwick
# Worked:  Adur
# Worked:  Arun
# Worked:  Chichester
# Worked:  Crawley
# Worked:  Horsham
# Worked:  Mid Sussex
# Worked:  Worthing
# Worked:  Bromsgrove
# Worked:  Malvern Hills
# Worked:  Redditch
# Worked:  Worcester
# Worked:  Wychavon
# Worked:  Wyre Forest
# Worked:  St Albans
# Worked:  Welwyn Hatfield
# Worked:  East Hertfordshire
# Worked:  Stevenage
# Worked:  East Suffolk
# Worked:  West Suffolk
# Worked:  Somerset West and Taunton
# Worked:  Bolton
# Worked:  Bury
# Worked:  Manchester
# Worked:  Oldham
# Worked:  Rochdale
# Worked:  Salford
# Worked:  Stockport
# Worked:  Tameside
# Worked:  Trafford
# Worked:  Wigan
# Worked:  Knowsley
# Worked:  Liverpool
# Worked:  St. Helens
# Worked:  Sefton
# Worked:  Wirral
# Worked:  Barnsley
# Worked:  Doncaster
# Worked:  Rotherham
# Worked:  Sheffield
# Worked:  Newcastle upon Tyne
# Worked:  North Tyneside
# Worked:  South Tyneside
# Worked:  Sunderland
# Worked:  Birmingham
# Worked:  Coventry
# Worked:  Dudley
# Worked:  Sandwell
# Worked:  Solihull
# Worked:  Walsall
# Worked:  Wolverhampton
# Worked:  Bradford
# Worked:  Calderdale
# Worked:  Kirklees
# Worked:  Leeds
# Worked:  Wakefield
# Worked:  Gateshead
# Worked:  City of London
# Worked:  Barking and Dagenham
# Worked:  Barnet
# Worked:  Bexley
# Worked:  Brent
# Worked:  Bromley
# Worked:  Camden
# Worked:  Croydon
# Worked:  Ealing
# Worked:  Enfield
# Worked:  Greenwich
# Worked:  Hackney
# Worked:  Hammersmith and Fulham
# Worked:  Haringey
# Worked:  Harrow
# Worked:  Havering
# Worked:  Hillingdon
# Worked:  Hounslow
# Worked:  Islington
# Worked:  Kensington and Chelsea
# Worked:  Kingston upon Thames
# Worked:  Lambeth
# Worked:  Lewisham
# Worked:  Merton
# Worked:  Newham
# Worked:  Redbridge
# Worked:  Richmond upon Thames
# Worked:  Southwark
# Worked:  Sutton
# Worked:  Tower Hamlets
# Worked:  Waltham Forest
# Worked:  Wandsworth
# Worked:  Westminster
# Worked:  Isle of Anglesey
# Worked:  Gwynedd
# Worked:  Conwy
# Worked:  Denbighshire
# Worked:  Flintshire
# Worked:  Wrexham
# Worked:  Ceredigion
# Worked:  Pembrokeshire
# Worked:  Carmarthenshire
# Worked:  Swansea
# Worked:  Neath Port Talbot
# Worked:  Bridgend
# Worked:  Vale of Glamorgan
# Worked:  Cardiff
# Worked:  Rhondda Cynon Taff
# Worked:  Caerphilly
# Worked:  Blaenau Gwent
# Worked:  Torfaen
# Worked:  Monmouthshire
# Worked:  Newport
# Worked:  Powys
# Worked:  Merthyr Tydfil

# %%
# !git add .
# !git commit -m "Add files"
# !git push -u origin main

# %%
[i for i in lads if i['parents'][0]['name']=='Wales']
# Out:
# [{'code': 'W06000001',
#   'name': 'Isle of Anglesey',
#   'type': 'lad',
#   'area': 71124.11,
#   'count': 336,
#   'parents': [{'code': 'W92000004', 'name': 'Wales', 'type': 'ctry'},
#    {'code': 'K04000001', 'name': 'England and Wales', 'type': 'ew'}],
#   'bounds': [[-4.69671, 53.12612], [-4.01903, 53.4358]],
#   'data': {'population': {'perc': {'2001': {'female': 51.6, 'male': 48.4},
#      '2011': {'female': 50.86, 'male': 49.14},
#      'change': {'female': -0.74, 'male': 0.74}},
#     'perc_rank': {'2001': {'female': 98, 'male': 237},
#      '2011': {'female': 173, 'male': 161},
#      'change': {'female': 262, 'male': 75}},
#     'value': {'2001': {'all': 66829, 'female': 34481, 'male': 32348},
#      '2011': {'all': 69751, 'female': 35477, 'male': 34274},
#      'change': {'all': 4.37, 'female': 2.89, 'male': 5.95}},
#     'value_rank': {'2001': {'all': 317, 'female': 317, 'male': 317},
#      '2011': {'all': 316, 'female': 315, 'male': 316},
#      'change': {'all': 249, 'female': 267, 'male': 215},
#      'overtake': {'all': ['Barrow-in-Furness']},
#      'top_bottom': {'all': {-1: {'Barrow-in-Furness': -4.02},
#        2: {'Manchester': 28.08},
#        -2: {'Sefton': -3.24},
#        -3: {'South Tyneside': -3.05},
#        3: {'Newham': 26.28},
#        1: {'Tower Hamlets': 29.57}}}},
#     'value_rank_local': {'2011': {'all': -2, 'female': -2, 'male': -2},
#      'change': {'all': -9, 'female': -9, 'male': -9},
#      'above_below': {'all': {'above': 'NaN',
#        'below': {'name': 'Merthyr Tydfil', 'value': 58802}}}}},
#    'age10yr': {'perc': {'2001': {'0-9': 11.66,
#       '10-19': 12.55,
#       '20-29': 10.25,
#       '30-39': 12.79,
#       '40-49': 13.04,
#       '50-59': 14.81,
#       '60-69': 11.34,
#       '70plus': 13.56},
#      '2011': {'0-9': 10.53,
#       '10-19': 10.89,
#       '20-29': 10.7,
#       '30-39': 10.62,
#       '40-49': 13.46,
#       '50-59': 13.53,
#       '60-69': 14.65,
#       '70plus': 15.61},
#      'change': {'0-9': -1.13,
#       '10-19': -1.66,
#       '20-29': 0.45,
#       '30-39': -2.17,
#       '40-49': 0.42,
#       '50-59': -1.28,
#       '60-69': 3.31,
#       '70plus': 2.05}},
#     'perc_rank': {'2001': {'0-9': 225,
#       '10-19': 182,
#       '20-29': 231,
#       '30-39': 318,
#       '40-49': 249,
#       '50-59': 39,
#       '60-69': 27,
#       '70plus': 62},
#      '2011': {'0-9': 252,
#       '10-19': 317,
#       '20-29': 220,
#       '30-39': 279,
#       '40-49': 308,
#       '50-59': 62,
#       '60-69': 23,
#       '70plus': 36},
#      'change': {'0-9': 257,
#       '10-19': 318,
#       '20-29': 195,
#       '30-39': 87,
#       '40-49': 315,
#       '50-59': 288,
#       '60-69': 45,
#       '70plus': 22}},
#     'value': {'2001': {'0-9': 7806,
#       '10-19': 8408,
#       '20-29': 6863,
#       '30-39': 8564,
#       '40-49': 8733,
#       '50-59': 9921,
#       '60-69': 7596,
#       '70plus': 9081,
#       'all': 66972},
#      '2011': {'0-9': 7342,
#       '10-19': 7597,
#       '20-29': 7466,
#       '30-39': 7409,
#       '40-49': 9391,
#       '50-59': 9439,
#       '60-69': 10220,
#       '70plus': 10887,
#       'all': 69751},
#      'change': {'0-9': -5.94,
#       '10-19': -9.65,
#       '20-29': 8.79,
#       '30-39': -13.49,
#       '40-49': 7.53,
#       '50-59': -4.86,
#       '60-69': 34.54,
#       '70plus': 19.89,
#       'all': 4.15}},
#     'value_rank': {'2001': {'0-9': 313,
#       '10-19': 314,
#       '20-29': 309,
#       '30-39': 320,
#       '40-49': 318,
#       '50-59': 301,
#       '60-69': 285,
#       '70plus': 289,
#       'all': 317},
#      '2011': {'0-9': 314,
#       '10-19': 319,
#       '20-29': 311,
#       '30-39': 315,
#       '40-49': 320,
#       '50-59': 313,
#       '60-69': 282,
#       '70plus': 275,
#       'all': 316},
#      'change': {'0-9': 270,
#       '10-19': 324,
#       '20-29': 220,
#       '30-39': 162,
#       '40-49': 318,
#       '50-59': 299,
#       '60-69': 105,
#       '70plus': 57,
#       'all': 253}},
#     'perc_rank_local': {'2011': {'0-9': -5,
#       '10-19': -1,
#       '20-29': -6,
#       '30-39': -8,
#       '40-49': -4,
#       '50-59': 4,
#       '60-69': 2,
#       '70plus': 3},
#      'change': {'0-9': 11,
#       '10-19': -2,
#       '20-29': -4,
#       '30-39': 5,
#       '40-49': -3,
#       '50-59': -2,
#       '60-69': 2,
#       '70plus': 1}},
#     'absChange': [('all', 2779),
#      ('60-69', 2624),
#      ('70plus', 1806),
#      ('40-49', 658),
#      ('20-29', 603),
#      ('0-9', -464),
#      ('50-59', -482),
#      ('10-19', -811),
#      ('30-39', -1155)]},
#    'ethnicity': {'perc': {'2001': {'asian': 0.28,
#       'black': 0.07,
#       'mixed': 0.32,
#       'other': 0.08,
#       'white': 99.25},
#      '2011': {'asian': 0.7,
#       'black': 0.12,
#       'mixed': 0.69,
#       'other': 0.26,
#       'white': 98.24},
#      'change': {'asian': 0.42,
#       'black': 0.05,
#       'mixed': 0.37,
#       'other': 0.18,
#       'white': -1.01}},
#     'perc_rank': {'2001': {'asian': 324,
#       'black': 316,
#       'mixed': 320,
#       'other': 277,
#       'white': 9},
#      '2011': {'asian': 313,
#       'black': 317,
#       'mixed': 298,
#       'other': 180,
#       'white': 28},
#      'change': {'asian': 284,
#       'black': 300,
#       'mixed': 258,
#       'other': 125,
#       'white': 71},
#      'overtake': {'black': ['Teignbridge',
#        'Torridge',
#        'West Devon',
#        'Craven']},
#      'top_bottom': {'black': {1: {'Barking and Dagenham': 13.02},
#        3: {'Croydon': 6.83},
#        2: {'Greenwich': 8.02},
#        -2: {'Hackney': -1.56},
#        -3: {'Haringey': -1.28},
#        -1: {'Newham': -2.01}}}},
#     'value': {'2001': {'all': 66866,
#       'asian': 185,
#       'black': 50,
#       'mixed': 211,
#       'other': 56,
#       'white': 66364},
#      '2011': {'all': 69751,
#       'asian': 491,
#       'black': 81,
#       'mixed': 480,
#       'other': 179,
#       'white': 68520},
#      'change': {'all': 4.31,
#       'asian': 165.41,
#       'black': 62.0,
#       'mixed': 127.49,
#       'other': 219.64,
#       'white': 3.25}},
#     'value_rank': {'2001': {'all': 317,
#       'asian': 331,
#       'black': 322,
#       'mixed': 327,
#       'other': 309,
#       'white': 314},
#      '2011': {'all': 316,
#       'asian': 323,
#       'black': 328,
#       'mixed': 320,
#       'other': 247,
#       'white': 312},
#      'change': {'all': 249,
#       'asian': 49,
#       'black': 255,
#       'mixed': 25,
#       'other': 60,
#       'white': 155}},
#     'perc_rank_local': {'2011': {'asian': -2,
#       'black': -3,
#       'mixed': -11,
#       'other': 8,
#       'white': 5},
#      'change': {'asian': -3, 'black': -5, 'mixed': 9, 'other': 7, 'white': 10},
#      'above_below': {'black': {'above': 'NaN',
#        'below': {'name': 'Powys', 'value': 0.1}}}}},
#    'health': {'perc': {'2001': {'bad': 10.53, 'fair': 22.11, 'good': 67.37},
#      '2011': {'bad': 6.32, 'fair': 15.11, 'good': 78.57},
#      'change': {'bad': -4.21, 'fair': -7.0, 'good': 11.2}},
#     'perc_rank': {'2001': {'bad': 73, 'fair': 187, 'good': 222},
#      '2011': {'bad': 82, 'fair': 57, 'good': 262},
#      'change': {'bad': 277, 'fair': 3, 'good': 310},
#      'overtake': {'bad': ['Sheffield',
#        'Barking and Dagenham',
#        'Hackney',
#        'Wrexham']},
#      'top_bottom': {'good': {-3: {'Wokingham': 10.23},
#        -2: {'Maldon': 10.14},
#        -1: {'Surrey Heath': 10.04},
#        1: {'Manchester': 15.87},
#        2: {'Barking and Dagenham': 15.48},
#        3: {'Tower Hamlets': 15.42}},
#       'bad': {1: {'Wokingham': -1.86},
#        2: {'Daventry': -2.03},
#        3: {'Surrey Heath': -2.06},
#        -3: {'Neath Port Talbot': -5.9},
#        -2: {'Rhondda Cynon Taff': -6.08},
#        -1: {'Merthyr Tydfil': -6.93}}}},
#     'value': {'2001': {'all': 66829,
#       'bad': 7035,
#       'fair': 14774,
#       'good': 45020},
#      '2011': {'all': 69751, 'bad': 4409, 'fair': 10541, 'good': 54801},
#      'change': {'all': 4.37, 'bad': -37.33, 'fair': -28.65, 'good': 21.73}},
#     'value_rank': {'2001': {'all': 317, 'bad': 261, 'fair': 312, 'good': 315},
#      '2011': {'all': 316, 'bad': 270, 'fair': 294, 'good': 315},
#      'change': {'all': 249, 'bad': 256, 'fair': 8, 'good': 265}},
#     'perc_rank_local': {'2011': {'bad': -6, 'fair': 10, 'good': 9},
#      'change': {'bad': 8, 'fair': 1, 'good': -1},
#      'above_below': {'good': {'above': {'name': 'Powys', 'value': 78.94},
#        'below': {'name': 'Newport', 'value': 78.55}},
#       'bad': {'above': 'NaN', 'below': {'name': 'Wrexham', 'value': 6.21}}}}},
#    'economic': {'perc': {'2001': {'employee': 44.48,
#       'inactive': 40.5,
#       'self-employed': 8.81,
#       'student': 1.52,
#       'unemployed': 4.7},
#      '2011': {'employee': 47.67,
#       'inactive': 35.02,
#       'self-employed': 10.23,
#       'student': 2.4,
#       'unemployed': 4.69},
#      'change': {'employee': 3.19,
#       'inactive': -5.48,
#       'self-employed': 1.42,
#       'student': 0.88,
#       'unemployed': -0.01}},
#     'perc_rank': {'2001': {'employee': 323,
#       'inactive': 19,
#       'self-employed': 163,
#       'student': 327,
#       'unemployed': 32},
#      '2011': {'employee': 303,
#       'inactive': 29,
#       'self-employed': 160,
#       'student': 264,
#       'unemployed': 92},
#      'change': {'employee': 16,
#       'inactive': 309,
#       'self-employed': 115,
#       'student': 73,
#       'unemployed': 320},
#      'overtake': {'self-employed': ['Blackpool',
#        'East Riding of Yorkshire',
#        'Tendring',
#        'West Lancashire',
#        'Blaby',
#        'Hinckley and Bosworth',
#        'South Holland',
#        'South Kesteven',
#        'West Lindsey',
#        'Breckland',
#        'Newark and Sherwood',
#        'North Warwickshire']},
#      'top_bottom': {'employee': {-1: {'Slough': -3.85},
#        3: {'Knowsley': 5.32},
#        -3: {'Hillingdon': -3.67},
#        1: {'Tower Hamlets': 6.23},
#        -2: {'Waltham Forest': -3.8},
#        2: {'Merthyr Tydfil': 5.92}},
#       'student': {-2: {'Wokingham': -0.07},
#        -1: {'Isles of Scilly': -0.38},
#        2: {'Lincoln': 3.32},
#        3: {'Newcastle upon Tyne': 2.96},
#        1: {'Newham': 4.1}},
#       'self-employed': {-2: {'Blackpool': -0.09},
#        -1: {'Boston': -0.16},
#        -3: {'East Lindsey': 0.06},
#        2: {'Haringey': 4.86},
#        3: {'Newham': 4.53},
#        1: {'Waltham Forest': 5.06}}}},
#     'value': {'2001': {'all': 47991,
#       'employee': 21345,
#       'inactive': 19434,
#       'self-employed': 4226,
#       'student': 731,
#       'unemployed': 2255},
#      '2011': {'all': 50818,
#       'employee': 24223,
#       'inactive': 17795,
#       'self-employed': 5200,
#       'student': 1219,
#       'unemployed': 2381},
#      'change': {'all': 5.89,
#       'employee': 13.48,
#       'inactive': -8.43,
#       'self-employed': 23.05,
#       'student': 66.76,
#       'unemployed': 5.59}},
#     'value_rank': {'2001': {'all': 317,
#       'employee': 322,
#       'inactive': 265,
#       'self-employed': 307,
#       'student': 324,
#       'unemployed': 187},
#      '2011': {'all': 317,
#       'employee': 320,
#       'inactive': 282,
#       'self-employed': 309,
#       'student': 313,
#       'unemployed': 259},
#      'change': {'all': 236,
#       'employee': 58,
#       'inactive': 319,
#       'self-employed': 185,
#       'student': 26,
#       'unemployed': 323}},
#     'perc_rank_local': {'2011': {'employee': -6,
#       'inactive': 10,
#       'self-employed': 9,
#       'student': -8,
#       'unemployed': 7},
#      'change': {'employee': 5,
#       'inactive': -9,
#       'self-employed': 4,
#       'student': 7,
#       'unemployed': -3},
#      'above_below': {'employee': {'above': 'NaN',
#        'below': {'name': 'Carmarthenshire', 'value': 47.63}},
#       'student': {'above': 'NaN',
#        'below': {'name': 'Monmouthshire', 'value': 2.27}},
#       'self-employed': {'above': {'name': 'Denbighshire', 'value': 10.3},
#        'below': {'name': 'Vale of Glamorgan', 'value': 9.29}}}}},
#    'travel': {'perc': {'2001': {'bicycle': 1.92,
#       'bus': 2.01,
#       'car_van': 67.21,
#       'foot': 11.62,
#       'home': 15.01,
#       'moto': 0.73,
#       'other': 0.68,
#       'taxi': 0.41,
#       'train_metro': 0.41},
#      '2011': {'bicycle': 1.58,
#       'bus': 2.67,
#       'car_van': 76.5,
#       'foot': 9.54,
#       'home': 6.85,
#       'moto': 0.73,
#       'other': 0.97,
#       'taxi': 0.38,
#       'train_metro': 0.78},
#      'change': {'bicycle': -0.34,
#       'bus': 0.66,
#       'car_van': 9.29,
#       'foot': -2.08,
#       'home': -8.16,
#       'moto': 0.0,
#       'other': 0.29,
#       'taxi': -0.03,
#       'train_metro': 0.37}},
#     'perc_rank': {'2001': {'bicycle': 214,
#       'bus': 303,
#       'car_van': 146,
#       'foot': 110,
#       'home': 34,
#       'moto': 298,
#       'other': 16,
#       'taxi': 180,
#       'train_metro': 258},
#      '2011': {'bicycle': 224,
#       'bus': 239,
#       'car_van': 40,
#       'foot': 194,
#       'home': 98,
#       'moto': 170,
#       'other': 23,
#       'taxi': 165,
#       'train_metro': 315},
#      'change': {'bicycle': 185,
#       'bus': 73,
#       'car_van': 26,
#       'foot': 273,
#       'home': 313,
#       'moto': 27,
#       'other': 103,
#       'taxi': 149,
#       'train_metro': 295},
#      'overtake': {'car_van': ['Middlesbrough',
#        'Redcar and Cleveland',
#        'Stockton-on-Tees',
#        'Halton',
#        'Warrington',
#        'Blackburn with Darwen',
#        'Derby',
#        'Stoke-on-Trent',
#        'South Gloucestershire',
#        'Swindon',
#        'Peterborough',
#        'Luton',
#        'Thurrock',
#        'Bracknell Forest',
#        'West Berkshire',
#        'Slough',
#        'Windsor and Maidenhead',
#        'Wokingham',
#        'Milton Keynes',
#        'County Durham',
#        'Cheshire East',
#        'Cheshire West and Chester',
#        'Bedford',
#        'Central Bedfordshire',
#        'Bournemouth, Christchurch and Poole',
#        'Buckinghamshire',
#        'Fenland',
#        'Huntingdonshire',
#        'South Cambridgeshire',
#        'Copeland',
#        'Chesterfield',
#        'Basildon',
#        'Brentwood',
#        'Chelmsford',
#        'Harlow',
#        'Uttlesford',
#        'Gloucester',
#        'Stroud',
#        'Tewkesbury',
#        'Basingstoke and Deane',
#        'Eastleigh',
#        'Fareham',
#        'Hart',
#        'Havant',
#        'New Forest',
#        'Rushmoor',
#        'Test Valley',
#        'Winchester',
#        'Broxbourne',
#        'Dacorum',
#        'Hertsmere',
#        'Three Rivers',
#        'Ashford',
#        'Dartford',
#        'Maidstone',
#        'Sevenoaks',
#        'Tonbridge and Malling',
#        'Burnley',
#        'Fylde',
#        'Hyndburn',
#        'Preston',
#        'Ribble Valley',
#        'West Lancashire',
#        'Boston',
#        "King's Lynn and West Norfolk",
#        'South Norfolk',
#        'Corby',
#        'Kettering',
#        'Northampton',
#        'Selby',
#        'Ashfield',
#        'Cherwell',
#        'Vale of White Horse',
#        'South Somerset',
#        'East Staffordshire',
#        'Stafford',
#        'Elmbridge',
#        'Mole Valley',
#        'Reigate and Banstead',
#        'Runnymede',
#        'Spelthorne',
#        'Surrey Heath',
#        'Rugby',
#        'Stratford-on-Avon',
#        'Warwick',
#        'Crawley',
#        'Redditch',
#        'Wychavon',
#        'St Albans',
#        'Welwyn Hatfield',
#        'East Hertfordshire',
#        'Stevenage',
#        'West Suffolk',
#        'Bolton',
#        'Salford',
#        'Trafford',
#        'Knowsley',
#        'St. Helens',
#        'Rotherham',
#        'Coventry',
#        'Dudley',
#        'Sandwell',
#        'Solihull',
#        'Wakefield',
#        'Hillingdon',
#        'Denbighshire',
#        'Swansea',
#        'Vale of Glamorgan',
#        'Monmouthshire',
#        'Newport',
#        'Merthyr Tydfil']},
#      'top_bottom': {'car_van': {3: {'East Northamptonshire': 13.48},
#        2: {'South Staffordshire': 14.43},
#        1: {'Staffordshire Moorlands': 14.88},
#        -1: {'Haringey': -25.96},
#        -3: {'Lewisham': -23.16},
#        -2: {'Newham': -24.53}}}},
#     'value': {'2001': {'all': 21714,
#       'bicycle': 417,
#       'bus': 436,
#       'car_van': 14593,
#       'foot': 2524,
#       'home': 3260,
#       'moto': 158,
#       'other': 148,
#       'taxi': 88,
#       'train_metro': 90},
#      '2011': {'all': 30431,
#       'bicycle': 481,
#       'bus': 812,
#       'car_van': 23281,
#       'foot': 2903,
#       'home': 2084,
#       'moto': 221,
#       'other': 295,
#       'taxi': 117,
#       'train_metro': 237},
#      'change': {'all': 40.14,
#       'bicycle': 15.35,
#       'bus': 86.24,
#       'car_van': 59.54,
#       'foot': 15.02,
#       'home': -36.07,
#       'moto': 39.87,
#       'other': 99.32,
#       'taxi': 32.95,
#       'train_metro': 163.33}},
#     'value_rank': {'2001': {'all': 326,
#       'bicycle': 316,
#       'bus': 329,
#       'car_van': 324,
#       'foot': 321,
#       'home': 296,
#       'moto': 330,
#       'other': 229,
#       'taxi': 302,
#       'train_metro': 306},
#      '2011': {'all': 320,
#       'bicycle': 307,
#       'bus': 303,
#       'car_van': 304,
#       'foot': 322,
#       'home': 283,
#       'moto': 310,
#       'other': 226,
#       'taxi': 276,
#       'train_metro': 329},
#      'change': {'all': 62,
#       'bicycle': 99,
#       'bus': 39,
#       'car_van': 32,
#       'foot': 190,
#       'home': 171,
#       'moto': 28,
#       'other': 188,
#       'taxi': 77,
#       'train_metro': 248}},
#     'perc_rank_local': {'2011': {'bicycle': 4,
#       'bus': -4,
#       'car_van': 10,
#       'foot': -11,
#       'home': 8,
#       'moto': 4,
#       'other': 1,
#       'taxi': -7,
#       'train_metro': -5},
#      'change': {'bicycle': -4,
#       'bus': 2,
#       'car_van': 2,
#       'foot': -6,
#       'home': -2,
#       'moto': 2,
#       'other': 6,
#       'taxi': 9,
#       'train_metro': -5},
#      'above_below': {'car_van': {'above': {'name': 'Carmarthenshire',
#         'value': 76.91},
#        'below': {'name': 'Merthyr Tydfil', 'value': 76.42}}}}},
#    'tenure': {'perc': {'2001': {'owned': 67.81,
#       'rent_free': 3.44,
#       'rented_private': 11.52,
#       'rented_social': 16.98,
#       'shared_ownership': 0.25},
#      '2011': {'owned': 68.55,
#       'rent_free': 2.45,
#       'rented_private': 14.13,
#       'rented_social': 14.67,
#       'shared_ownership': 0.21},
#      'change': {'owned': 0.74,
#       'rent_free': -0.99,
#       'rented_private': 2.61,
#       'rented_social': -2.31,
#       'shared_ownership': -0.04}},
#     'perc_rank': {'2001': {'owned': 256,
#       'rent_free': 12,
#       'rented_private': 77,
#       'rented_social': 127,
#       'shared_ownership': 319},
#      '2011': {'owned': 166,
#       'rent_free': 10,
#       'rented_private': 170,
#       'rented_social': 156,
#       'shared_ownership': 329},
#      'change': {'owned': 4,
#       'rent_free': 280,
#       'rented_private': 331,
#       'rented_social': 271,
#       'shared_ownership': 250}},
#     'value': {'2001': {'all': 28438,
#       'owned': 19284,
#       'rent_free': 979,
#       'rented_private': 3277,
#       'rented_social': 4828,
#       'shared_ownership': 70},
#      '2011': {'all': 30594,
#       'owned': 20971,
#       'rent_free': 749,
#       'rented_private': 4324,
#       'rented_social': 4487,
#       'shared_ownership': 63},
#      'change': {'all': 7.58,
#       'owned': 8.75,
#       'rent_free': -23.49,
#       'rented_private': 31.95,
#       'rented_social': -7.06,
#       'shared_ownership': -10.0}},
#     'value_rank': {'2001': {'all': 315,
#       'owned': 319,
#       'rent_free': 183,
#       'rented_private': 231,
#       'rented_social': 265,
#       'shared_ownership': 328},
#      '2011': {'all': 314,
#       'owned': 314,
#       'rent_free': 159,
#       'rented_private': 284,
#       'rented_social': 285,
#       'shared_ownership': 331},
#      'change': {'all': 145,
#       'owned': 13,
#       'rent_free': 115,
#       'rented_private': 331,
#       'rented_social': 294,
#       'shared_ownership': 280}},
#     'perc_rank_local': {'2011': {'owned': -11,
#       'rent_free': 2,
#       'rented_private': 9,
#       'rented_social': -9,
#       'shared_ownership': -5},
#      'change': {'owned': 1,
#       'rent_free': -4,
#       'rented_private': -3,
#       'rented_social': -6,
#       'shared_ownership': 7}}},
#    'density': {'value': {'2001': {'all': 0.94},
#      '2011': {'all': 0.98},
#      'change': {'all': 4.26}},
#     'value_rank': {'2001': {'all': 309},
#      '2011': {'all': 309},
#      'change': {'all': 251}},
#     'value_rank_local': {'2011': {'all': -6}, 'change': {'all': -8}}},
#    'agemed': {'value': {'2001': {'all': 40.0},
#      '2011': {'all': 42.0},
#      'change': {'all': 2.0}},
#     'value_rank': {'2001': {'all': 38},
#      '2011': {'all': 25},
#      'change': {'all': 69},
#      'overtake': {'all': ['Bournemouth, Christchurch and Poole',
#        'Eastbourne',
#        'Adur',
#        'Worthing']},
#      'top_bottom': {'all': {-3: {'Manchester': -2.0},
#        1: {'Maldon': 3.0},
#        3: {'Wychavon': 3.0},
#        -1: {'Barking and Dagenham': -3.0}}}},
#     'value_rank_local': {'2011': {'all': 2},
#      'change': {'all': 1},
#      'above_below': {'all': {'above': 'NaN',
#        'below': {'name': 'Powys', 'value': 42.0}}},
#      'equalAgeChange]': 3}}},
#   'Priorities': [{'label': 'health_perc_change_good',
#     'locRank': -1,
#     'natRank': -27,
#     'value': 11.2},
#    {'label': 'age10yr_perc_2011_10-19',
#     'locRank': -1,
#     'natRank': -20,
#     'value': 10.89},
#    {'label': 'health_perc_change_fair',
#     'locRank': 1,
#     'natRank': 3,
#     'value': -7.0},
#    {'label': 'age10yr_perc_change_70plus',
#     'locRank': 1,
#     'natRank': 22,
#     'value': 2.05},
#    {'label': 'agemed_value_change_all',
#     'locRank': 1,
#     'natRank': 69,
#     'value': 2.0},
#    {'label': 'travel_perc_2011_other',
#     'locRank': 1,
#     'natRank': 23,
#     'value': 0.97},
#    {'label': 'tenure_perc_change_owned',
#     'locRank': 1,
#     'natRank': 4,
#     'value': 0.74},
#    {'label': 'population_value_2011_all',
#     'locRank': -2,
#     'natRank': -21,
#     'value': 69751},
#    {'label': 'population_value_2011_female',
#     'locRank': -2,
#     'natRank': -22,
#     'value': 35477},
#    {'label': 'population_value_2011_male',
#     'locRank': -2,
#     'natRank': -21,
#     'value': 34274},
#    {'label': 'agemed_value_2011_all',
#     'locRank': 2,
#     'natRank': 25,
#     'value': 42.0},
#    {'label': 'age10yr_perc_2011_60-69',
#     'locRank': 2,
#     'natRank': 23,
#     'value': 14.65},
#    {'label': 'travel_perc_change_car_van',
#     'locRank': 2,
#     'natRank': 26,
#     'value': 9.29},
#    {'label': 'travel_perc_change_home',
#     'locRank': -2,
#     'natRank': -24,
#     'value': -8.16},
#    {'label': 'age10yr_perc_change_60-69',
#     'locRank': 2,
#     'natRank': 45,
#     'value': 3.31},
#    {'label': 'tenure_perc_2011_rent_free',
#     'locRank': 2,
#     'natRank': 10,
#     'value': 2.45},
#    {'label': 'age10yr_perc_change_10-19',
#     'locRank': -2,
#     'natRank': -19,
#     'value': -1.66},
#    {'label': 'age10yr_perc_change_50-59',
#     'locRank': -2,
#     'natRank': -49,
#     'value': -1.28},
#    {'label': 'ethnicity_perc_2011_asian',
#     'locRank': -2,
#     'natRank': -24,
#     'value': 0.7},
#    {'label': 'travel_perc_change_bus',
#     'locRank': 2,
#     'natRank': 73,
#     'value': 0.66},
#    {'label': 'travel_perc_change_moto',
#     'locRank': 2,
#     'natRank': 27,
#     'value': 0.0},
#    {'label': 'age10yr_perc_2011_70plus',
#     'locRank': 3,
#     'natRank': 36,
#     'value': 15.61},
#    {'label': 'tenure_perc_change_rented_private',
#     'locRank': -3,
#     'natRank': -6,
#     'value': 2.61},
#    {'label': 'age10yr_perc_change_40-49',
#     'locRank': -3,
#     'natRank': -22,
#     'value': 0.42},
#    {'label': 'ethnicity_perc_change_asian',
#     'locRank': -3,
#     'natRank': -53,
#     'value': 0.42},
#    {'label': 'ethnicity_perc_2011_black',
#     'locRank': -3,
#     'natRank': -20,
#     'value': 0.12},
#    {'label': 'economic_perc_change_unemployed',
#     'locRank': -3,
#     'natRank': -17,
#     'value': -0.01},
#    {'label': 'age10yr_perc_2011_50-59',
#     'locRank': 4,
#     'natRank': 62,
#     'value': 13.53},
#    {'label': 'age10yr_perc_2011_40-49',
#     'locRank': -4,
#     'natRank': -29,
#     'value': 13.46},
#    {'label': 'travel_perc_2011_bus',
#     'locRank': -4,
#     'natRank': -98,
#     'value': 2.67},
#    {'label': 'travel_perc_2011_bicycle',
#     'locRank': 4,
#     'natRank': -113,
#     'value': 1.58},
#    {'label': 'economic_perc_change_self-employed',
#     'locRank': 4,
#     'natRank': 115,
#     'value': 1.42},
#    {'label': 'tenure_perc_change_rent_free',
#     'locRank': -4,
#     'natRank': -57,
#     'value': -0.99},
#    {'label': 'travel_perc_2011_moto',
#     'locRank': 4,
#     'natRank': -167,
#     'value': 0.73},
#    {'label': 'age10yr_perc_change_20-29',
#     'locRank': -4,
#     'natRank': -142,
#     'value': 0.45},
#    {'label': 'travel_perc_change_bicycle',
#     'locRank': -4,
#     'natRank': -152,
#     'value': -0.34},
#    {'label': 'ethnicity_perc_2011_white',
#     'locRank': 5,
#     'natRank': 28,
#     'value': 98.24},
#    {'label': 'age10yr_perc_2011_0-9',
#     'locRank': -5,
#     'natRank': -85,
#     'value': 10.53},
#    {'label': 'economic_perc_change_employee',
#     'locRank': 5,
#     'natRank': 16,
#     'value': 3.19},
#    {'label': 'age10yr_perc_change_30-39',
#     'locRank': 5,
#     'natRank': 87,
#     'value': -2.17},
#    {'label': 'travel_perc_2011_train_metro',
#     'locRank': -5,
#     'natRank': -22,
#     'value': 0.78},
#    {'label': 'travel_perc_change_train_metro',
#     'locRank': -5,
#     'natRank': -42,
#     'value': 0.37},
#    {'label': 'tenure_perc_2011_shared_ownership',
#     'locRank': -5,
#     'natRank': -8,
#     'value': 0.21},
#    {'label': 'ethnicity_perc_change_black',
#     'locRank': -5,
#     'natRank': -37,
#     'value': 0.05},
#    {'label': 'economic_perc_2011_employee',
#     'locRank': -6,
#     'natRank': -34,
#     'value': 47.67},
#    {'label': 'age10yr_perc_2011_20-29',
#     'locRank': -6,
#     'natRank': -117,
#     'value': 10.7},
#    {'label': 'health_perc_2011_bad',
#     'locRank': -6,
#     'natRank': 82,
#     'value': 6.32},
#    {'label': 'tenure_perc_change_rented_social',
#     'locRank': -6,
#     'natRank': -66,
#     'value': -2.31},
#    {'label': 'travel_perc_change_foot',
#     'locRank': -6,
#     'natRank': -64,
#     'value': -2.08},
#    {'label': 'density_value_2011_all',
#     'locRank': -6,
#     'natRank': -28,
#     'value': 0.98},
#    {'label': 'travel_perc_change_other',
#     'locRank': 6,
#     'natRank': 103,
#     'value': 0.29},
#    {'label': 'economic_perc_2011_unemployed',
#     'locRank': 7,
#     'natRank': 92,
#     'value': 4.69},
#    {'label': 'economic_perc_change_student',
#     'locRank': 7,
#     'natRank': 73,
#     'value': 0.88},
#    {'label': 'travel_perc_2011_taxi',
#     'locRank': -7,
#     'natRank': 165,
#     'value': 0.38},
#    {'label': 'ethnicity_perc_change_other',
#     'locRank': 7,
#     'natRank': 125,
#     'value': 0.18},
#    {'label': 'tenure_perc_change_shared_ownership',
#     'locRank': 7,
#     'natRank': -87,
#     'value': -0.04},
#    {'label': 'age10yr_perc_2011_30-39',
#     'locRank': -8,
#     'natRank': -58,
#     'value': 10.62},
#    {'label': 'travel_perc_2011_home',
#     'locRank': 8,
#     'natRank': 98,
#     'value': 6.85},
#    {'label': 'density_value_change_all',
#     'locRank': -8,
#     'natRank': -86,
#     'value': 4.26},
#    {'label': 'health_perc_change_bad',
#     'locRank': 8,
#     'natRank': -60,
#     'value': -4.21},
#    {'label': 'economic_perc_2011_student',
#     'locRank': -8,
#     'natRank': -73,
#     'value': 2.4},
#    {'label': 'ethnicity_perc_2011_other',
#     'locRank': 8,
#     'natRank': -157,
#     'value': 0.26},
#    {'label': 'health_perc_2011_good',
#     'locRank': 9,
#     'natRank': -75,
#     'value': 78.57},
#    {'label': 'tenure_perc_2011_rented_social',
#     'locRank': -9,
#     'natRank': 156,
#     'value': 14.67},
#    {'label': 'tenure_perc_2011_rented_private',
#     'locRank': 9,
#     'natRank': -167,
#     'value': 14.13},
#    {'label': 'economic_perc_2011_self-employed',
#     'locRank': 9,
#     'natRank': 160,
#     'value': 10.23},
#    {'label': 'population_value_change_male',
#     'locRank': -9,
#     'natRank': -122,
#     'value': 5.95},
#    {'label': 'economic_perc_change_inactive',
#     'locRank': -9,
#     'natRank': -28,
#     'value': -5.48},
#    {'label': 'population_value_change_all',
#     'locRank': -9,
#     'natRank': -88,
#     'value': 4.37},
#    {'label': 'population_value_change_female',
#     'locRank': -9,
#     'natRank': -70,
#     'value': 2.89},
#    {'label': 'ethnicity_perc_change_mixed',
#     'locRank': 9,
#     'natRank': -79,
#     'value': 0.37},
#    {'label': 'travel_perc_change_taxi',
#     'locRank': 9,
#     'natRank': 149,
#     'value': -0.03},
#    {'label': 'travel_perc_2011_car_van',
#     'locRank': 10,
#     'natRank': 40,
#     'value': 76.5},
#    {'label': 'economic_perc_2011_inactive',
#     'locRank': 10,
#     'natRank': 29,
#     'value': 35.02},
#    {'label': 'health_perc_2011_fair',
#     'locRank': 10,
#     'natRank': 57,
#     'value': 15.11},
#    {'label': 'ethnicity_perc_change_white',
#     'locRank': 10,
#     'natRank': 71,
#     'value': -1.01},
#    {'label': 'tenure_perc_2011_owned',
#     'locRank': -11,
#     'natRank': 166,
#     'value': 68.55},
#    {'label': 'travel_perc_2011_foot',
#     'locRank': -11,
#     'natRank': -143,
#     'value': 9.54},
#    {'label': 'age10yr_perc_change_0-9',
#     'locRank': 11,
#     'natRank': -80,
#     'value': -1.13},
#    {'label': 'ethnicity_perc_2011_mixed',
#     'locRank': -11,
#     'natRank': -39,
#     'value': 0.69}],
#   'pri': [{'label': 'health_perc_change_good',
#     'locRank': -1,
#     'natRank': -27,
#     'value': 11.2},
#    {'label': 'age10yr_perc_change_70plus',
#     'locRank': 1,
#     'natRank': 22,
#     'value': 2.05},
#    {'label': 'agemed_value_change_all',
#     'locRank': 1,
#     'natRank': 69,
#     'value': 2.0},
#    {'label': 'tenure_perc_change_owned',
#     'locRank': 1,
#     'natRank': 4,
#     'value': 0.74},
#    {'label': 'travel_perc_change_car_van',
#     'locRank': 2,
#     'natRank': 26,
#     'value': 9.29},
#    {'label': 'travel_perc_change_home',
#     'locRank': -2,
#     'natRank': -24,
#     'value': -8.16},
#    {'label': 'age10yr_perc_change_60-69',
#     'locRank': 2,
#     'natRank': 45,
#     'value': 3.31},
#    {'label': 'age10yr_perc_change_10-19',
#     'locRank': -2,
#     'natRank': -19,
#     'value': -1.66},
#    {'label': 'age10yr_perc_change_50-59',
#     'locRank': -2,
#     'natRank': -49,
#     'value': -1.28},
#    {'label': 'tenure_perc_change_rented_private',
#     'locRank': -3,
#     'natRank': -6,
#     'value': 2.61},
#    {'label': 'age10yr_perc_change_40-49',
#     'locRank': -3,
#     'natRank': -22,
#     'value': 0.42},
#    {'label': 'ethnicity_perc_change_asian',
#     'locRank': -3,
#     'natRank': -53,
#     'value': 0.42},
#    {'label': 'economic_perc_change_unemployed',
#     'locRank': -3,
#     'natRank': -17,
#     'value': -0.01},
#    {'label': 'economic_perc_change_self-employed',
#     'locRank': 4,
#     'natRank': 115,
#     'value': 1.42},
#    {'label': 'age10yr_perc_change_20-29',
#     'locRank': -4,
#     'natRank': -142,
#     'value': 0.45},
#    {'label': 'economic_perc_change_employee',
#     'locRank': 5,
#     'natRank': 16,
#     'value': 3.19},
#    {'label': 'age10yr_perc_change_30-39',
#     'locRank': 5,
#     'natRank': 87,
#     'value': -2.17},
#    {'label': 'travel_perc_change_train_metro',
#     'locRank': -5,
#     'natRank': -42,
#     'value': 0.37},
#    {'label': 'ethnicity_perc_change_black',
#     'locRank': -5,
#     'natRank': -37,
#     'value': 0.05},
#    {'label': 'tenure_perc_change_rented_social',
#     'locRank': -6,
#     'natRank': -66,
#     'value': -2.31},
#    {'label': 'travel_perc_change_foot',
#     'locRank': -6,
#     'natRank': -64,
#     'value': -2.08},
#    {'label': 'economic_perc_change_student',
#     'locRank': 7,
#     'natRank': 73,
#     'value': 0.88},
#    {'label': 'density_value_change_all',
#     'locRank': -8,
#     'natRank': -86,
#     'value': 4.26},
#    {'label': 'health_perc_change_bad',
#     'locRank': 8,
#     'natRank': -60,
#     'value': -4.21},
#    {'label': 'economic_perc_change_inactive',
#     'locRank': -9,
#     'natRank': -28,
#     'value': -5.48},
#    {'label': 'population_value_change_all',
#     'locRank': -9,
#     'natRank': -88,
#     'value': 4.37},
#    {'label': 'ethnicity_perc_change_mixed',
#     'locRank': 9,
#     'natRank': -79,
#     'value': 0.37},
#    {'label': 'ethnicity_perc_change_white',
#     'locRank': 10,
#     'natRank': 71,
#     'value': -1.01},
#    {'label': 'age10yr_perc_change_0-9',
#     'locRank': 11,
#     'natRank': -80,
#     'value': -1.13}],
#   'pri2011': [{'label': 'age10yr_perc_2011_10-19',
#     'locRank': -1,
#     'natRank': -20,
#     'value': 10.89},
#    {'label': 'travel_perc_2011_other',
#     'locRank': 1,
#     'natRank': 23,
#     'value': 0.97},
#    {'label': 'population_value_2011_all',
#     'locRank': -2,
#     'natRank': -21,
#     'value': 69751},
#    {'label': 'population_value_2011_female',
#     'locRank': -2,
#     'natRank': -22,
#     'value': 35477},
#    {'label': 'population_value_2011_male',
#     'locRank': -2,
#     'natRank': -21,
#     'value': 34274},
#    {'label': 'agemed_value_2011_all',
#     'locRank': 2,
#     'natRank': 25,
#     'value': 42.0},
#    {'label': 'age10yr_perc_2011_60-69',
#     'locRank': 2,
#     'natRank': 23,
#     'value': 14.65},
#    {'label': 'tenure_perc_2011_rent_free',
#     'locRank': 2,
#     'natRank': 10,
#     'value': 2.45},
#    {'label': 'ethnicity_perc_2011_asian',
#     'locRank': -2,
#     'natRank': -24,
#     'value': 0.7},
#    {'label': 'age10yr_perc_2011_70plus',
#     'locRank': 3,
#     'natRank': 36,
#     'value': 15.61},
#    {'label': 'ethnicity_perc_2011_black',
#     'locRank': -3,
#     'natRank': -20,
#     'value': 0.12},
#    {'label': 'age10yr_perc_2011_50-59',
#     'locRank': 4,
#     'natRank': 62,
#     'value': 13.53},
#    {'label': 'age10yr_perc_2011_40-49',
#     'locRank': -4,
#     'natRank': -29,
#     'value': 13.46},
#    {'label': 'travel_perc_2011_bus',
#     'locRank': -4,
#     'natRank': -98,
#     'value': 2.67},
#    {'label': 'travel_perc_2011_bicycle',
#     'locRank': 4,
#     'natRank': -113,
#     'value': 1.58},
#    {'label': 'travel_perc_2011_moto',
#     'locRank': 4,
#     'natRank': -167,
#     'value': 0.73},
#    {'label': 'ethnicity_perc_2011_white',
#     'locRank': 5,
#     'natRank': 28,
#     'value': 98.24},
#    {'label': 'age10yr_perc_2011_0-9',
#     'locRank': -5,
#     'natRank': -85,
#     'value': 10.53},
#    {'label': 'travel_perc_2011_train_metro',
#     'locRank': -5,
#     'natRank': -22,
#     'value': 0.78},
#    {'label': 'tenure_perc_2011_shared_ownership',
#     'locRank': -5,
#     'natRank': -8,
#     'value': 0.21},
#    {'label': 'economic_perc_2011_employee',
#     'locRank': -6,
#     'natRank': -34,
#     'value': 47.67},
#    {'label': 'age10yr_perc_2011_20-29',
#     'locRank': -6,
#     'natRank': -117,
#     'value': 10.7},
#    {'label': 'health_perc_2011_bad',
#     'locRank': -6,
#     'natRank': 82,
#     'value': 6.32},
#    {'label': 'density_value_2011_all',
#     'locRank': -6,
#     'natRank': -28,
#     'value': 0.98},
#    {'label': 'economic_perc_2011_unemployed',
#     'locRank': 7,
#     'natRank': 92,
#     'value': 4.69},
#    {'label': 'travel_perc_2011_taxi',
#     'locRank': -7,
#     'natRank': 165,
#     'value': 0.38},
#    {'label': 'age10yr_perc_2011_30-39',
#     'locRank': -8,
#     'natRank': -58,
#     'value': 10.62},
#    {'label': 'travel_perc_2011_home',
#     'locRank': 8,
#     'natRank': 98,
#     'value': 6.85},
#    {'label': 'economic_perc_2011_student',
#     'locRank': -8,
#     'natRank': -73,
#     'value': 2.4},
#    {'label': 'ethnicity_perc_2011_other',
#     'locRank': 8,
#     'natRank': -157,
#     'value': 0.26},
#    {'label': 'health_perc_2011_good',
#     'locRank': 9,
#     'natRank': -75,
#     'value': 78.57},
#    {'label': 'tenure_perc_2011_rented_social',
#     'locRank': -9,
#     'natRank': 156,
#     'value': 14.67},
#    {'label': 'tenure_perc_2011_rented_private',
#     'locRank': 9,
#     'natRank': -167,
#     'value': 14.13},
#    {'label': 'economic_perc_2011_self-employed',
#     'locRank': 9,
#     'natRank': 160,
#     'value': 10.23},
#    {'label': 'travel_perc_2011_car_van',
#     'locRank': 10,
#     'natRank': 40,
#     'value': 76.5},
#    {'label': 'economic_perc_2011_inactive',
#     'locRank': 10,
#     'natRank': 29,
#     'value': 35.02},
#    {'label': 'health_perc_2011_fair',
#     'locRank': 10,
#     'natRank': 57,
#     'value': 15.11},
#    {'label': 'tenure_perc_2011_owned',
#     'locRank': -11,
#     'natRank': 166,
#     'value': 68.55},
#    {'label': 'travel_perc_2011_foot',
#     'locRank': -11,
#     'natRank': -143,
#     'value': 9.54},
#    {'label': 'ethnicity_perc_2011_mixed',
#     'locRank': -11,
#     'natRank': -39,
#     'value': 0.69}],
#   'stories': [{'label': 'tenure_perc_change_owned',
#     'locRank': 1,
#     'natRank': 4,
#     'value': 0.74},
#    {'label': 'health_perc_change_good',
#     'locRank': -1,
#     'natRank': -27,
#     'value': 11.2},
#    {'label': 'agemed_value_change_all',
#     'locRank': 1,
#     'natRank': 69,
#     'value': 2.0},
#    {'label': 'travel_perc_change_home',
#     'locRank': -2,
#     'natRank': -24,
#     'value': -8.16},
#    {'label': 'economic_perc_change_unemployed',
#     'locRank': -3,
#     'natRank': -17,
#     'value': -0.01},
#    {'label': 'ethnicity_perc_change_asian',
#     'locRank': -3,
#     'natRank': -53,
#     'value': 0.42}],
#   'nearSimilar': {'triples': [], 'nearTops': []},
#   'differences': {'country': [('travel_perc_change_car_van', 8.37),
#     ('tenure_perc_change_owned', 5.67),
#     ('ethnicity_perc_change_white', 4.5),
#     ('travel_perc_change_home', -4.34),
#     ('tenure_perc_change_rented_private', -4.34),
#     ('density_value_change_all', -3.7),
#     ('population_value_change_all', -3.51),
#     ('economic_perc_change_employee', 3.4699999999999998),
#     ('travel_perc_change_foot', -2.85),
#     ('economic_perc_change_inactive', -2.4300000000000006),
#     ('ethnicity_perc_change_asian', -2.38),
#     ('age10yr_perc_change_70plus', 1.9499999999999997),
#     ('age10yr_perc_change_60-69', 1.84),
#     ('travel_perc_change_train_metro', -1.67),
#     ('health_perc_change_good', -1.4300000000000015),
#     ('ethnicity_perc_change_black', -1.13),
#     ('economic_perc_change_unemployed', -1.04),
#     ('age10yr_perc_change_10-19', -1.0299999999999998),
#     ('agemed_value_change_all', 1.0),
#     ('age10yr_perc_change_40-49', -0.8600000000000001),
#     ('tenure_perc_change_rented_social', -0.8500000000000001),
#     ('age10yr_perc_change_50-59', -0.8),
#     ('age10yr_perc_change_0-9', -0.6799999999999999),
#     ('health_perc_change_bad', -0.6699999999999999),
#     ('ethnicity_perc_change_mixed', -0.57),
#     ('age10yr_perc_change_20-29', -0.56),
#     ('age10yr_perc_change_30-39', 0.1200000000000001),
#     ('economic_perc_change_self-employed', -0.020000000000000018),
#     ('economic_perc_change_student', 0.020000000000000018)],
#    'region': [('travel_perc_change_car_van', 5.239999999999999),
#     ('tenure_perc_change_owned', 4.27),
#     ('travel_perc_change_home', -3.5200000000000005),
#     ('tenure_perc_change_rented_private', -2.98),
#     ('travel_perc_change_foot', -2.23),
#     ('age10yr_perc_change_70plus', 1.7299999999999998),
#     ('health_perc_change_good', -1.5),
#     ('density_value_change_all', -1.4500000000000002),
#     ('ethnicity_perc_change_white', 1.2699999999999998),
#     ('age10yr_perc_change_60-69', 1.2400000000000002),
#     ('population_value_change_all', -1.1499999999999995),
#     ('economic_perc_change_employee', 1.1400000000000001),
#     ('agemed_value_change_all', 1.0),
#     ('tenure_perc_change_rented_social', -0.99),
#     ('age10yr_perc_change_20-29', -0.96),
#     ('age10yr_perc_change_10-19', -0.84),
#     ('economic_perc_change_unemployed', -0.83),
#     ('ethnicity_perc_change_asian', -0.77),
#     ('economic_perc_change_inactive', -0.6900000000000004),
#     ('age10yr_perc_change_50-59', -0.6900000000000001),
#     ('age10yr_perc_change_40-49', -0.6500000000000001),
#     ('health_perc_change_bad', 0.6100000000000003),
#     ('travel_perc_change_train_metro', -0.59),
#     ('economic_perc_change_self-employed', 0.47),
#     ('age10yr_perc_change_30-39', 0.30000000000000027),
#     ('ethnicity_perc_change_black', -0.3),
#     ('age10yr_perc_change_0-9', -0.1299999999999999),
#     ('economic_perc_change_student', -0.09999999999999998),
#     ('ethnicity_perc_change_mixed', -0.04999999999999999)],
#    'near': [('travel_perc_change_train_metro', -25.689999999999998),
#     ('population_value_change_all', 21.19),
#     ('density_value_change_all', 21.19),
#     ('travel_perc_change_foot', 12.36),
#     ('travel_perc_change_home', 5.98),
#     ('travel_perc_change_car_van', 4.0200000000000005),
#     ('ethnicity_perc_change_white', -3.539999999999999),
#     ('tenure_perc_change_owned', 3.5300000000000002),
#     ('tenure_perc_change_rented_social', -1.6700000000000002),
#     ('age10yr_perc_change_20-29', -1.5899999999999999),
#     ('tenure_perc_change_rented_private', -1.5),
#     ('age10yr_perc_change_60-69', -1.49),
#     ('age10yr_perc_change_0-9', 1.35),
#     ('economic_perc_change_employee', -1.3399999999999999),
#     ('economic_perc_change_inactive', 1.1599999999999997),
#     ('age10yr_perc_change_30-39', 1.15),
#     ('health_perc_change_good', 0.6199999999999992),
#     ('ethnicity_perc_change_black', 0.52),
#     ('economic_perc_change_unemployed', 0.45),
#     ('ethnicity_perc_change_mixed', -0.44999999999999996),
#     ('economic_perc_change_self-employed', -0.3700000000000001),
#     ('age10yr_perc_change_50-59', 0.27),
#     ('age10yr_perc_change_40-49', 0.21999999999999997),
#     ('health_perc_change_bad', 0.1900000000000004),
#     ('age10yr_perc_change_10-19', 0.15999999999999998),
#     ('ethnicity_perc_change_asian', -0.14000000000000012),
#     ('economic_perc_change_student', 0.09000000000000002),
#     ('age10yr_perc_change_70plus', -0.06000000000000005),
#     ('agemed_value_change_all', 0.0)]}},
#  {'code': 'W06000002',
#   'name': 'Gwynedd',
#   'type': 'lad',
#   'area': 253493.94,
#   'count': 336,
#   'parents': [{'code': 'W92000004', 'name': 'Wales', 'type': 'ctry'},
#    {'code': 'K04000001', 'name': 'England and Wales', 'type': 'ew'}],
#   'bounds': [[-4.80438, 52.53679], [-3.43678, 53.28112]],
#   'data': {'population': {'perc': {'2001': {'female': 52.05, 'male': 47.95},
#      '2011': {'female': 50.85, 'male': 49.15},
#      'change': {'female': -1.2, 'male': 1.2}},
#     'perc_rank': {'2001': {'female': 42, 'male': 295},
#      '2011': {'female': 177, 'male': 158},
#      'change': {'female': 312, 'male': 24}},
#     'value': {'2001': {'all': 116843, 'female': 60814, 'male': 56029},
#      '2011': {'all': 121874, 'female': 61968, 'male': 59906},
#      'change': {'all': 4.31, 'female': 1.9, 'male': 6.92}},
#     'value_rank': {'2001': {'all': 184, 'female': 178, 'male': 188},
#      '2011': {'all': 188, 'female': 190, 'male': 189},
#      'change': {'all': 251, 'female': 293, 'male': 182},
#      'overtake': {'all': ['Havant']},
#      'top_bottom': {'all': {-1: {'Barrow-in-Furness': -4.02},
#        2: {'Manchester': 28.08},
#        -2: {'Sefton': -3.24},
#        -3: {'South Tyneside': -3.05},
#        3: {'Newham': 26.28},
#        1: {'Tower Hamlets': 29.57}}}},
#     'value_rank_local': {'2011': {'all': -9, 'female': -9, 'male': -10},
#      'change': {'all': -8, 'female': -6, 'male': 9},
#      'above_below': {'all': {'above': 'NaN',
#        'below': {'name': 'Conwy', 'value': 115228}}}}},
#    'age10yr': {'perc': {'2001': {'0-9': 12.05,
#       '10-19': 12.34,
#       '20-29': 12.21,
#       '30-39': 12.69,
#       '40-49': 12.32,
#       '50-59': 13.68,
#       '60-69': 10.87,
#       '70plus': 13.84},
#      '2011': {'0-9': 10.66,
#       '10-19': 12.27,
#       '20-29': 13.29,
#       '30-39': 10.5,
#       '40-49': 13.19,
#       '50-59': 12.46,
#       '60-69': 13.07,
#       '70plus': 14.56},
#      'change': {'0-9': -1.39,
#       '10-19': -0.07,
#       '20-29': 1.08,
#       '30-39': -2.19,
#       '40-49': 0.87,
#       '50-59': -1.22,
#       '60-69': 2.2,
#       '70plus': 0.72}},
#     'perc_rank': {'2001': {'0-9': 182,
#       '10-19': 217,
#       '20-29': 113,
#       '30-39': 321,
#       '40-49': 309,
#       '50-59': 130,
#       '60-69': 55,
#       '70plus': 56},
#      '2011': {'0-9': 238,
#       '10-19': 122,
#       '20-29': 98,
#       '30-39': 291,
#       '40-49': 315,
#       '50-59': 199,
#       '60-69': 82,
#       '70plus': 65},
#      'change': {'0-9': 300,
#       '10-19': 65,
#       '20-29': 100,
#       '30-39': 89,
#       '40-49': 263,
#       '50-59': 284,
#       '60-69': 166,
#       '70plus': 148}},
#     'value': {'2001': {'0-9': 14087,
#       '10-19': 14426,
#       '20-29': 14282,
#       '30-39': 14836,
#       '40-49': 14400,
#       '50-59': 15997,
#       '60-69': 12712,
#       '70plus': 16183,
#       'all': 116923},
#      '2011': {'0-9': 12997,
#       '10-19': 14958,
#       '20-29': 16191,
#       '30-39': 12796,
#       '40-49': 16072,
#       '50-59': 15187,
#       '60-69': 15924,
#       '70plus': 17749,
#       'all': 121874},
#      'change': {'0-9': -7.74,
#       '10-19': 3.69,
#       '20-29': 13.37,
#       '30-39': -13.75,
#       '40-49': 11.61,
#       '50-59': -5.06,
#       '60-69': 25.27,
#       '70plus': 9.68,
#       'all': 4.23}},
#     'value_rank': {'2001': {'0-9': 179,
#       '10-19': 185,
#       '20-29': 160,
#       '30-39': 229,
#       '40-49': 216,
#       '50-59': 177,
#       '60-69': 144,
#       '70plus': 134,
#       'all': 182},
#      '2011': {'0-9': 194,
#       '10-19': 181,
#       '20-29': 154,
#       '30-39': 222,
#       '40-49': 222,
#       '50-59': 199,
#       '60-69': 153,
#       '70plus': 140,
#       'all': 188},
#      'change': {'0-9': 292,
#       '10-19': 141,
#       '20-29': 152,
#       '30-39': 168,
#       '40-49': 281,
#       '50-59': 305,
#       '60-69': 203,
#       '70plus': 187,
#       'all': 251}},
#     'perc_rank_local': {'2011': {'0-9': -6,
#       '10-19': 10,
#       '20-29': 6,
#       '30-39': -6,
#       '40-49': -3,
#       '50-59': -5,
#       '60-69': 9,
#       '70plus': 7},
#      'change': {'0-9': -6,
#       '10-19': 3,
#       '20-29': 9,
#       '30-39': 6,
#       '40-49': -9,
#       '50-59': -3,
#       '60-69': -10,
#       '70plus': 8}},
#     'absChange': [('all', 4951),
#      ('60-69', 3212),
#      ('20-29', 1909),
#      ('40-49', 1672),
#      ('70plus', 1566),
#      ('10-19', 532),
#      ('50-59', -810),
#      ('0-9', -1090),
#      ('30-39', -2040)]},
#    'ethnicity': {'perc': {'2001': {'asian': 0.54,
#       'black': 0.11,
#       'mixed': 0.45,
#       'other': 0.14,
#       'white': 98.77},
#      '2011': {'asian': 1.78,
#       'black': 0.24,
#       'mixed': 0.79,
#       'other': 0.72,
#       'white': 96.47},
#      'change': {'asian': 1.24,
#       'black': 0.13,
#       'mixed': 0.34,
#       'other': 0.58,
#       'white': -2.3}},
#     'perc_rank': {'2001': {'asian': 261,
#       'black': 279,
#       'mixed': 270,
#       'other': 191,
#       'white': 67},
#      '2011': {'asian': 196,
#       'black': 259,
#       'mixed': 277,
#       'other': 88,
#       'white': 136},
#      'change': {'asian': 170,
#       'black': 238,
#       'mixed': 273,
#       'other': 59,
#       'white': 165},
#      'overtake': {'black': ['Halton',
#        'Torbay',
#        'Isle of Wight',
#        'Shropshire',
#        'Cornwall',
#        'Dorset',
#        'High Peak',
#        'West Devon',
#        'Wealden',
#        'Stroud',
#        'Fylde',
#        'Pendle',
#        'West Lancashire',
#        'North Kesteven',
#        'Sedgemoor',
#        'South Somerset',
#        'Stratford-on-Avon',
#        'Malvern Hills',
#        'Wychavon',
#        'Wyre Forest',
#        'Somerset West and Taunton',
#        'Wirral',
#        'Denbighshire',
#        'Neath Port Talbot']},
#      'top_bottom': {'black': {1: {'Barking and Dagenham': 13.02},
#        3: {'Croydon': 6.83},
#        2: {'Greenwich': 8.02},
#        -2: {'Hackney': -1.56},
#        -3: {'Haringey': -1.28},
#        -1: {'Newham': -2.01}}}},
#     'value': {'2001': {'all': 116863,
#       'asian': 627,
#       'black': 132,
#       'mixed': 523,
#       'other': 158,
#       'white': 115423},
#      '2011': {'all': 121874,
#       'asian': 2170,
#       'black': 289,
#       'mixed': 964,
#       'other': 878,
#       'white': 117573},
#      'change': {'all': 4.29,
#       'asian': 246.09,
#       'black': 118.94,
#       'mixed': 84.32,
#       'other': 455.7,
#       'white': 1.86}},
#     'value_rank': {'2001': {'all': 183,
#       'asian': 247,
#       'black': 266,
#       'mixed': 254,
#       'other': 213,
#       'white': 173},
#      '2011': {'all': 188,
#       'asian': 206,
#       'black': 259,
#       'mixed': 263,
#       'other': 108,
#       'white': 173},
#      'change': {'all': 251,
#       'asian': 9,
#       'black': 147,
#       'mixed': 202,
#       'other': 14,
#       'white': 197}},
#     'perc_rank_local': {'2011': {'asian': 4,
#       'black': 8,
#       'mixed': 7,
#       'other': 4,
#       'white': -5},
#      'change': {'asian': 4, 'black': 9, 'mixed': 11, 'other': 4, 'white': -4},
#      'above_below': {'black': {'above': {'name': 'Ceredigion', 'value': 0.35},
#        'below': {'name': 'Gwynedd', 'value': 0.24}}}}},
#    'health': {'perc': {'2001': {'bad': 9.54, 'fair': 21.21, 'good': 69.25},
#      '2011': {'bad': 5.34, 'fair': 13.61, 'good': 81.05},
#      'change': {'bad': -4.2, 'fair': -7.6, 'good': 11.8}},
#     'perc_rank': {'2001': {'bad': 115, 'fair': 244, 'good': 158},
#      '2011': {'bad': 159, 'fair': 149, 'good': 185},
#      'change': {'bad': 276, 'fair': 18, 'good': 231},
#      'overtake': {'bad': []},
# ...
#       'value_rank': {'2001': {'all': 310,
#         'bad': 149,
#         'fair': 293,
#         'good': 320},
#        '2011': {'all': 315, 'bad': 150, 'fair': 274, 'good': 318},
#        'change': {'all': 326, 'bad': 184, 'fair': 28, 'good': 261}},
#       'perc_rank_local': {'2011': {'bad': 2, 'fair': 1, 'good': -1},
#        'change': {'bad': -4, 'fair': 7, 'good': 6},
#        'above_below': {'good': {'above': 'NaN',
#          'below': {'name': 'Cardiff', 'value': 81.43}},
#         'bad': {'above': 'NaN',
#          'below': {'name': 'Neath Port Talbot', 'value': 10.46}}}}},
#      'economic': {'perc': {'2001': {'employee': 45.94,
#         'inactive': 44.27,
#         'self-employed': 3.75,
#         'student': 1.36,
#         'unemployed': 4.69},
#        '2011': {'employee': 48.08,
#         'inactive': 37.95,
#         'self-employed': 5.03,
#         'student': 2.07,
#         'unemployed': 6.87},
#        'change': {'employee': 2.14,
#         'inactive': -6.32,
#         'self-employed': 1.28,
#         'student': 0.71,
#         'unemployed': 2.18}},
#       'perc_rank': {'2001': {'employee': 309,
#         'inactive': 3,
#         'self-employed': 336,
#         'student': 335,
#         'unemployed': 33},
#        '2011': {'employee': 293,
#         'inactive': 5,
#         'self-employed': 336,
#         'student': 329,
#         'unemployed': 9},
#        'change': {'employee': 33,
#         'inactive': 327,
#         'self-employed': 154,
#         'student': 107,
#         'unemployed': 6},
#        'overtake': {'self-employed': []},
#        'top_bottom': {'employee': {-1: {'Slough': -3.85},
#          3: {'Knowsley': 5.32},
#          -3: {'Hillingdon': -3.67},
#          1: {'Tower Hamlets': 6.23},
#          -2: {'Waltham Forest': -3.8},
#          2: {'Merthyr Tydfil': 5.92}},
#         'student': {-2: {'Wokingham': -0.07},
#          -1: {'Isles of Scilly': -0.38},
#          2: {'Lincoln': 3.32},
#          3: {'Newcastle upon Tyne': 2.96},
#          1: {'Newham': 4.1}},
#         'self-employed': {-2: {'Blackpool': -0.09},
#          -1: {'Boston': -0.16},
#          -3: {'East Lindsey': 0.06},
#          2: {'Haringey': 4.86},
#          3: {'Newham': 4.53},
#          1: {'Waltham Forest': 5.06}}}},
#       'value': {'2001': {'all': 49476,
#         'employee': 22727,
#         'inactive': 21901,
#         'self-employed': 1856,
#         'student': 674,
#         'unemployed': 2318},
#        '2011': {'all': 51809,
#         'employee': 24910,
#         'inactive': 19664,
#         'self-employed': 2606,
#         'student': 1072,
#         'unemployed': 3557},
#        'change': {'all': 4.72,
#         'employee': 9.61,
#         'inactive': -10.21,
#         'self-employed': 40.41,
#         'student': 59.05,
#         'unemployed': 53.45}},
#       'value_rank': {'2001': {'all': 314,
#         'employee': 318,
#         'inactive': 244,
#         'self-employed': 332,
#         'student': 328,
#         'unemployed': 177},
#        '2011': {'all': 315,
#         'employee': 319,
#         'inactive': 260,
#         'self-employed': 333,
#         'student': 322,
#         'unemployed': 160},
#        'change': {'all': 269,
#         'employee': 125,
#         'inactive': 324,
#         'self-employed': 37,
#         'student': 47,
#         'unemployed': 128}},
#       'perc_rank_local': {'2011': {'employee': -9,
#         'inactive': 2,
#         'self-employed': -1,
#         'student': -1,
#         'unemployed': 1},
#        'change': {'employee': 10,
#         'inactive': -2,
#         'self-employed': 7,
#         'student': -11,
#         'unemployed': 1},
#        'above_below': {'employee': {'above': 'NaN',
#          'below': {'name': 'Swansea', 'value': 47.89}},
#         'student': {'above': 'NaN',
#          'below': {'name': 'Ceredigion', 'value': 6.21}},
#         'self-employed': {'above': 'NaN',
#          'below': {'name': 'Powys', 'value': 17.39}}}}},
#      'travel': {'perc': {'2001': {'bicycle': 0.72,
#         'bus': 3.37,
#         'car_van': 72.65,
#         'foot': 14.52,
#         'home': 6.84,
#         'moto': 0.56,
#         'other': 0.29,
#         'taxi': 0.88,
#         'train_metro': 0.16},
#        '2011': {'bicycle': 0.47,
#         'bus': 3.08,
#         'car_van': 82.18,
#         'foot': 9.81,
#         'home': 1.98,
#         'moto': 0.53,
#         'other': 0.48,
#         'taxi': 0.62,
#         'train_metro': 0.85},
#        'change': {'bicycle': -0.25,
#         'bus': -0.29,
#         'car_van': 9.53,
#         'foot': -4.71,
#         'home': -4.86,
#         'moto': -0.03,
#         'other': 0.19,
#         'taxi': -0.26,
#         'train_metro': 0.69}},
#       'perc_rank': {'2001': {'bicycle': 334,
#         'bus': 212,
#         'car_van': 28,
#         'foot': 26,
#         'home': 280,
#         'moto': 331,
#         'other': 221,
#         'taxi': 32,
#         'train_metro': 330},
#        '2011': {'bicycle': 334,
#         'bus': 212,
#         'car_van': 1,
#         'foot': 179,
#         'home': 335,
#         'moto': 287,
#         'other': 276,
#         'taxi': 80,
#         'train_metro': 306},
#        'change': {'bicycle': 161,
#         'bus': 174,
#         'car_van': 21,
#         'foot': 335,
#         'home': 163,
#         'moto': 32,
#         'other': 227,
#         'taxi': 312,
#         'train_metro': 263},
#        'overtake': {'car_van': ['Stockton-on-Tees',
#          'Halton',
#          'Warrington',
#          'Telford and Wrekin',
#          'South Gloucestershire',
#          'Slough',
#          'Milton Keynes',
#          'Basildon',
#          'Eastleigh',
#          'Tonbridge and Malling',
#          'North West Leicestershire',
#          'Corby',
#          'Northampton',
#          'Wellingborough',
#          'Runnymede',
#          'Surrey Heath',
#          'North Warwickshire',
#          'Crawley',
#          'Welwyn Hatfield',
#          'Flintshire',
#          'Wrexham',
#          'Swansea',
#          'Neath Port Talbot',
#          'Bridgend',
#          'Rhondda Cynon Taff',
#          'Torfaen',
#          'Newport']},
#        'top_bottom': {'car_van': {3: {'East Northamptonshire': 13.48},
#          2: {'South Staffordshire': 14.43},
#          1: {'Staffordshire Moorlands': 14.88},
#          -1: {'Haringey': -25.96},
#          -3: {'Lewisham': -23.16},
#          -2: {'Newham': -24.53}}}},
#       'value': {'2001': {'all': 20986,
#         'bicycle': 151,
#         'bus': 708,
#         'car_van': 15247,
#         'foot': 3048,
#         'home': 1436,
#         'moto': 118,
#         'other': 61,
#         'taxi': 184,
#         'train_metro': 33},
#        '2011': {'all': 28291,
#         'bicycle': 134,
#         'bus': 870,
#         'car_van': 23249,
#         'foot': 2774,
#         'home': 561,
#         'moto': 151,
#         'other': 136,
#         'taxi': 175,
#         'train_metro': 241},
#        'change': {'all': 34.81,
#         'bicycle': -11.26,
#         'bus': 22.88,
#         'car_van': 52.48,
#         'foot': -8.99,
#         'home': -60.93,
#         'moto': 27.97,
#         'other': 122.95,
#         'taxi': -4.89,
#         'train_metro': 630.3}},
#       'value_rank': {'2001': {'all': 329,
#         'bicycle': 335,
#         'bus': 305,
#         'car_van': 318,
#         'foot': 300,
#         'home': 333,
#         'moto': 333,
#         'other': 328,
#         'taxi': 204,
#         'train_metro': 333},
#        '2011': {'all': 325,
#         'bicycle': 335,
#         'bus': 297,
#         'car_van': 306,
#         'foot': 325,
#         'home': 334,
#         'moto': 329,
#         'other': 330,
#         'taxi': 224,
#         'train_metro': 328},
#        'change': {'all': 92,
#         'bicycle': 261,
#         'bus': 125,
#         'car_van': 53,
#         'foot': 334,
#         'home': 335,
#         'moto': 46,
#         'other': 128,
#         'taxi': 241,
#         'train_metro': 56}},
#       'perc_rank_local': {'2011': {'bicycle': -3,
#         'bus': -9,
#         'car_van': 1,
#         'foot': 11,
#         'home': -1,
#         'moto': -9,
#         'other': -4,
#         'taxi': 8,
#         'train_metro': -6},
#        'change': {'bicycle': -8,
#         'bus': -10,
#         'car_van': 1,
#         'foot': -1,
#         'home': 10,
#         'moto': 4,
#         'other': -9,
#         'taxi': -1,
#         'train_metro': 11},
#        'above_below': {'car_van': {'above': 'NaN',
#          'below': {'name': 'Neath Port Talbot', 'value': 80.48}}}}},
#      'tenure': {'perc': {'2001': {'owned': 62.45,
#         'rent_free': 1.65,
#         'rented_private': 6.88,
#         'rented_social': 28.75,
#         'shared_ownership': 0.27},
#        '2011': {'owned': 62.09,
#         'rent_free': 1.04,
#         'rented_private': 12.8,
#         'rented_social': 23.95,
#         'shared_ownership': 0.13},
#        'change': {'owned': -0.36,
#         'rent_free': -0.61,
#         'rented_private': 5.92,
#         'rented_social': -4.8,
#         'shared_ownership': -0.14}},
#       'perc_rank': {'2001': {'owned': 292,
#         'rent_free': 245,
#         'rented_private': 242,
#         'rented_social': 30,
#         'shared_ownership': 316},
#        '2011': {'owned': 262,
#         'rent_free': 263,
#         'rented_private': 227,
#         'rented_social': 38,
#         'shared_ownership': 335},
#        'change': {'owned': 12,
#         'rent_free': 138,
#         'rented_private': 170,
#         'rented_social': 320,
#         'shared_ownership': 298}},
#       'value': {'2001': {'all': 29650,
#         'owned': 18517,
#         'rent_free': 489,
#         'rented_private': 2040,
#         'rented_social': 8523,
#         'shared_ownership': 81},
#        '2011': {'all': 30416,
#         'owned': 18884,
#         'rent_free': 316,
#         'rented_private': 3892,
#         'rented_social': 7284,
#         'shared_ownership': 40},
#        'change': {'all': 2.58,
#         'owned': 1.98,
#         'rent_free': -35.38,
#         'rented_private': 90.78,
#         'rented_social': -14.54,
#         'shared_ownership': -50.62}},
#       'value_rank': {'2001': {'all': 308,
#         'owned': 322,
#         'rent_free': 312,
#         'rented_private': 302,
#         'rented_social': 152,
#         'shared_ownership': 318},
#        '2011': {'all': 316,
#         'owned': 321,
#         'rent_free': 322,
#         'rented_private': 303,
#         'rented_social': 183,
#         'shared_ownership': 333},
#        'change': {'all': 311,
#         'owned': 122,
#         'rent_free': 258,
#         'rented_private': 149,
#         'rented_social': 329,
#         'shared_ownership': 333}},
#       'perc_rank_local': {'2011': {'owned': -2,
#         'rent_free': -4,
#         'rented_private': -10,
#         'rented_social': 1,
#         'shared_ownership': -1},
#        'change': {'owned': 3,
#         'rent_free': 11,
#         'rented_private': 7,
#         'rented_social': -1,
#         'shared_ownership': -10}}},
#      'density': {'value': {'2001': {'all': 6.44},
#        '2011': {'all': 6.42},
#        'change': {'all': -0.31}},
#       'value_rank': {'2001': {'all': 163},
#        '2011': {'all': 165},
#        'change': {'all': 326}},
#       'value_rank_local': {'2011': {'all': 5}, 'change': {'all': -1}}},
#      'agemed': {'value': {'2001': {'all': 38.0},
#        '2011': {'all': 39.0},
#        'change': {'all': 1.0}},
#       'value_rank': {'2001': {'all': 116},
#        '2011': {'all': 128},
#        'change': {'all': 144},
#        'overtake': {'all': ['Epsom and Ewell']},
#        'top_bottom': {'all': {-3: {'Manchester': -2.0},
#          1: {'Maldon': 3.0},
#          3: {'Wychavon': 3.0},
#          -1: {'Barking and Dagenham': -3.0}}}},
#       'value_rank_local': {'2011': {'all': 11},
#        'change': {'all': 4},
#        'above_below': {'all': {'above': {'name': 'Gwynedd', 'value': 40.0},
#          'below': {'name': 'Torfaen', 'value': 39.0}}},
#        'equalAgeChange]': 15}}}}},
#   'differences': {'country': [('economic_perc_change_inactive',
#      -6.760000000000001),
#     ('economic_perc_change_employee', 6.2),
#     ('ethnicity_perc_change_white', 4.1499999999999995),
#     ('travel_perc_change_car_van', 3.41),
#     ('health_perc_change_bad', -3.3899999999999997),
#     ('tenure_perc_change_owned', 3.3599999999999994),
#     ('density_value_change_all', -2.99),
#     ('population_value_change_all', -2.84),
#     ('ethnicity_perc_change_asian', -2.28),
#     ('age10yr_perc_change_20-29', 2.0300000000000002),
#     ('health_perc_change_good', 1.709999999999999),
#     ('tenure_perc_change_rented_private', -1.6500000000000004),
#     ('travel_perc_change_foot', -1.54),
#     ('age10yr_perc_change_10-19', -1.2400000000000002),
#     ('ethnicity_perc_change_black', -1.0),
#     ('age10yr_perc_change_30-39', -0.8599999999999999),
#     ('age10yr_perc_change_0-9', -0.69),
#     ('economic_perc_change_unemployed', 0.6499999999999999),
#     ('age10yr_perc_change_50-59', 0.53),
#     ('travel_perc_change_train_metro', -0.49),
#     ('ethnicity_perc_change_mixed', -0.4099999999999999),
#     ('tenure_perc_change_rented_social', -0.19999999999999996),
#     ('travel_perc_change_home', -0.16000000000000014),
#     ('age10yr_perc_change_40-49', 0.1299999999999999),
#     ('economic_perc_change_student', -0.10999999999999999),
#     ('age10yr_perc_change_70plus', 0.07999999999999999),
#     ('economic_perc_change_self-employed', 0.030000000000000027),
#     ('age10yr_perc_change_60-69', 0.0),
#     ('agemed_value_change_all', 0.0)],
#    'region': [('economic_perc_change_inactive', -5.0200000000000005),
#     ('economic_perc_change_employee', 3.87),
#     ('health_perc_change_bad', -2.1099999999999994),
#     ('tenure_perc_change_owned', 1.9599999999999997),
#     ('health_perc_change_good', 1.6400000000000006),
#     ('age10yr_perc_change_20-29', 1.6300000000000001),
#     ('age10yr_perc_change_10-19', -1.0500000000000003),
#     ('travel_perc_change_foot', -0.92),
#     ('ethnicity_perc_change_white', 0.9199999999999997),
#     ('economic_perc_change_unemployed', 0.86),
#     ('density_value_change_all', -0.7400000000000002),
#     ('age10yr_perc_change_30-39', -0.6799999999999997),
#     ('ethnicity_perc_change_asian', -0.6699999999999999),
#     ('travel_perc_change_home', 0.6599999999999997),
#     ('age10yr_perc_change_50-59', 0.64),
#     ('age10yr_perc_change_60-69', -0.5999999999999999),
#     ('travel_perc_change_train_metro', 0.5900000000000001),
#     ('economic_perc_change_self-employed', 0.52),
#     ('population_value_change_all', -0.47999999999999954),
#     ('tenure_perc_change_rented_social', -0.33999999999999986),
#     ('age10yr_perc_change_40-49', 0.33999999999999986),
#     ('tenure_perc_change_rented_private', -0.29000000000000004),
#     ('travel_perc_change_car_van', 0.28000000000000025),
#     ('economic_perc_change_student', -0.22999999999999998),
#     ('ethnicity_perc_change_black', -0.16999999999999998),
#     ('age10yr_perc_change_70plus', -0.14),
#     ('age10yr_perc_change_0-9', -0.1399999999999999),
#     ('ethnicity_perc_change_mixed', 0.11000000000000004),
#     ('agemed_value_change_all', 0.0)],
#    'near': [('population_value_change_all', 5.4),
#     ('density_value_change_all', 5.279999999999999),
#     ('travel_perc_change_car_van', -5.199999999999999),
#     ('travel_perc_change_foot', 3.94),
#     ('economic_perc_change_employee', 3.78),
#     ('economic_perc_change_inactive', -3.49),
#     ('tenure_perc_change_rented_social', 3.1399999999999997),
#     ('age10yr_perc_change_40-49', -1.36),
#     ('age10yr_perc_change_20-29', 1.32),
#     ('tenure_perc_change_owned', -1.21),
#     ('health_perc_change_bad', -1.1399999999999997),
#     ('health_perc_change_good', 1.0600000000000005),
#     ('age10yr_perc_change_50-59', 0.9700000000000001),
#     ('travel_perc_change_home', 0.8800000000000003),
#     ('travel_perc_change_train_metro', 0.8600000000000001),
#     ('age10yr_perc_change_10-19', -0.7300000000000002),
#     ('age10yr_perc_change_60-69', -0.72),
#     ('ethnicity_perc_change_white', -0.6700000000000002),
#     ('tenure_perc_change_rented_private', -0.6200000000000001),
#     ('economic_perc_change_unemployed', -0.5000000000000002),
#     ('age10yr_perc_change_0-9', 0.40000000000000013),
#     ('ethnicity_perc_change_asian', 0.28),
#     ('ethnicity_perc_change_mixed', 0.23000000000000004),
#     ('economic_perc_change_self-employed', 0.18999999999999995),
#     ('age10yr_perc_change_70plus', 0.13),
#     ('ethnicity_perc_change_black', 0.12),
#     ('economic_perc_change_student', 0.040000000000000036),
#     ('age10yr_perc_change_30-39', -0.020000000000000018),
#     ('agemed_value_change_all', 0.0)]}}]
