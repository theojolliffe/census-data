# %%
import pandas as pd
import json
import networkx as nx
from networkx_query import search_nodes, search_edges
import numpy as np
import math

# %%
with open('/Users/theojolliffe/Documents/Wayback BBC/topicScoresOrder.json', 'r') as fp:
    topicScoresOrder = json.load(fp)

topicScoresOrder = {i: {i[0]: 1/(1+i[1]/10) for i in topicScoresOrder[i]} for i in topicScoresOrder}

for i in topicScoresOrder.keys():
    topicScoresOrder[i]['welsh'] = 0.1

# %%
topicScoresOrder
# Out:
# {'cumbria': {'travel': 0.7278796788254589,
#   'health': 0.7373155446935475,
#   'children': 0.7476531793275849,
#   'care': 0.7585366002252635,
#   'hoursworked': 0.7611622171779674,
#   'economic': 0.7636918415774013,
#   'marital': 0.7685554019510524,
#   'tenure': 0.779938758790283,
#   'household': 0.7882348325426418,
#   'population': 0.7963740295092272,
#   'ethnicity': 0.7982391433758176,
#   'agemed': 0.7992360398420778,
#   'religion': 0.7995554267899909,
#   'welsh': 0.1},
#  'lancashire': {'travel': 0.7171315720239612,
#   'children': 0.748713647791873,
#   'care': 0.7513147822620997,
#   'health': 0.7586229979282538,
#   'household': 0.7757078208924982,
#   'tenure': 0.7759788872262368,
#   'agemed': 0.7806512760808537,
#   'religion': 0.7820732983808982,
#   'marital': 0.7852504244841253,
#   'economic': 0.7873235362629281,
#   'population': 0.787423350003117,
#   'hoursworked': 0.7972097949882635,
#   'ethnicity': 0.8084732213155831,
#   'welsh': 0.1},
#  'merseyside': {'travel': 0.7106237924816501,
#   'health': 0.7278382857596577,
#   'children': 0.7306060980859569,
#   'care': 0.7358807758835416,
#   'economic': 0.7711712174678397,
#   'household': 0.7750766839388459,
#   'agemed': 0.7779374674120872,
#   'religion': 0.779073671690977,
#   'marital': 0.7807961287530807,
#   'ethnicity': 0.7866335348970832,
#   'hoursworked': 0.7905448369982688,
#   'tenure': 0.7915405955832009,
#   'population': 0.796070104403568,
#   'welsh': 0.1},
#  'manchester': {'travel': 0.7074811043631529,
#   'children': 0.7238700206868964,
#   'health': 0.738087022115538,
#   'care': 0.7558519281123564,
#   'household': 0.7613326723373005,
#   'tenure': 0.7627581345485799,
#   'agemed': 0.7672102327141105,
#   'religion': 0.7702836218991344,
#   'marital': 0.7750766051631796,
#   'economic': 0.7839927242374438,
#   'ethnicity': 0.7868940014520368,
#   'population': 0.7904816454982166,
#   'hoursworked': 0.7997675055216205,
#   'welsh': 0.1},
#  'tees': {'travel': 0.7172159353385555,
#   'health': 0.7330266824699889,
#   'household': 0.7562546660863214,
#   'children': 0.7563254111096028,
#   'care': 0.7592436967564415,
#   'marital': 0.7621119017706416,
#   'economic': 0.7630458327172921,
#   'agemed': 0.7752324717620834,
#   'religion': 0.7752399092766117,
#   'population': 0.7804669768691049,
#   'tenure': 0.7813785438438218,
#   'hoursworked': 0.7820486035248075,
#   'ethnicity': 0.7924794793199582,
#   'welsh': 0.1},
#  'tyne_and_wear': {'travel': 0.7132919157284661,
#   'health': 0.7309526599857864,
#   'household': 0.7396440404949479,
#   'children': 0.7438546435316382,
#   'marital': 0.7498468363585112,
#   'tenure': 0.7517004404824085,
#   'care': 0.7559009554878222,
#   'economic': 0.7641805350605976,
#   'agemed': 0.7675808968012964,
#   'population': 0.7729957278679088,
#   'religion': 0.7782779605265256,
#   'hoursworked': 0.7805102861424732,
#   'ethnicity': 0.7826605264612522,
#   'welsh': 0.1},
#  'Humberside': {'travel': 0.6798212870622432,
#   'health': 0.7437993262790836,
#   'economic': 0.7582765706839657,
#   'tenure': 0.7613410936242878,
#   'children': 0.7646357479682637,
#   'care': 0.7754877366562047,
#   'religion': 0.7774426517036053,
#   'population': 0.7796201306255601,
#   'household': 0.7833630601553918,
#   'agemed': 0.7864338941997624,
#   'hoursworked': 0.7888920566447251,
#   'ethnicity': 0.7924335786659166,
#   'marital': 0.7931123834370233,
#   'welsh': 0.1},
#  'york_and_north_yorkshire': {'travel': 0.6817048085321266,
#   'health': 0.725670330094022,
#   'tenure': 0.7449304686492298,
#   'care': 0.7476526962151738,
#   'agemed': 0.7568477913223057,
#   'children': 0.7592804593980013,
#   'economic': 0.7610250594791239,
#   'population': 0.7637299714655365,
#   'religion': 0.7712414500502254,
#   'ethnicity': 0.7736166093333777,
#   'household': 0.781051954267434,
#   'marital': 0.7844083462727349,
#   'hoursworked': 0.7850184216212561,
#   'welsh': 0.1},
#  'leeds_and_west_yorkshire': {'travel': 0.6748469802564226,
#   'children': 0.7020544505115837,
#   'health': 0.7176939573855695,
#   'care': 0.7380275011363793,
#   'agemed': 0.7435902361826834,
#   'tenure': 0.7483515925068797,
#   'household': 0.7553240367844327,
#   'ethnicity': 0.7563267936860072,
#   'population': 0.7619877791078418,
#   'economic': 0.7625448587304298,
#   'hoursworked': 0.7630687416114176,
#   'religion': 0.7695054136545283,
#   'marital': 0.7796045890577495,
#   'welsh': 0.1},
#  'lincolnshire': {'travel': 0.6966217555914459,
#   'health': 0.7247778602494601,
#   'care': 0.7357799123570093,
#   'tenure': 0.7516470786018798,
#   'economic': 0.7528540748074632,
#   'population': 0.7603139327850758,
#   'household': 0.7609228957463471,
#   'religion': 0.7749262569723354,
#   'agemed': 0.7752367605173401,
#   'children': 0.7764223446323115,
#   'hoursworked': 0.7792242077344398,
#   'marital': 0.7889355186031335,
#   'ethnicity': 0.7907034967327953,
#   'welsh': 0.1},
#  'south_yorkshire': {'travel': 0.6784151779299022,
#   'children': 0.729343389755283,
#   'tenure': 0.7393739842015525,
#   'economic': 0.7430097947686956,
#   'agemed': 0.7453163581651455,
#   'household': 0.7492535040656901,
#   'health': 0.7523933250884309,
#   'population': 0.7527368127554158,
#   'ethnicity': 0.7534759587429236,
#   'care': 0.7567492633472069,
#   'marital': 0.767121811975364,
#   'hoursworked': 0.7674208961774796,
#   'religion': 0.7674862552218368,
#   'welsh': 0.1},
#  'birmingham_and_black_country': {'children': 0.7220287052357569,
#   'health': 0.722128175627472,
#   'care': 0.7284957073431817,
#   'economic': 0.7333963527921866,
#   'travel': 0.747400408612981,
#   'ethnicity': 0.7575116469584785,
#   'marital': 0.7585662324250787,
#   'household': 0.7587836077009091,
#   'tenure': 0.7634783664771301,
#   'agemed': 0.76419018380398,
#   'religion': 0.7669146360443794,
#   'hoursworked': 0.7696239939992029,
#   'population': 0.7728701498055927,
#   'welsh': 0.1},
#  'coventry_and_warwickshire': {'children': 0.7185309416524198,
#   'economic': 0.7467606773896089,
#   'health': 0.7523283892798939,
#   'travel': 0.7564841898294019,
#   'marital': 0.7581831370387576,
#   'ethnicity': 0.7584577517821391,
#   'tenure': 0.7648371615428005,
#   'household': 0.7658095353639987,
#   'care': 0.7705622075238632,
#   'hoursworked': 0.7725166473709209,
#   'religion': 0.7753837567536421,
#   'agemed': 0.7758148303990247,
#   'population': 0.7769023105016654,
#   'welsh': 0.1},
#  'hereford_and_worcester': {'health': 0.7278669621573836,
#   'care': 0.7337964257982882,
#   'economic': 0.7361568360257538,
#   'tenure': 0.738152682630958,
#   'travel': 0.7409609656392377,
#   'household': 0.7539032860316751,
#   'marital': 0.755114095372932,
#   'children': 0.7584363429228238,
#   'population': 0.7641749485077883,
#   'ethnicity': 0.769786193272499,
#   'agemed': 0.7703480546296605,
#   'religion': 0.780717053578176,
#   'hoursworked': 0.7879582406389446,
#   'welsh': 0.1},
#  'shropshire': {'health': 0.7232012569754513,
#   'children': 0.7412947797732231,
#   'care': 0.7415223248936491,
#   'economic': 0.7472441600906062,
#   'travel': 0.7482606069431281,
#   'household': 0.7490161766593407,
#   'agemed': 0.7572173165747657,
#   'hoursworked': 0.7682922396764882,
#   'population': 0.7685251373447868,
#   'tenure': 0.7709192048017249,
#   'marital': 0.7771934222488387,
#   'ethnicity': 0.7791278085767573,
#   'religion': 0.785293449347834,
#   'welsh': 0.1},
#  'stoke_and_staffordshire': {'health': 0.727468194754851,
#   'economic': 0.7362925509773827,
#   'travel': 0.7378631361548095,
#   'care': 0.7405173961581669,
#   'children': 0.7431367924162664,
#   'tenure': 0.7572372229068528,
#   'ethnicity': 0.7611371763829765,
#   'marital': 0.7646579351757811,
#   'population': 0.7717138221347241,
#   'agemed': 0.7734862827556096,
#   'household': 0.7782315477042996,
#   'religion': 0.782577388173454,
#   'hoursworked': 0.7834886723891394,
#   'welsh': 0.1},
#  'derbyshire': {'travel': 0.731339907114053,
#   'children': 0.7547208107870685,
#   'care': 0.764069924336305,
#   'economic': 0.7654714382738215,
#   'tenure': 0.7661730990240053,
#   'health': 0.7676070815936195,
#   'ethnicity': 0.780031988664208,
#   'household': 0.7819401345121526,
#   'marital': 0.7858492614614447,
#   'religion': 0.7904213575555611,
#   'hoursworked': 0.7916638777275617,
#   'population': 0.8013879476511109,
#   'agemed': 0.8044764469284269,
#   'welsh': 0.1},
#  'leicester': {'care': 0.7393581876689868,
#   'travel': 0.7432329630672528,
#   'health': 0.7511097467815198,
#   'children': 0.7578233075248743,
#   'religion': 0.7648159227291399,
#   'economic': 0.7652277262304135,
#   'hoursworked': 0.773422618263103,
#   'household': 0.7751357540829601,
#   'population': 0.7767575340673786,
#   'tenure': 0.7769680838036424,
#   'marital': 0.7820322751173794,
#   'ethnicity': 0.7838676754954726,
#   'agemed': 0.7840522983675902,
#   'welsh': 0.1},
#  'northamptonshire': {'travel': 0.7446021912596549,
#   'care': 0.7446090402611009,
#   'health': 0.7571177510690935,
#   'household': 0.7573426059969814,
#   'hoursworked': 0.7630837939999563,
#   'tenure': 0.7647645207218363,
#   'children': 0.7653397390460934,
#   'religion': 0.7759733116719143,
#   'marital': 0.7773647297315628,
#   'economic': 0.7788557349926716,
#   'population': 0.7825375402270139,
#   'ethnicity': 0.7880000045794249,
#   'agemed': 0.7975154327196261,
#   'welsh': 0.1},
#  'nottingham': {'health': 0.7385236836196117,
#   'travel': 0.7415676589308995,
#   'economic': 0.7566282648678956,
#   'marital': 0.7625183770210053,
#   'household': 0.7628929985158496,
#   'care': 0.7654861856959161,
#   'children': 0.765515036055764,
#   'population': 0.7783174489518041,
#   'ethnicity': 0.7822382304813825,
#   'agemed': 0.7834399869919909,
#   'tenure': 0.7918355345589295,
#   'religion': 0.7919102245825084,
#   'hoursworked': 0.7929205531341053,
#   'welsh': 0.1},
#  'bristol': {'children': 0.7064548031062396,
#   'travel': 0.7107242201812655,
#   'ethnicity': 0.7383378838865281,
#   'care': 0.7409207954296414,
#   'health': 0.7409913841526716,
#   'household': 0.7547838987425515,
#   'tenure': 0.7554873417703706,
#   'marital': 0.7680333114057313,
#   'economic': 0.7728123144041558,
#   'population': 0.7729294484892288,
#   'agemed': 0.778386988576941,
#   'religion': 0.779132370301063,
#   'hoursworked': 0.7956863654782135,
#   'welsh': 0.1},
#  'cornwall': {'health': 0.7267334628362303,
#   'care': 0.7382540548512049,
#   'travel': 0.7496458955110025,
#   'tenure': 0.7501048113453571,
#   'children': 0.7563982223107809,
#   'hoursworked': 0.7625568507913829,
#   'economic': 0.7649533761516898,
#   'household': 0.7662535939911475,
#   'population': 0.7791224282892418,
#   'marital': 0.7807814341323878,
#   'agemed': 0.7848546842858357,
#   'religion': 0.7860340125567704,
#   'ethnicity': 0.8008552797051893,
#   'welsh': 0.1},
#  'devon': {'travel': 0.7292653818218137,
#   'health': 0.7428718457601823,
#   'care': 0.7469381622745384,
#   'children': 0.7504175281537135,
#   'household': 0.7541176289285471,
#   'population': 0.7652796417063135,
#   'marital': 0.7660388174271738,
#   'hoursworked': 0.7692384579541056,
#   'tenure': 0.7702976074924947,
#   'economic': 0.7740227737663627,
#   'religion': 0.774714642577866,
#   'agemed': 0.7770881008319714,
#   'ethnicity': 0.788862558883486,
#   'welsh': 0.1},
#  'gloucestershire': {'travel': 0.722979666938066,
#   'care': 0.7344143276651761,
#   'health': 0.7387759175229859,
#   'children': 0.752340576647076,
#   'household': 0.7608169055811258,
#   'religion': 0.7612976901462729,
#   'tenure': 0.7625750839524041,
#   'hoursworked': 0.7647616412424111,
#   'marital': 0.7684024293158044,
#   'agemed': 0.7711585435358347,
#   'population': 0.7719709581334969,
#   'ethnicity': 0.7734768471478601,
#   'economic': 0.7829844415114343,
#   'welsh': 0.1},
#  'somerset': {'travel': 0.7171685801773549,
#   'care': 0.7178239692764857,
#   'children': 0.7349616363682776,
#   'health': 0.7365629992580355,
#   'tenure': 0.7512816128583831,
#   'household': 0.7522526475313699,
#   'marital': 0.7608345587821899,
#   'hoursworked': 0.7623092548640878,
#   'religion': 0.7644604022948299,
#   'economic': 0.7668662429757417,
#   'population': 0.770403560126914,
#   'ethnicity': 0.7800755597859901,
#   'agemed': 0.7802971774025768,
#   'welsh': 0.1},
#  'wiltshire': {'travel': 0.7141094572858216,
#   'children': 0.725690329288053,
#   'care': 0.7303534496683566,
#   'health': 0.7373502241480443,
#   'religion': 0.7399374455931138,
#   'ethnicity': 0.7462338847558749,
#   'economic': 0.7546036232939474,
#   'tenure': 0.7614806774587186,
#   'marital': 0.7627357228282164,
#   'household': 0.7633005836997291,
#   'agemed': 0.7647157502870257,
#   'hoursworked': 0.7680724896539765,
#   'population': 0.7729894471942711,
#   'welsh': 0.1},
#  'beds_bucks_and_herts': {'children': 0.7183163911550389,
#   'care': 0.7290181990703937,
#   'travel': 0.7326877059328389,
#   'tenure': 0.7489037408119529,
#   'health': 0.7513054660033515,
#   'household': 0.7621887729022097,
#   'economic': 0.7685261547516811,
#   'religion': 0.7690777215574853,
#   'marital': 0.770355999161596,
#   'hoursworked': 0.7717893655460398,
#   'ethnicity': 0.7777875768128506,
#   'agemed': 0.7779924647737168,
#   'population': 0.7867813542788713,
#   'welsh': 0.1},
#  'cambridgeshire': {'children': 0.7256767536339935,
#   'travel': 0.7331083322306481,
#   'health': 0.7338868119731307,
#   'care': 0.7370100337284607,
#   'tenure': 0.7393483412445239,
#   'agemed': 0.7482973733209226,
#   'household': 0.7599118913050555,
#   'population': 0.7652944995568571,
#   'ethnicity': 0.7669402933331715,
#   'religion': 0.7793594747274889,
#   'hoursworked': 0.7803179491686958,
#   'economic': 0.7833617269315414,
#   'marital': 0.7856359280034935,
#   'welsh': 0.1},
#  'essex': {'care': 0.732403475631235,
#   'travel': 0.7356865252580511,
#   'children': 0.7398902680167824,
#   'health': 0.7451264965407303,
#   'household': 0.7484218297816293,
#   'tenure': 0.7564696831881773,
#   'ethnicity': 0.7623199492425132,
#   'agemed': 0.7656773091901901,
#   'marital': 0.7679437342006148,
#   'hoursworked': 0.7759449577994537,
#   'population': 0.7827846607395726,
#   'religion': 0.7863320203409012,
#   'economic': 0.7892860435343068,
#   'welsh': 0.1},
#  'norfolk': {'care': 0.7165363862022887,
#   'tenure': 0.7250006950876821,
#   'health': 0.7251647293433136,
#   'children': 0.7251654189104303,
#   'travel': 0.7416963035224285,
#   'marital': 0.7498523293302684,
#   'household': 0.7547768409103954,
#   'hoursworked': 0.7575208903156586,
#   'agemed': 0.7617331806971723,
#   'religion': 0.7680945901643194,
#   'ethnicity': 0.7683085561440867,
#   'population': 0.7754047605107474,
#   'economic': 0.7763488832072181,
#   'welsh': 0.1},
#  'suffolk': {'care': 0.7097831137693351,
#   'children': 0.736099807548378,
#   'health': 0.7373193083356256,
#   'travel': 0.7421994720537737,
#   'tenure': 0.7529085880644065,
#   'household': 0.753501389690721,
#   'marital': 0.7619421166289196,
#   'hoursworked': 0.7627537027284029,
#   'economic': 0.7692484253077191,
#   'agemed': 0.7711905047625089,
#   'religion': 0.7713460613388494,
#   'population': 0.7776714322837274,
#   'ethnicity': 0.78666090295829,
#   'welsh': 0.1},
#  'berkshire': {'travel': 0.7184514281817511,
#   'tenure': 0.7339317019790688,
#   'children': 0.7359975908617676,
#   'care': 0.7435885751543999,
#   'household': 0.7508403238131188,
#   'health': 0.760015372615854,
#   'agemed': 0.7711498735373237,
#   'hoursworked': 0.7725367508319202,
#   'religion': 0.7768042289127812,
#   'marital': 0.7776158333430493,
#   'population': 0.778079705227856,
#   'economic': 0.77994915856432,
#   'ethnicity': 0.785986896541567,
#   'welsh': 0.1},
#  'dorset': {'travel': 0.7269337162255121,
#   'household': 0.729178557941947,
#   'children': 0.7295845539114829,
#   'health': 0.7351747717593703,
#   'tenure': 0.7359981558914613,
#   'care': 0.741828199036987,
#   'marital': 0.7689399309769686,
#   'hoursworked': 0.7750631258082373,
#   'ethnicity': 0.7765531360050911,
#   'population': 0.7776438841325437,
#   'religion': 0.7776787914037995,
#   'agemed': 0.7781795998880868,
#   'economic': 0.7891456044723588,
#   'welsh': 0.1},
#  'hampshire': {'travel': 0.7189278473984154,
#   'children': 0.7239686151369195,
#   'health': 0.7277592435631517,
#   'tenure': 0.7394096266302047,
#   'care': 0.7448422656871475,
#   'economic': 0.749495637632598,
#   'household': 0.7503156421480801,
#   'hoursworked': 0.760004432947266,
#   'marital': 0.763925433004158,
#   'ethnicity': 0.7665357157217387,
#   'religion': 0.7695162967780431,
#   'agemed': 0.773089757853107,
#   'population': 0.7776789626316164,
#   'welsh': 0.1},
#  'oxford': {'travel': 0.741962513831627,
#   'care': 0.7484195561568728,
#   'health': 0.7515671745559374,
#   'economic': 0.759552587498906,
#   'household': 0.7619772532393959,
#   'ethnicity': 0.7663293567493779,
#   'children': 0.7665716222846168,
#   'tenure': 0.7737921000012291,
#   'population': 0.7766283185776393,
#   'agemed': 0.7806960843669905,
#   'marital': 0.7853375973927409,
#   'religion': 0.7906714971767271,
#   'hoursworked': 0.7927973616551949,
#   'welsh': 0.1},
#  'kent': {'travel': 0.7145443749970892,
#   'health': 0.7155505284125688,
#   'tenure': 0.7175666181477494,
#   'care': 0.728275088162876,
#   'economic': 0.7397439130551023,
#   'children': 0.7401818781742535,
#   'agemed': 0.7498577754616429,
#   'hoursworked': 0.7574582075038058,
#   'household': 0.7609397324600371,
#   'religion': 0.7635468277349714,
#   'population': 0.7636488613684393,
#   'ethnicity': 0.7654787796074689,
#   'marital': 0.7752146052950145,
#   'welsh': 0.1},
#  'london': {'travel': 0.6824889601601172,
#   'tenure': 0.7001049006701664,
#   'children': 0.7114113514538657,
#   'household': 0.7146310635355723,
#   'agemed': 0.7227135255671565,
#   'ethnicity': 0.7265565003738381,
#   'health': 0.729188033934593,
#   'religion': 0.7314258641681838,
#   'marital': 0.7354281448896216,
#   'care': 0.7384264868044815,
#   'economic': 0.7436537216971639,
#   'population': 0.7440183564619935,
#   'hoursworked': 0.7651263240612036,
#   'welsh': 0.1},
#  'surrey': {'travel': 0.7097781140847292,
#   'health': 0.7314500070057334,
#   'household': 0.7344187256232411,
#   'children': 0.7441740294808927,
#   'agemed': 0.7497763531559986,
#   'care': 0.7550479517233137,
#   'tenure': 0.7558726617630639,
#   'economic': 0.7568860091178891,
#   'marital': 0.7707185746469998,
#   'population': 0.7717708399864859,
#   'hoursworked': 0.7722311606497111,
#   'religion': 0.7801864272318974,
#   'ethnicity': 0.7871918353816181,
#   'welsh': 0.1},
#  'sussex': {'travel': 0.704372899490556,
#   'children': 0.7185287183038218,
#   'health': 0.7203629574402339,
#   'household': 0.7330320182489374,
#   'tenure': 0.7352426668031401,
#   'care': 0.738745651352565,
#   'agemed': 0.7467035229712513,
#   'marital': 0.7537538735192304,
#   'economic': 0.7576096465762858,
#   'ethnicity': 0.7605294891626091,
#   'religion': 0.7633980149545593,
#   'population': 0.7759684342491564,
#   'hoursworked': 0.784312652103906,
#   'welsh': 0.1}}

# %%
# COLLECT 2021 LAs

las2021 = pd.read_csv('./pipeline_active/lookup/lad2015_lad2021.csv')
las2021 = [x for x in las2021['parent'] if str(x) != 'nan']
las2021 = list(set(las2021))

lads = []
for i in las2021:
    try:
        lads.append(json.load(open(f'/Users/theojolliffe/Documents/pipeline_active/final/json/place/{i}.json', 'rb')))
    except FileNotFoundError:
        print(i)
        # pass

# Remove tiny areas
# lads = [lad for lad in lads if (lad['name'] != 'City of London')&(lad['name'] != 'Isle of Scilly')]

for lad in lads:
    lad['data']['agemed']['value']['change']['all'] = lad['data']['agemed']['value']['2011']['all']-lad['data']['agemed']['value']['2001']['all']
    lad['data']['density']['value']['change']['all'] = lad['data']['density']['value']['2011']['all']-lad['data']['density']['value']['2001']['all']

# %%
options = pd.read_csv('./csv/lists/places_2020.csv')
areaType = pd.read_csv('../census-data-transformed/csv/lists/censusAreaLookup.csv')
typeLookup = {}
for i in areaType.index:
    typeLookup[areaType.iloc[i]['Name']]=areaType.iloc[i]['Group name']

areas = []
for i in options["code"]:
    try:
        areas.append(json.load(open(f'/Users/theojolliffe/Documents/pipeline_active/final/json/place/{i}.json', 'rb')))
    except FileNotFoundError:
#         print(i)
        pass

for area in areas:
    area['data']['agemed']['value']['change']['all'] = area['data']['agemed']['value']['2011']['all']-area['data']['agemed']['value']['2001']['all']
    area['data']['density']['value']['change']['all'] = area['data']['density']['value']['2011']['all']-area['data']['density']['value']['2001']['all']

# Seperate the areas by area type
regions = []
for i in areas:
    if i['type']=='rgn':
        regions.append(i)

countries = []
for i in areas:
    if (i['type']=='ew')|(i['type']=='ctry'):
        countries.append(i)

# %%
# Transform the welsh language data

for area in lads:
    if area['parents'][0]['name']=='Wales':
        x = area['data']['welsh']
        for y in x.keys():
            if y=='value':
                for z in x[y].keys():
                    if z=='change':
                        x[y][z]['NoWelsh'] = round(((x[y]['2011']['NoWelsh'] - x[y]['2001']['NoWelsh'])/x[y]['2001']['NoWelsh'])*100, 2)
                        x[y][z]['all'] = x[y][z]['AllOver3']
                        del x[y][z]['AllOver3']
                    else:
                        x[y][z]['NoWelsh'] = x[y][z]['AllOver3'] - x[y][z]['SpeaksWelsh']
                        x[y][z]['all'] = x[y][z]['AllOver3']
                        del x[y][z]['AllOver3']

for area in lads:
    if area['parents'][0]['name']=='Wales':
        x = area['data']['welsh']
        for y in x.keys():
            if y=='perc':
                for z in x[y].keys():
                    if z=='change':
                        x[y][z]['NoWelsh'] = x[y]['2011']['NoWelsh'] - x[y]['2001']['NoWelsh']
                        x[y][z]['all'] = x[y][z]['AllOver3']
                        del x[y][z]['AllOver3']
                        for w in x[y][z].keys():
                            x[y][z][w] = round(x[y]['2011'][w]-x[y]['2001'][w], 2)
                    else:
                        x[y][z]['NoWelsh'] = x[y][z]['AllOver3'] - x[y][z]['SpeaksWelsh']
                        x[y][z]['all'] = x[y][z]['AllOver3']
                        del x[y][z]['AllOver3']
                        for w in x[y][z].keys():
                            x[y][z][w] = round((x[y][z][w]/x[y][z]['all'])*100, 2)

for area in lads:
    if area['parents'][0]['name']!='Wales':
        x = area['data']['welsh']
        for y in x.keys():
            for z in x[y].keys():
                x[y][z]['all'] = 1
                del x[y][z]['AllOver3']
                for w in x[y][z].keys():
                    x[y][z][w] = x[y][z][w] = 1

# %%
for area in lads:
    x = area['data']
    for a in x.keys():
        for y in x[a].keys():
            for z in x[a][y].keys():
                for b in x[a][y][z].keys():
                    if math.isinf(x[a][y][z][b]):
                        x[a][y][z][b] = 'Inf'

# %%
# Transform the welsh language data

for area in countries:
    if area['name']=='Wales':
        x = area['data']['welsh']
        for y in x.keys():
            if y=='value':
                for z in x[y].keys():
                    if z=='change':
                        x[y][z]['NoWelsh'] = round(((x[y]['2011']['NoWelsh'] - x[y]['2001']['NoWelsh'])/x[y]['2001']['NoWelsh'])*100, 2)
                        x[y][z]['all'] = x[y][z]['AllOver3']
                        del x[y][z]['AllOver3']
                    else:
                        x[y][z]['NoWelsh'] = x[y][z]['AllOver3'] - x[y][z]['SpeaksWelsh']
                        x[y][z]['all'] = x[y][z]['AllOver3']
                        del x[y][z]['AllOver3']

for area in countries:
    if area['name']=='Wales':
        x = area['data']['welsh']
        for y in x.keys():
            if y=='perc':
                for z in x[y].keys():
                    if z=='change':
                        x[y][z]['NoWelsh'] = x[y]['2011']['NoWelsh'] - x[y]['2001']['NoWelsh']
                        x[y][z]['all'] = x[y][z]['AllOver3']
                        del x[y][z]['AllOver3']
                        for w in x[y][z].keys():
                            x[y][z][w] = round(x[y]['2011'][w]-x[y]['2001'][w], 2)
                    else:
                        x[y][z]['NoWelsh'] = x[y][z]['AllOver3'] - x[y][z]['SpeaksWelsh']
                        x[y][z]['all'] = x[y][z]['AllOver3']
                        del x[y][z]['AllOver3']
                        for w in x[y][z].keys():
                            x[y][z][w] = round((x[y][z][w]/x[y][z]['all'])*100, 2)
        
for area in countries:
    if area['name']!='Wales':
        x = area['data']['welsh']
        for y in x.keys():
            for z in x[y].keys():
                x[y][z]['all'] = 1
                del x[y][z]['AllOver3']
                for w in x[y][z].keys():
                    x[y][z][w] = x[y][z][w] = 1

# %%
nameChanges = {
    "Herefordshire, County of": "Herefordshire",
    "Bristol, City of": "Bristol",
    # "City of London": "the City of London",
    # "Isles of Scilly": "the Isles of Scilly",
    # "Isle of Anglesey": "the Isle of Anglesey",
    "Derbyshire Dales": "the Derbyshire Dales",
    "Kingston upon Hull, City of": "Kingston upon Hull",
    # "New Forest": "the New Forest"
}
for lad in lads:
    if lad['name'] in nameChanges.keys():
        lad['name'] = nameChanges[lad['name']]

# %%
simiDF = pd.read_csv('/Users/theojolliffe/Documents/correspondinglocalauthoritiesv3r.csv')

# %%
noOfLads = {"England": 309, "Wales": 22}
areaClassDF = pd.read_csv('../census-data-transformed/csv/lists/censusAreaLookup.csv')
areaClassDF.at[75, 'Code'] = "E06000058"
areaClassLU = {
    "1a1r": "affluent suburban area", "1b1r": "affluent rural area", 
    "1b2r": "growing rural area", "2a1r": "city", 
    "2b1r": "area", "3a2r": "remote area", 
    "3a1r": "agricultural area", "3b1r": "coastal area",
    "3b2r": "seaside  area",
    "4a1r": "urban area", "5a1r": "cosmopolitan area",
    "6a2r": "industrial area", "6a3r": "service economy area",
    "6a1r": "industrial area", "7a1r": "rural area",
    "7c2r": "affluent area", "7c1r": "affluent area",
    "8a1r": "multi-cultural area", "8a2r": "urban area",
    "8b1r": "suburban area", "8b2r": "suburban area",
}
areaClassSuperLU = {
    "1r": "affluent area",
    "2r": "urban area",
    "3r": "rural area",
    "4r": "multi-cultural area",
    "5r": "cosmopolitan area",
    "6r": "industrial area",
    "7r": "suburban area",
    "8r": "built up area",
}
gssLookup = {"E09": "London borough", "E08": "metropolitan district", "E07": "district", "E06": "unitary authority", "W06": "Welsh district"}
gssLookupShort = {"E09": "borough", "E08": "district", "E07": "district", "E06": "unitary authority", "W06": "district"}

# %%
bbcReg = pd.read_csv('/Users/theojolliffe/Downloads/bbc_regions.csv')
bbcRegLU = {}
for i in bbcReg.index:
    if bbcReg['areaCode'].iloc[i] in [lad['code'] for lad in lads]:
        bbcRegLU[bbcReg['areaCode'].iloc[i]] = bbcReg['bbc_online'].iloc[i]
bbcRegLU['E06000053'] = 'cornwall'
bbcRegLU['E06000060'] = 'beds_bucks_and_herts'
bbcRegLU['E09000001'] = 'london'
bbcRegLU['E07000150'] = 'northamptonshire'
bbcRegLU['E06000061'] = 'northamptonshire'
bbcRegLU['E06000062'] = 'northamptonshire'

regionsBBC = ['cumbria', 'lancashire', 'merseyside', 'manchester', 'tees', 'tyne_and_wear', 'Humberside', 'york_and_north_yorkshire', 'leeds_and_west_yorkshire', 'lincolnshire', 'south_yorkshire', 'birmingham_and_black_country', 'coventry_and_warwickshire', 'hereford_and_worcester', 'shropshire', 'stoke_and_staffordshire', 'derbyshire', 'leicester', 'northamptonshire', 'nottingham', 'bristol', 'cornwall', 'devon', 'gloucestershire', 'somerset', 'wiltshire', 'beds_bucks_and_herts', 'cambridgeshire', 'essex', 'norfolk', 'suffolk', 'berkshire', 'dorset', 'hampshire', 'oxford', 'kent', 'london', 'surrey', 'sussex']
bbcNames = {
     'derby': 'derbyshire', 
     'hereford and worcester': 'hereford_and_worcester',
     'tyne and wear': 'tyne_and_wear',
     'northampton': 'northamptonshire',
     'liverpool': 'merseyside',
     'coventry and warwickshire': 'coventry_and_warwickshire',
     'humberside': 'Humberside',
     'sheffield and south yorkshire': 'south_yorkshire',
     'hampshire & isle of wight': 'hampshire',
     'stoke and staffordshire': 'stoke_and_staffordshire',
     'york & north yorkshire': 'york_and_north_yorkshire',
     'birmingham and black country': 'birmingham_and_black_country',
     'beds, bucks and herts': 'beds_bucks_and_herts',
     'leeds and west yorkshire': 'leeds_and_west_yorkshire'
}
for i in bbcRegLU.keys():
    bbcRegLU[i] = bbcRegLU[i].lower()
    if bbcRegLU[i] not in regionsBBC:
        try:
            bbcRegLU[i] = bbcNames[bbcRegLU[i]]
        except:
            pass

# %%
tfidf = pd.read_csv('/Users/theojolliffe/Documents/Wayback BBC/BBCRegionalTFIDF.csv')
tfidf = tfidf.set_index('Unnamed: 0')
for i in tfidf.columns:
    for j in tfidf[i].index:
        tfidf[i].loc[j] = 1+100*tfidf[i].loc[j]
tfidfLU = {}
for i in regionsBBC:
    tfidfLU[i]=tfidf.loc[i].to_dict()

# %%
TFtopicLU = {
    'health': 'health',
    'racial': 'ethnicity',
    'population': 'population',
    'age': 'agemed',
    'work': 'economic',
    'commuter': 'travel',
    'housing': 'tenure'
}
TFtopicRev = dict((TFtopicLU[x],x) for x in TFtopicLU)

# %%
def this(lad):
    return[l for l in lads if l['name']==lad][0]

# %%
topics = [{1: 'population', 2: 'value', 3: 'all'}, 
          {1: 'density', 2: 'value', 3: 'all'},
          {1: 'agemed', 2: 'value', 3: 'all'},
          {1: 'welsh', 2: 'perc', 3: 'SpeaksWelsh'},
          {1: 'welsh', 2: 'perc', 3: 'all'},
          {1: 'care', 2: 'perc', 3: '20to49hoursWeek'},
          {1: 'care', 2: 'perc', 3: '40PlushoursWeek'},
          {1: 'children', 2: 'perc', 3: 'NoKids'},
          {1: 'children', 2: 'perc', 3: 'Kids'},
          {1: 'children', 2: 'perc', 3: 'NonDepKids'},
          {1: 'tenure', 2: 'perc', 3: 'rented_social'},
          {1: 'tenure', 2: 'perc', 3: 'rented_private'},
          {1: 'tenure', 2: 'perc', 3: 'owned'},
          {1: 'religion', 2: 'perc', 3: 'Hindu'},
          {1: 'religion', 2: 'perc', 3: 'Buddhist'},
          {1: 'religion', 2: 'perc', 3: 'Sikh'},
          {1: 'religion', 2: 'perc', 3: 'Jewish'},
          {1: 'religion', 2: 'perc', 3: 'Christian'},
          {1: 'religion', 2: 'perc', 3: 'Muslim'},
          {1: 'religion', 2: 'perc', 3: 'Noreligion'},
          {1: 'religion', 2: 'perc', 3: 'Otherreligion'},
          {1: 'household', 2: 'perc', 3: 'OnePerson'},
          {1: 'household', 2: 'perc', 3: 'Married'},
          {1: 'household', 2: 'perc', 3: 'LoneParent'},
          {1: 'household', 2: 'perc', 3: 'Cohabiting'},
          {1: 'health', 2: 'perc', 3: 'bad'},
          {1: 'health', 2: 'perc', 3: 'good'},
          {1: 'ethnicity', 2: 'perc', 3: 'black'},
          {1: 'ethnicity', 2: 'perc', 3: 'white'},
          {1: 'ethnicity', 2: 'perc', 3: 'asian'},
          {1: 'ethnicity', 2: 'perc', 3: 'other'},
          {1: 'ethnicity', 2: 'perc', 3: 'mixed'},
          {1: 'marital', 2: 'perc', 3: 'Married'},
          {1: 'marital', 2: 'perc', 3: 'Seperated'},
          {1: 'marital', 2: 'perc', 3: 'Single'},
          {1: 'hoursworked', 2: 'perc', 3: 'Female1-15'},
          {1: 'hoursworked', 2: 'perc', 3: 'Male1-15'},
          {1: 'hoursworked', 2: 'perc', 3: 'Female49plus'},
          {1: 'hoursworked', 2: 'perc', 3: 'Male49plus'},
          {1: 'economic', 2: 'perc', 3: 'employee'},
          {1: 'economic', 2: 'perc', 3: 'student'},
          {1: 'economic', 2: 'perc', 3: 'unemployed'},
          {1: 'economic', 2: 'perc', 3: 'self-employed'}]

ladCodes = []
for lad in lads:
    ladCodes.append(lad['code'])
    
    
df = pd.DataFrame(columns=
                  ['lad', '2001',  '2011',  'change', 'topic', 'parent'])
for j in range(len(topics)):
    df1 = pd.DataFrame(index=ladCodes, columns=
                      ['lad', '2001',  '2011',  'change', 'topic', 'parent'])
    for i in range(len(lads)):
        df1['lad'].iloc[i] = lads[i]['name']
        df1['2001'].iloc[i] = lads[i]['data'][topics[j][1]][topics[j][2]]['2001'][topics[j][3]]
        df1['2011'].iloc[i] = lads[i]['data'][topics[j][1]][topics[j][2]]['2011'][topics[j][3]]    
        df1['change'].iloc[i] = lads[i]['data'][topics[j][1]][topics[j][2]]['change'][topics[j][3]]
        df1['topic'].iloc[i] = topics[j][1]+"_"+topics[j][3]
        df1['parent'].iloc[i] = lads[i]['parents'][0]['name']
    df = pd.concat([df,df1])

# %%
df[df['topic'].map(lambda x: x.split("_")[1] == 'Sikh')].sort_values(['change'])
# Out:
#                          lad  2001   2011 change          topic  \
# E09000011          Greenwich  2.19   1.37  -0.82  religion_Sikh
# E09000025             Newham  2.83   2.08  -0.75  religion_Sikh
# E09000009             Ealing  8.51   7.91   -0.6  religion_Sikh
# E09000005              Brent  0.66   0.55  -0.11  religion_Sikh
# E09000031     Waltham Forest  0.57   0.47   -0.1  religion_Sikh
# ...                      ...   ...    ...    ...            ...
# E08000031      Wolverhampton  7.58   9.09   1.51  religion_Sikh
# E06000039             Slough  9.09  10.62   1.53  religion_Sikh
# E08000028           Sandwell  6.87   8.74   1.87  religion_Sikh
# E09000017         Hillingdon  4.55   6.65    2.1  religion_Sikh
# E07000135  Oadby and Wigston  4.16   6.52   2.36  religion_Sikh
#
#                    parent
# E09000011          London
# E09000025          London
# E09000009          London
# E09000005          London
# E09000031          London
# ...                   ...
# E08000031   West Midlands
# E06000039      South East
# E08000028   West Midlands
# E09000017          London
# E07000135  Leicestershire
#
# [331 rows x 6 columns]

# %%
df[ ( ( df['topic'].map(lambda x: x == 'religion_Sikh') ) & ( df['parent'] == 'South East' ) ) ].sort_values(['change'])
# Out:
#                               lad  2001   2011 change          topic  \
# E06000046           Isle of Wight  0.02   0.03   0.01  religion_Sikh
# E06000043       Brighton and Hove   0.1   0.13   0.03  religion_Sikh
# E06000037          West Berkshire   0.1   0.15   0.05  religion_Sikh
# E06000038                 Reading  0.55   0.61   0.06  religion_Sikh
# E06000044              Portsmouth  0.17   0.23   0.06  religion_Sikh
# E06000042           Milton Keynes  0.38   0.55   0.17  religion_Sikh
# E06000045             Southampton  1.29   1.47   0.18  religion_Sikh
# E06000036        Bracknell Forest  0.19    0.4   0.21  religion_Sikh
# E06000035                  Medway  1.22   1.46   0.24  religion_Sikh
# E06000041               Wokingham  0.97   1.32   0.35  religion_Sikh
# E06000060         Buckinghamshire  0.35   0.92   0.57  religion_Sikh
# E06000040  Windsor and Maidenhead  1.21   2.03   0.82  religion_Sikh
# E06000039                  Slough  9.09  10.62   1.53  religion_Sikh
#
#                parent
# E06000046  South East
# E06000043  South East
# E06000037  South East
# E06000038  South East
# E06000044  South East
# E06000042  South East
# E06000045  South East
# E06000036  South East
# E06000035  South East
# E06000041  South East
# E06000060  South East
# E06000040  South East
# E06000039  South East

# %%
# Create triple data for areas of closest proximity
geogTriples = []
for lad in lads:
    list1 = lad['bounds'][0]+lad['bounds'][1]
    for lad2 in lads:
        list2 = lad2['bounds'][0]+lad2['bounds'][1]
        listDif = [abs(list1[i]-list2[i]) for i in [0,1,2,3]]
        listDif.sort()
        if (sum(listDif[:3]) < 5) & (lad!=lad2):
            geogTriples.append([lad['name'], lad2['name'], ("near", round(sum(listDif[:3]), 2))])

# %%
subjectList = ["NoWelsh", "Male31-48", "Male16-30", "Female31-48", "Female16-30", "Widowed", "65andOver", "Other", "noCare", "MultiOther", "fair", "rent_free", "shared_ownership", "bicycle", "taxi", "moto", "female", "male", "inactive", "LoneNKids", "MultiStudents", '1to19hoursWeek', "Religionnotstated"]
topicList = ["age10yr", "travel"]

# Find each LAD local and national ranks and put in prioirity order
for thisLad in lads:

    if (areaClassDF[areaClassDF['Code']==thisLad['code']]['Subgroup code'].shape[0]>0):
        thisLad['classification'] = areaClassLU[areaClassDF[areaClassDF['Code']==thisLad['code']]['Subgroup code'].iloc[0]]
        thisLad['Subgroup code'] = areaClassDF[areaClassDF['Code']==thisLad['code']]['Subgroup code'].iloc[0]
    else:
        thisLad['classification'] = "unk"
    thisLad['gss'] = {}
    thisLad['gss']['short'] = gssLookupShort[thisLad['code'][:3]]
    thisLad['gss']['long'] = gssLookup[thisLad['code'][:3]]

    if thisLad['parents'][0]['type'] == "cty":
        thisLad['parents'] = thisLad['parents'][1:]

    # Empty array will be populted with ranks for each variable
    ranks = []

    # Filter areas with same parent
    sister_lads = []
    try:
        par_name = next(i for i in thisLad['parents'] if ([j for j in i.values()][2] == 'rgn'))['name']
    except:
        par_name = next(i for i in thisLad['parents'] if ([j for j in i.values()][2] == 'ctry'))['name']
        
    for thatLad in lads:
        try:
            if  par_name == next(i for i in thatLad['parents'] if ([j for j in i.values()][2] == 'rgn'))['name']:
                sister_lads.append(thatLad)
        except:
            if par_name=='Wales':
                sister_lads.append(thatLad)

    # Loop through the various data variables
    for a in thisLad['data']:
        if a not in topicList:
            if a in ['population', 'density', 'agemed']:
                b = 'value'
            else:
                b = 'perc'
            # Create nested object with localised rank
            thisLad['data'][a][b+"_rank_local"] = {}    
            for c in ['2001', '2011', 'change']:
                thisLad['data'][a][b+"_rank_local"][c] = {}
                for d in thisLad['data'][a][b][c]:
                    if d not in subjectList:
                        vari = thisLad['data'][a][b][c][d]

                        # Create sorted list of values from sister areas
                        group_values = []
                        for lad in sister_lads:
                            group_values.append(lad['data'][a][b][c][d])
                            group_values = [x if (type(x) == float) | (type(x) == int) else np.nan for x in group_values]
                        group_values.sort(reverse=True)

                        # Find index of value of area of interest
                        varRank = group_values.index(vari) + 1

                        # Convert bottom half rankings into negative values
                        if varRank>len(group_values)/2:
                            varRank = varRank-len(group_values)-1

                        # Find the variable's rank nationally
                        if thisLad['parents'][0]['name'] == "Wales":
                            natRank = [i for i in df[(df['parent']=="Wales")&(df['topic']==a+"_"+d)].sort_values(by=[c], ascending=False)['lad']].index(thisLad['name'])+1
                            if natRank > noOfLads["Wales"]/2:
                                natRank = natRank-noOfLads["Wales"]-1
                        else:
                            # Index + 1 gives toprank = 1
                            natRank = [i for i in df[(df['parent']!="Wales")&(df['topic']==a+"_"+d)].sort_values(by=[c], ascending=False)['lad']].index(thisLad['name'])+1
                            # If the rank is in the bottom half, ie, greater value than the middle rank
                            if natRank > noOfLads["England"]/2:
                                natRank = (natRank-noOfLads["England"])-1

                        thisLad['data'][a][b+"_rank_local"][c][d] = varRank
                        thisLad['data'][a][b+"_rank"][c][d] = natRank

                        # Append ranking data to original array
                        ranks.append({
                            'label': a+'_'+b+'_'+c+'_'+d, 
                            'locRank': varRank, 
                            'natRank': natRank, 
                            'value': vari
                        })

    # Sort in rank order
    ranks = sorted(ranks, key=lambda x: (abs(x['locRank']), -abs(x['value'])))
    thisLad["Priorities"] = ranks

# %%
# Find each LAD find statistically similar areas
for thisLad in lads:

    nearThis = [i for i in geogTriples if i[0]==thisLad['name']]
    simiThis = list(areaClassDF[areaClassDF['Subgroup code']==thisLad['Subgroup code']].Name)
    nearandsimi = [i for i in nearThis if i[1] in simiThis]
    nearandsimi = sorted(nearandsimi, reverse=False, key=lambda x: x[2])

    try:
        thisLad['similar'] = [
            {'code': simiDF[simiDF['Code']==thisLad['code']]['Code.1'].iloc[0], 'name': simiDF[simiDF['Code']==thisLad['code']]['Name.1'].iloc[0]},
            {'code': simiDF[simiDF['Code']==thisLad['code']]['Code.2'].iloc[0], 'name': simiDF[simiDF['Code']==thisLad['code']]['Name.2'].iloc[0]},
            {'code': simiDF[simiDF['Code']==thisLad['code']]['Code.3'].iloc[0], 'name': simiDF[simiDF['Code']==thisLad['code']]['Name.3'].iloc[0]}
        ]
    except:
        thisLad['similar'] = [
            {'code': this(nearandsimi[0][1])['code'], 'name': nearandsimi[0][1]},
            {'code': this(nearandsimi[1][1])['code'], 'name': nearandsimi[1][1]}
        ]

# %%
# Increase a positive or negative number by 1 (-1 => -2)
def incmag(x):
    return int((abs(x)+1) * (x/abs(x)))

# %%
df = pd.DataFrame(columns=
                  ['lad', '2001',  '2011',  'change', 'natRank', 'localRank', 'topic', 'parent'])
for j in range(len(topics)):
    df1 = pd.DataFrame(index=ladCodes, columns=
                      ['lad', '2001',  '2011',  'change', 'natRank', 'localRank', 'topic', 'parent'])
    for i in range(len(lads)):
        df1['lad'].iloc[i] = lads[i]['name']
        df1['2001'].iloc[i] = lads[i]['data'][topics[j][1]][topics[j][2]]['2001'][topics[j][3]]
        df1['2011'].iloc[i] = lads[i]['data'][topics[j][1]][topics[j][2]]['2011'][topics[j][3]]    
        df1['change'].iloc[i] = lads[i]['data'][topics[j][1]][topics[j][2]]['change'][topics[j][3]]
        df1['natRank'].iloc[i] = lads[i]['data'][topics[j][1]][topics[j][2]+"_rank"]['change'][topics[j][3]]    
        df1['localRank'].iloc[i] = lads[i]['data'][topics[j][1]][topics[j][2]+"_rank_local"]['change'][topics[j][3]]    
        df1['topic'].iloc[i] = topics[j][1]+"_"+topics[j][3]
        try:
            df1['parent'].iloc[i] = next(k for k in lads[i]['parents'] if ([j for j in k.values()][2] == 'rgn'))['name']
        except:
            df1['parent'].iloc[i] = next(k for k in lads[i]['parents'] if ([j for j in k.values()][2] == 'ctry'))['name']

    df = pd.concat([df,df1])

for topic in topics:
    for lad in lads:
        
        # Find the areas that this area has overtaken
        v2001 = lad['data'][topic[1]][topic[2]]['2001'][topic[3]]
        v2011 = lad['data'][topic[1]][topic[2]]['2011'][topic[3]]
        if thisLad['parents'][0]['name'] == "Wales":
            dfT = df[(df['parent']=="Wales")&(df['topic']==topic[1]+"_"+topic[3])&(df['2001']>v2001)&(df['2011']<v2011)]
        else:
            dfT = df[(df['parent']!="Wales")&(df['topic']==topic[1]+"_"+topic[3])&(df['2001']>v2001)&(df['2011']<v2011)]

        obje = []
        for i in range(dfT.shape[0]):
            obje.append(dfT.iloc[i]['lad'])
        
        if 'overtake' not in lad['data'][topic[1]][topic[2]+'_rank'].keys():
            lad['data'][topic[1]][topic[2]+'_rank']['overtake'] = {}
        lad['data'][topic[1]][topic[2]+"_rank"]['overtake'][topic[3]] = obje

        # Find areas within the region that this area has overtaken
        reg = lad['parents'][0]['name']
        dfTr = df[(df['topic']==topic[1]+"_"+topic[3])&(df['2001']>v2001)&(df['2011']<v2011)&(df['parent']==reg)]
        objeR = []
        for i in range(dfTr.shape[0]):
            objeR.append(dfTr.iloc[i]['lad'])
        if 'overtake' not in lad['data'][topic[1]][topic[2]+'_rank_local'].keys():
            lad['data'][topic[1]][topic[2]+'_rank_local']['overtake'] = {}
        lad['data'][topic[1]][topic[2]+"_rank_local"]['overtake'][topic[3]] = objeR
        
        dfReg = df[(df['topic']==topic[1]+"_"+topic[3])&(df['parent']==reg)]
        rank2001 = sorted(dfReg['2001'], reverse=True).index(v2001)+1
        if rank2001 > 168:
            rank2001 = rank2001-336-1
        if '2001' not in lad['data'][topic[1]][topic[2]+'_rank_local'].keys():
            lad['data'][topic[1]][topic[2]+'_rank_local']['2001'] = {}
        lad['data'][topic[1]][topic[2]+'_rank_local']['2001'][topic[3]] = rank2001

        # Find the area immediatly above or below
        above = lad['data'][topic[1]][topic[2]+'_rank_local']['2011'][topic[3]]-2
        below = lad['data'][topic[1]][topic[2]+'_rank_local']['2011'][topic[3]]
        if below<0:
            above = lad['data'][topic[1]][topic[2]+'_rank_local']['2011'][topic[3]]-1
            below = lad['data'][topic[1]][topic[2]+'_rank_local']['2011'][topic[3]]+1
            
        name_above = df[(df['parent']==reg)&(df['topic']==topic[1]+"_"+topic[3])].sort_values('2011', ascending=False).iloc[above]['lad']
        name_below = df[(df['parent']==reg)&(df['topic']==topic[1]+"_"+topic[3])].sort_values('2011', ascending=False).iloc[below]['lad']

        area_above = {'name': name_above,
                         'value': df[(df['lad']==name_above)&(df['topic']==topic[1]+"_"+topic[3])]['2011'].iloc[0]}
        area_below = {'name': name_below,
                          'value': df[(df['lad']==name_below)&(df['topic']==topic[1]+"_"+topic[3])]['2011'].iloc[0]}


        if 'above_below' not in lad['data'][topic[1]][topic[2]+'_rank_local'].keys():
            lad['data'][topic[1]][topic[2]+'_rank_local']['above_below'] = {}

        if topic[3] not in lad['data'][topic[1]][topic[2]+'_rank_local']['above_below'].keys():
            lad['data'][topic[1]][topic[2]+'_rank_local']['above_below'][topic[3]] = {}
        
        lad['data'][topic[1]][topic[2]+'_rank_local']['above_below'][topic[3]]["above"] = area_above
        lad['data'][topic[1]][topic[2]+'_rank_local']['above_below'][topic[3]]["below"] = area_below
            
        # Add top and bottom three biggest movers for each subject to every area
        if thisLad['parents'][0]['name'] == "Wales":
            df_topic = df[(df['parent']=="Wales")&(df['topic']==topic[1]+"_"+topic[3])&(abs(df['natRank'])<4)]
        else:
            df_topic = df[(df['parent']!="Wales")&(df['topic']==topic[1]+"_"+topic[3])&(abs(df['natRank'])<4)]

        ob = {}
        for index, row in df_topic.iterrows():
            ob[int(row['natRank'])] = {'name': row['lad'], 2001: row['2001'], 2011: row['2011'], 'change': row['change']}
        if 'top_bottom' not in lad['data'][topic[1]][topic[2]+'_rank'].keys():
            lad['data'][topic[1]][topic[2]+'_rank']['top_bottom'] = {}
        lad['data'][topic[1]][topic[2]+'_rank']['top_bottom'][topic[3]]=ob

        # Add top and bottom three biggest movers for each subject to every area (regional)
        df_topicReg = df[(df['topic']==topic[1]+"_"+topic[3])&(abs(df['localRank'])<4)&(df['parent']==reg)]

        ob = {}
        for index, row in df_topicReg.iterrows():
            if int(row['localRank']) in ob.keys():
                if int(row['localRank'])+1 in ob.keys():
                    ob[int(row['localRank'])+2] = {'name': row['lad'], 2001: row['2001'], 2011: row['2011'], 'change': row['change']}
                else:
                    ob[int(row['localRank'])+1] = {'name': row['lad'], 2001: row['2001'], 2011: row['2011'], 'change': row['change']}
            else:
                ob[int(row['localRank'])] = {'name': row['lad'], 2001: row['2001'], 2011: row['2011'], 'change': row['change']}
        if 'top_bottom' not in lad['data'][topic[1]][topic[2]+'_rank_local'].keys():
            lad['data'][topic[1]][topic[2]+'_rank_local']['top_bottom'] = {}
        lad['data'][topic[1]][topic[2]+'_rank_local']['top_bottom'][topic[3]]=ob

# %%
df_topicReg = df[(df['topic']=='household_OnePerson')&(abs(df['localRank'])<4)&(df['parent']=="South East")]
ob = {}
for index, row in df_topicReg.iterrows():
    if int(row['localRank']) in ob.keys():
        if int(row['localRank'])+1 in ob.keys():
            ob[int(row['localRank'])+2] = {'name': row['lad'], 2001: row['2001'], 2011: row['2011'], 'change': row['change']}
        else:
            ob[int(row['localRank'])+1] = {'name': row['lad'], 2001: row['2001'], 2011: row['2011'], 'change': row['change']}
    else:
        ob[int(row['localRank'])] = {'name': row['lad'], 2001: row['2001'], 2011: row['2011'], 'change': row['change']}

ob
# Out:
# {-1: {'name': 'Brighton and Hove', 2001: 39.35, 2011: 36.44, 'change': -2.91},
#  2: {'name': 'Vale of White Horse', 2001: 24.18, 2011: 26.44, 'change': 2.26},
#  -2: {'name': 'Guildford', 2001: 29.07, 2011: 26.72, 'change': -2.35},
#  1: {'name': 'Folkestone and Hythe', 2001: 30.7, 2011: 33.33, 'change': 2.63},
#  3: {'name': 'Havant', 2001: 26.56, 2011: 28.6, 'change': 2.04}}

# %%
df[(df['topic']=='household_OnePerson')&(abs(df['localRank'])<5)&(df['parent']=="South East")]
# Out:
#                             lad   2001   2011 change natRank localRank  \
# E07000217                Woking  28.29   26.6  -1.69     -36        -4
# E07000211  Reigate and Banstead  29.05  27.36  -1.69     -37        -4
# E06000043     Brighton and Hove  39.35  36.44  -2.91     -25        -1
# E07000180   Vale of White Horse  24.18  26.44   2.26      33         2
# E07000209             Guildford  29.07  26.72  -2.35     -31        -2
# E07000112  Folkestone and Hythe   30.7  33.33   2.63      19         1
# E07000088               Gosport  27.95  29.82   1.87      54         4
# E07000090                Havant  26.56   28.6   2.04      44         3
#
#                          topic      parent
# E07000217  household_OnePerson  South East
# E07000211  household_OnePerson  South East
# E06000043  household_OnePerson  South East
# E07000180  household_OnePerson  South East
# E07000209  household_OnePerson  South East
# E07000112  household_OnePerson  South East
# E07000088  household_OnePerson  South East
# E07000090  household_OnePerson  South East

# %%
df_topicReg
# Out:
#                       lad   2001   2011 change natRank localRank  \
# E07000120        Hyndburn  51.79  45.82  -5.97     -17        -2
# E07000123         Preston  47.76  41.48  -6.28      -6        -1
# E07000031  South Lakeland  56.48  54.09  -2.39      44         2
# E08000009        Trafford  51.04  48.82  -2.22      41         1
# E08000003      Manchester   32.1  29.71  -2.39      46         2
#
#                      topic      parent
# E07000120  marital_Married  North West
# E07000123  marital_Married  North West
# E07000031  marital_Married  North West
# E08000009  marital_Married  North West
# E08000003  marital_Married  North West

# %%
lads_copy = lads.copy()

# %%
def moveethrel(li):
    li_temp = [i['label'].split("_")[0] for i in li]
    print('li_temp', li_temp)
    if li_temp[1] in ['religion', 'ethnicity']:

        topic = next(i for i in li_temp[2:] if i not in ['religion', 'ethnicity'])
        indi = li_temp.index(topic)
        li.insert(1, li.pop(indi))

        print('indi', li)

    return li

# %%
lads = lads_copy.copy()
# Filter out priority list by subject
for lad in lads:
    subjectList = ["Male31-48", "Male16-30", "Female31-48", "Female16-30", "Widowed", "65andOver", "Other", "noCare", "MultiOther", "fair", "rent_free", "shared_ownership", "bicycle", "taxi", "moto", "other", "female", "male", "inactive", "LoneNKids", "MultiStudents", "Religionnotstated"]
    priorities = []
    priorities2011 = []
    for rank in lad['Priorities']:
        s=rank['label'].split("_")
        if len(s)>4:
            s[3] = s[3] + "_" + s[4]
        if ((s[2] == "change") & (s[3] not in subjectList) & (((s[0]=="household")&(s[3]=="Married")) is False)):
            if (s[0]=='welsh') & (lad['parents'][0]['name'] != 'Wales'):
                pass
            else:
                rank['2011'] = [i for i in lad['Priorities'] if i['label']==s[0]+'_'+s[1]+'_2011_'+s[3]][0]['value']
                rank['perccha'] = round(100*((rank['value']+0.001)/([i for i in lad['Priorities'] if i['label']==s[0]+'_'+s[1]+'_2001_'+s[3]][0]['value']+0.001)),2)
                priorities.append(rank)
        if (s[2]!="change"):
            priorities2011.append(rank)
    lad['pri'] = priorities
    lad['pri2011'] = priorities2011

sign = lambda x: math.copysign(1, x)

for thisLad in lads:

    # Find nearby area
    nearbyArea = [i for i in geogTriples if i[0]==thisLad['name']]
    nearbyArea = [i for i in nearbyArea if this(i[1])['parents'][1]['name'] == thisLad['parents'][1]['name']]

    nearbyArea = sorted(nearbyArea, key=lambda x: x[2][1])

    #Find differences in data
    if (thisLad['parents'][0]['name']=='Wales'):
        region=[i for i in countries if i['name']=="Wales"][0]
        country=[i for i in countries if i['name']=="Wales"][0]
    else:
        region=[i for i in regions if i['name']==thisLad['parents'][0]['name']][0]
        country=[i for i in countries if i['name']==thisLad['parents'][1]['name']][0]

    def reg(i):
        s=i['label'].split("_")
        if len(s)>4:
            s[3] = s[3] + "_" + s[4]    
        try:
            return region['data'][s[0]][s[1]][s[2]][s[3]]
        except:
            if (thisLad['parents'][0]['name']=='Wales'):
                return country['data'][s[0]][s[1]][s[2]][s[3]]
            else:
                return 0

    regDiff = [(i, {'val': reg(i), 'dif': i['value']-reg(i)}) for i in thisLad['pri']]
    regDiff = sorted(regDiff, reverse=True, key=lambda x: abs(x[1]['dif']))

    def regpc(i):
        s=i['label'].split("_")
        if len(s)>4:
            s[3] = s[3] + "_" + s[4]    
        try:
            return round(100*( (region['data'][s[0]]['perc']['change'][s[3]] + 0.001) / (region['data'][s[0]]['perc']['2001'][s[3]] + 0.001) ), 2)
        except:
            if (thisLad['parents'][0]['name']=='Wales'):
                try:
                    return round(100*( (country['data'][s[0]]['perc']['change'][s[3]] + 0.001) / (country['data'][s[0]]['perc']['2001'][s[3]] + 0.001) ), 2)
                except:
                    return 0
            else:
                return 0

    regDiffPerc = [(i, {'val': reg(i), 'dif': i['perccha']-regpc(i)}) for i in thisLad['pri']]
    regDiffPerc = sorted(regDiff, reverse=True, key=lambda x: abs(x[1]['dif']))

    # Pick out the top stories for ethnicity based on biggest percentage change 
    try:
        ethStory = next(filter(lambda x: x[0]['label'].split("_")[0] == 'ethnicity', regDiffPerc))[0]
    except:
        pass

    # Pick out the top stories for religion based on biggest percentage change 
    try:
        relStory = next(filter(lambda x: x[0]['label'].split("_")[0] == 'religion', regDiffPerc))[0]
    except:
        pass

     # remove all the other cases of ethnicity 
    thisLad['pri'] = [i for i in thisLad['pri'] if i['label'].split("_")[0]!='ethnicity']

    if ethStory['value']>0.2:
        ethStory = [{**ethStory, **{'type':['ethrel']}}]
    else:
        ethStory = []

    # remove all the other cases of religion 
    thisLad['pri'] = [i for i in thisLad['pri'] if i['label'].split("_")[0]!='religion']

    if relStory['value']>0.2:
        relStory = [{**relStory, **{'type':['ethrel']}}]
    else:
        relStory = []

    def cou(i):
        s=i['label'].split("_")
        if len(s)>4:
            s[3] = s[3] + "_" + s[4]
        return country['data'][s[0]][s[1]][s[2]][s[3]]
    couDiff = [(i, {'val': cou(i), 'dif': i['value']-cou(i)}) for i in thisLad['pri']]
    couDiff = sorted(couDiff, reverse=True, key=lambda x: abs(x[1]['dif']))
    
    try:
        nearbyAreaData = {}
        nearbyAreaData['name'] = nearbyArea[0][1]
        nearbyAreaData['data'] = [lad for lad in lads if lad['name']==nearbyArea[0][1]][0]['data']
    except:
        print("Nearby data not found for:: ", thisLad['name'])
        nearbyAreaData = []
        
    try:
        similarData = {}
        if (nearbyArea[0][1]!=thisLad['similar'][0]['name']):
            try:
                similarData['name'] = thisLad['similar'][0]['name']
                similarData['data'] = [lad for lad in lads if lad['name']==thisLad['similar'][0]['name']][0]['data']
            except:
                try:
                    similarData['name'] = thisLad['similar'][1]['name']
                    similarData['data'] = [lad for lad in lads if lad['name']==thisLad['similar'][1]['name']][0]['data']
                except:
                    similarData['name'] = thisLad['similar'][2]['name']
                    similarData['data'] = [lad for lad in lads if lad['name']==thisLad['similar'][2]['name']][0]['data']
        else:
            try:
                similarData['name'] = thisLad['similar'][1]['name']
                similarData['data'] = [lad for lad in lads if lad['name']==thisLad['similar'][1]['name']][0]['data']
            except:
                similarData['name'] = thisLad['similar'][2]['name']
                similarData['data'] = [lad for lad in lads if lad['name']==thisLad['similar'][2]['name']][0]['data']

    except:
        print("Similar data not found for:: ", thisLad['name'])
        similarData = []

    def simi(i):
        s=i['label'].split("_")
        if len(s)>4:
            s[3] = s[3] + "_" + s[4]
        return similarData['data'][s[0]][s[1]][s[2]][s[3]]
    if len(similarData)>0:
        simiDiff = [(i, {'val': simi(i), 'dif': i['value']-simi(i)}) for i in thisLad['pri']]
        simiDiff = sorted(simiDiff, reverse=True, key=lambda x: abs(x[1]['dif']))

    def near(i):
        s=i['label'].split("_")
        if len(s)>4:
            s[3] = s[3] + "_" + s[4]
        return nearbyAreaData['data'][s[0]][s[1]][s[2]][s[3]]
    if len(nearbyAreaData)>0:
        nearDiff = [(i, {'val': near(i), 'dif': i['value']-near(i)}) for i in thisLad['pri']]
        nearDiff = sorted(nearDiff, reverse=True, key=lambda x: abs(x[1]['dif']))

    nearTops = sorted([(lad['name'], lad['pri'][0]) for lad in lads if lad['name'] in [i[1] for i in nearbyArea if i[0]==thisLad['name']]], key=lambda x: abs(x[1]['locRank']))

    ageBandChange = sorted([(i, thisLad['data']['age10yr']['value']['2011'][i]-thisLad['data']['age10yr']['value']['2001'][i]) for i in thisLad['data']['age10yr']['value']['2001'].keys()], 
           reverse=True, key=lambda x: x[1])

    equalAgeChange = [lad['name'] for 
     lad in lads if (lad['parents'][0]['name'] == thisLad['parents'][0]['name']) 
     & (lad['data']['agemed']['value']['change']['all']==thisLad['data']['agemed']['value']['change']['all'])]
    len(equalAgeChange)


    # Find and refine stories
    stories = []
    stories = stories+relStory
    stories = stories+ethStory
    if (thisLad['parents'][0]['name']=='Wales'):
        stories=stories+[{**i, **{'type':['welsh']}} for i in thisLad['pri'] if i['label'] == 'welsh_perc_change_SpeaksWelsh']
    stories=stories+[{**i, **{'type':['pop']}} for i in thisLad['pri'] if i['label'] == 'population_value_change_all']
    stories=stories+[{**i, **{'type':['size']}} for i in thisLad['pri'] if ((abs(i['value'])/abs(i['2011'])>0.2)&(abs(i['value']) > 1))]
    stories=stories+[{**i, **{'type':['locRank']}} for i in thisLad['pri'] if (abs(i['locRank']) < 4)&(abs(i['value']) > 0.5)]
    stories=stories+[{**i, **{'type':['natRank']}} for i in thisLad['pri'] if (abs(i['natRank']) < 4)&(abs(i['value']) > 0.5)]
    stories=stories+[{**i[0], **{'type':['couBuck']}} for i in couDiff if ((abs(i[1]['val'])>0.5) & (abs(i[0]['value'])>0.5) & (sign(i[1]['val'])!=sign(i[0]['value'])))]
    stories=stories+[{**i[0], **{'type':['regBuck']}} for i in regDiff if ((abs(i[1]['val'])>0.5) & (abs(i[0]['value'])>0.5) & (sign(i[1]['val'])!=sign(i[0]['value'])))]
    stories=stories+[{**i[0], **{'type':['nearBuck']}} for i in nearDiff if ((abs(i[1]['val'])>0.8) & (abs(i[0]['value'])>0.8) & (sign(i[1]['val'])!=sign(i[0]['value'])))]
    stories=stories+[{**i[0], **{'type':['simiBuck']}} for i in simiDiff if ((abs(i[1]['val'])>0.8) & (abs(i[0]['value'])>0.8) & (sign(i[1]['val'])!=sign(i[0]['value'])))]
    stories=stories+[{**i[0], **{'type':['couDiff']}} for i in couDiff if ((abs(i[1]['dif'])>2) & (sign(i[1]['val'])==sign(i[0]['value'])))]
    stories=stories+[{**i[0], **{'type':['regDiff']}} for i in regDiff if ((abs(i[1]['dif'])>2) & (sign(i[1]['val'])==sign(i[0]['value'])))]
    stories=stories+[{**i[0], **{'type':['nearDiff']}} for i in nearDiff if ((abs(i[1]['dif'])>2) & (sign(i[1]['val'])==sign(i[0]['value'])))]
    stories=stories+[{**i[0], **{'type':['simiDiff']}} for i in simiDiff if ((abs(i[1]['dif'])>2) & (sign(i[1]['val'])==sign(i[0]['value'])))]
    seen = set()
    uniq = [item['label'] for item in stories if item['label'] in seen or seen.add(item['label'])]
    listofdoubles = [[i for i in stories if i['label'] == uniqI] for uniqI in uniq]
    multi = [{**double[0], **{'type': [item for sublist in [i['type'] for i in double] for item in sublist]}} for double in listofdoubles]
    stories = [item for item in stories if item['label'] not in [i['label'] for i in multi]]
    stories=stories+multi

    storiesRefined =[]
    notInc = ['density', 'age10yr', 'travel']
    for i in stories:
        if i['label'].split("_")[0] not in notInc:
            storiesRefined.append(i)
            notInc.append(i['label'].split("_")[0])

    if (thisLad['code'][0]!='W'):
        storiesRefined = sorted(storiesRefined, key=lambda x: ((topicScoresOrder[bbcRegLU[thisLad['code']]][x['label'].split('_')[0]])*(1/(1+abs(x['value'])))))
    else:
        storiesRefined = sorted(storiesRefined, key=lambda x: 1/(1+abs(x['value'])))

    storiesRefined = sorted(storiesRefined, reverse=True, key=lambda x: abs(x['locRank'])<4)
    storiesRefined = sorted(storiesRefined, reverse=True, key=lambda x: abs(x['natRank'])<4)
    storiesRefined = sorted(storiesRefined, reverse=True, key=lambda x: abs(x['locRank'])<3)
    storiesRefined = sorted(storiesRefined, reverse=True, key=lambda x: abs(x['natRank'])<3)
    storiesRefined = sorted(storiesRefined, reverse=True, key=lambda x: x['type']=='regBuck')
    storiesRefined = sorted(storiesRefined, reverse=True, key=lambda x: x['type']=='couBuck')
    # storiesRefined = storiesRefined[:6]
    storiesRefined = sorted(storiesRefined, reverse=True, key=lambda x: x['label']=='welsh_perc_change_SpeaksWelsh')
    storiesRefined = sorted(storiesRefined, reverse=True, key=lambda x: x['label']=='agemed_value_change_all')
    storiesRefined = sorted(storiesRefined, reverse=True, key=lambda x: x['label']=='population_value_change_all')

    
    # Create a varibale 'hiRank' which holds the index of a top 5 rank at the national or reginal level to be used for an overtake story
    hiRank ={}
    hiRankNat = []
    for i in storiesRefined:
        if i['label'] not in ['population_value_change_all', 'agemed_value_change_all']:
            s=i['label'].split("_")
            if len(s)>4:
                s[3] = s[3] + "_" + s[4]
            if thisLad['data'][s[0]][s[1]+"_rank"]['2011'][s[3]]!=thisLad['data'][s[0]][s[1]+"_rank"]['2001'][s[3]]:
                hiRankNat.append(abs(thisLad['data'][s[0]][s[1]+"_rank"]['2011'][s[3]]))
            else:
                hiRankNat.append(100)
        else:
            hiRankNat.append(100)

    hiRankReg = []
    for i in storiesRefined:
        if i['label'] not in ['population_value_change_all', 'agemed_value_change_all']:
            s=i['label'].split("_")
            if len(s)>4:
                s[3] = s[3] + "_" + s[4]
            if thisLad['data'][s[0]][s[1]+"_rank_local"]['2011'][s[3]]!=thisLad['data'][s[0]][s[1]+"_rank_local"]['2001'][s[3]]:
                hiRankReg.append(abs(thisLad['data'][s[0]][s[1]+"_rank_local"]['2011'][s[3]]))
            else:
                hiRankReg.append(100)
        else:
            hiRankReg.append(100)
            
    if min(hiRankNat)<5:
        hiRank['rankIn'] = hiRankNat.index(min(hiRankNat))
        hiRank['type'] = 'nat'
    elif min(hiRankReg)<5:
        hiRank['rankIn'] = hiRankReg.index(min(hiRankReg))
        hiRank['type'] = 'reg'
    elif min(hiRankNat)<10:
        hiRank['rankIn'] = hiRankNat.index(min(hiRankNat))
        hiRank['type'] = 'nat'
    else:
        hiRank['rankIn'] = "None"
        hiRank['type'] = "None"

    ageBandChange= [i for i in ageBandChange if i[0]!='all']
    ageBandPos = sorted([i for i in ageBandChange if i[1]>0], reverse=True, key=lambda x: abs(x[1]))
    ageBandNeg = sorted([i for i in ageBandChange if i[1]<0], reverse=True, key=lambda x: abs(x[1]))

    storiesRefined = moveethrel(storiesRefined)

    # Add data to object
    thisLad['hiRank']=hiRank
    thisLad['stories'] = storiesRefined
    thisLad['similar'] = similarData
    thisLad['nearbyArea'] = {}
    thisLad['nearbyArea']['triples'] = nearbyArea
    thisLad['nearbyArea']['nearTops'] = nearTops
    thisLad['nearbyArea']['nearTops'] = nearbyAreaData
    thisLad['differences'] = {}
    thisLad['differences']['country'] = couDiff
    thisLad['differences']['region'] = regDiff
    thisLad['differences']['near'] = nearDiff
    thisLad['data']['age10yr']['absChange'] = {}
    thisLad['data']['age10yr']['absChange']['pos'] = ageBandPos
    thisLad['data']['age10yr']['absChange']['neg'] = ageBandNeg
    thisLad['data']['agemed']['value_rank_local']['equalAgeChange]'] = len(equalAgeChange)
# Out:
# li_temp ['population', 'marital', 'tenure', 'hoursworked', 'health', 'economic', 'ethnicity', 'household', 'children']
# li_temp ['population', 'marital', 'health', 'household', 'economic', 'ethnicity', 'tenure', 'children', 'hoursworked', 'religion']
# li_temp ['population', 'religion', 'marital', 'economic', 'hoursworked', 'tenure', 'health', 'household', 'ethnicity', 'children']
# indi [{'label': 'population_value_change_all', 'locRank': 4, 'natRank': 23, 'value': 15.35, '2011': 88270.0, 'perccha': 0.02, 'type': ['pop', 'couDiff', 'regDiff']}, {'label': 'marital_perc_change_Married', 'locRank': -2, 'natRank': -13, 'value': -6.09, '2011': 53.47, 'perccha': -10.22, 'type': ['locRank', 'couDiff']}, {'label': 'religion_perc_change_Christian', 'locRank': 2, 'natRank': 44, 'value': -10.24, '2011': 72.35, 'perccha': -12.4, 'type': ['regDiff']}, {'label': 'economic_perc_change_unemployed', 'locRank': 1, 'natRank': 25, 'value': 1.74, '2011': 3.96, 'perccha': 78.39, 'type': ['size', 'locRank']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': -2, 'natRank': -26, 'value': 0.79, '2011': 2.28, 'perccha': 53.05, 'type': ['locRank']}, {'label': 'tenure_perc_change_rented_private', 'locRank': 13, 'natRank': 141, 'value': 6.26, '2011': 12.65, 'perccha': 97.97, 'type': ['size', 'nearDiff']}, {'label': 'health_perc_change_bad', 'locRank': 12, 'natRank': 146, 'value': -3.21, '2011': 6.1, 'perccha': -34.46, 'type': ['size']}, {'label': 'household_perc_change_Cohabiting', 'locRank': 4, 'natRank': 23, 'value': 2.48, '2011': 10.89, 'perccha': 29.5, 'type': ['size']}, {'label': 'ethnicity_perc_change_white', 'locRank': 11, 'natRank': 57, 'value': -1.0, '2011': 97.85, 'perccha': -1.01, 'type': ['regDiff']}, {'label': 'children_perc_change_NoKids', 'locRank': -6, 'natRank': -83, 'value': -0.74, '2011': 64.88, 'perccha': -1.13, 'type': ['regBuck']}]
# li_temp ['population', 'agemed', 'children', 'religion', 'tenure', 'health', 'hoursworked', 'economic', 'household', 'ethnicity']
# li_temp ['population', 'agemed', 'tenure', 'ethnicity', 'religion', 'hoursworked', 'household', 'children', 'marital', 'health', 'economic']
# li_temp ['population', 'children', 'marital', 'religion', 'tenure', 'health', 'hoursworked', 'household', 'ethnicity', 'economic']
# li_temp ['population', 'tenure', 'ethnicity', 'children', 'health', 'hoursworked', 'economic']
# li_temp ['population', 'agemed', 'welsh', 'children', 'religion', 'health', 'tenure', 'household', 'hoursworked']
# li_temp ['population', 'religion', 'tenure', 'marital', 'health', 'ethnicity', 'hoursworked', 'economic', 'children']
# indi [{'label': 'population_value_change_all', 'locRank': -19, 'natRank': -127, 'value': 5.79, '2011': 263925.0, 'perccha': 0.0, 'type': ['pop', 'couDiff', 'regDiff', 'simiDiff']}, {'label': 'tenure_perc_change_rented_private', 'locRank': 14, 'natRank': 77, 'value': 7.8, '2011': 17.09, 'perccha': 83.96, 'type': ['size']}, {'label': 'religion_perc_change_Noreligion', 'locRank': 10, 'natRank': 35, 'value': 13.23, '2011': 29.93, 'perccha': 79.22, 'type': ['ethrel']}, {'label': 'marital_perc_change_Single', 'locRank': 6, 'natRank': 38, 'value': 5.84, '2011': 34.63, 'perccha': 20.29, 'type': ['regDiff']}, {'label': 'health_perc_change_bad', 'locRank': 22, 'natRank': 35, 'value': -2.53, '2011': 5.03, 'perccha': -33.45, 'type': ['size']}, {'label': 'ethnicity_perc_change_black', 'locRank': 8, 'natRank': 43, 'value': 1.83, '2011': 2.52, 'perccha': 264.98, 'type': ['ethrel']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': 7, 'natRank': 55, 'value': 1.34, '2011': 2.75, 'perccha': 95.04, 'type': ['size']}, {'label': 'economic_perc_change_student', 'locRank': 7, 'natRank': 46, 'value': 1.12, '2011': 3.38, 'perccha': 49.58, 'type': ['size']}, {'label': 'children_perc_change_NoKids', 'locRank': 16, 'natRank': -152, 'value': 0.58, '2011': 56.91, 'perccha': 1.03, 'type': ['regBuck']}]
# li_temp ['population', 'economic', 'religion', 'ethnicity', 'marital', 'hoursworked', 'health', 'household', 'tenure']
# li_temp ['population', 'agemed', 'religion', 'marital', 'health', 'ethnicity', 'hoursworked', 'tenure', 'children', 'economic']
# li_temp ['population', 'marital', 'children', 'religion', 'tenure', 'health', 'hoursworked', 'economic']
# li_temp ['population', 'hoursworked', 'tenure', 'economic', 'health', 'marital']
# li_temp ['population', 'agemed', 'tenure', 'economic', 'hoursworked', 'religion', 'health', 'marital', 'children', 'household', 'ethnicity']
# li_temp ['population', 'children', 'health', 'religion', 'tenure', 'hoursworked', 'household', 'ethnicity']
# li_temp ['population', 'marital', 'household', 'tenure', 'care', 'religion', 'health', 'ethnicity', 'hoursworked', 'children', 'economic']
# li_temp ['population', 'household', 'health', 'tenure', 'marital', 'economic', 'ethnicity', 'hoursworked', 'religion']
# li_temp ['population', 'health', 'hoursworked', 'economic', 'tenure', 'children']
# li_temp ['population', 'agemed', 'children', 'health', 'marital', 'tenure', 'household', 'hoursworked', 'ethnicity']
# li_temp ['population', 'household', 'hoursworked', 'tenure', 'health', 'children', 'ethnicity', 'religion']
# li_temp ['population', 'agemed', 'economic', 'tenure', 'household', 'children', 'religion', 'health', 'hoursworked', 'marital']
# li_temp ['population', 'religion', 'tenure', 'hoursworked', 'health', 'marital', 'children', 'economic']
# indi [{'label': 'population_value_change_all', 'locRank': 16, 'natRank': 73, 'value': 9.98, '2011': 167799.0, 'perccha': 0.01, 'type': ['pop', 'couDiff', 'simiDiff']}, {'label': 'tenure_perc_change_owned', 'locRank': -28, 'natRank': -107, 'value': -5.37, '2011': 67.71, 'perccha': -7.35, 'type': ['nearDiff']}, {'label': 'religion_perc_change_Noreligion', 'locRank': 14, 'natRank': 60, 'value': 12.68, '2011': 29.66, 'perccha': 74.68, 'type': ['ethrel']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': 32, 'natRank': 151, 'value': -3.07, '2011': 10.75, 'perccha': -22.21, 'type': ['size']}, {'label': 'health_perc_change_bad', 'locRank': 18, 'natRank': 28, 'value': -2.49, '2011': 3.46, 'perccha': -41.82, 'type': ['size']}, {'label': 'marital_perc_change_Single', 'locRank': -19, 'natRank': -51, 'value': 2.38, '2011': 29.59, 'perccha': 8.75, 'type': ['couDiff']}, {'label': 'children_perc_change_NoKids', 'locRank': 7, 'natRank': 110, 'value': 1.16, '2011': 59.84, 'perccha': 1.98, 'type': ['regBuck']}, {'label': 'economic_perc_change_unemployed', 'locRank': 18, 'natRank': 88, 'value': 1.27, '2011': 3.24, 'perccha': 64.49, 'type': ['size']}]
# li_temp ['population', 'children', 'health', 'hoursworked', 'tenure', 'household', 'ethnicity', 'economic']
# li_temp ['population', 'agemed', 'marital', 'religion', 'household', 'children', 'tenure', 'ethnicity', 'health', 'economic', 'hoursworked']
# li_temp ['population', 'marital', 'tenure', 'health', 'hoursworked', 'economic', 'ethnicity', 'religion']
# li_temp ['population', 'agemed', 'religion', 'tenure', 'hoursworked', 'health', 'children', 'economic', 'ethnicity']
# li_temp ['population', 'religion', 'health', 'tenure', 'household', 'ethnicity', 'hoursworked', 'economic']
# indi [{'label': 'population_value_change_all', 'locRank': 10, 'natRank': 49, 'value': 12.02, '2011': 124012.0, 'perccha': 0.01, 'type': ['pop', 'couDiff', 'regDiff', 'nearDiff']}, {'label': 'health_perc_change_bad', 'locRank': -12, 'natRank': 136, 'value': -3.16, '2011': 4.48, 'perccha': -41.34, 'type': ['size']}, {'label': 'religion_perc_change_Noreligion', 'locRank': 4, 'natRank': 31, 'value': 13.33, '2011': 28.71, 'perccha': 86.67, 'type': ['ethrel', 'regDiff']}, {'label': 'tenure_perc_change_owned', 'locRank': 10, 'natRank': 63, 'value': -2.92, '2011': 74.9, 'perccha': -3.75, 'type': ['couDiff']}, {'label': 'household_perc_change_Cohabiting', 'locRank': 4, 'natRank': 36, 'value': 2.35, '2011': 10.58, 'perccha': 28.56, 'type': ['size']}, {'label': 'ethnicity_perc_change_white', 'locRank': 10, 'natRank': 90, 'value': -1.34, '2011': 97.56, 'perccha': -1.35, 'type': ['regDiff']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': 15, 'natRank': 139, 'value': 1.07, '2011': 3.04, 'perccha': 54.34, 'type': ['size']}, {'label': 'economic_perc_change_employee', 'locRank': 6, 'natRank': 87, 'value': 0.54, '2011': 53.26, 'perccha': 1.03, 'type': ['regBuck']}]
# li_temp ['population', 'agemed', 'marital', 'health', 'hoursworked', 'ethnicity', 'tenure']
# li_temp ['population', 'agemed', 'tenure', 'economic', 'marital', 'health', 'hoursworked', 'religion']
# li_temp ['population', 'agemed', 'welsh', 'religion', 'tenure', 'health', 'marital', 'household', 'economic', 'hoursworked']
# li_temp ['population', 'religion', 'tenure', 'hoursworked', 'health', 'household', 'ethnicity', 'economic', 'children']
# indi [{'label': 'population_value_change_all', 'locRank': 13, 'natRank': 60, 'value': 11.09, '2011': 170756.0, 'perccha': 0.01, 'type': ['pop', 'couDiff', 'regDiff', 'nearDiff']}, {'label': 'tenure_perc_change_owned', 'locRank': 22, 'natRank': 152, 'value': -4.33, '2011': 62.94, 'perccha': -6.44, 'type': ['simiDiff']}, {'label': 'religion_perc_change_Noreligion', 'locRank': 14, 'natRank': 81, 'value': 12.3, '2011': 28.11, 'perccha': 77.8, 'type': ['ethrel']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': 10, 'natRank': 147, 'value': -3.06, '2011': 12.7, 'perccha': -19.41, 'type': ['size']}, {'label': 'health_perc_change_bad', 'locRank': 14, 'natRank': 60, 'value': -2.68, '2011': 4.28, 'perccha': -38.49, 'type': ['size']}, {'label': 'household_perc_change_Cohabiting', 'locRank': 6, 'natRank': 52, 'value': 2.16, '2011': 10.68, 'perccha': 25.36, 'type': ['size']}, {'label': 'ethnicity_perc_change_white', 'locRank': 19, 'natRank': 129, 'value': -1.96, '2011': 94.59, 'perccha': -2.03, 'type': ['regDiff']}, {'label': 'economic_perc_change_employee', 'locRank': -19, 'natRank': -102, 'value': -1.04, '2011': 58.74, 'perccha': -1.74, 'type': ['nearBuck']}, {'label': 'children_perc_change_NoKids', 'locRank': 10, 'natRank': -155, 'value': 0.6, '2011': 62.8, 'perccha': 0.97, 'type': ['regBuck']}]
# li_temp ['population', 'household', 'health', 'religion', 'tenure', 'hoursworked', 'economic']
# li_temp ['population', 'tenure', 'health', 'ethnicity', 'hoursworked', 'religion']
# li_temp ['population', 'marital', 'tenure', 'health', 'ethnicity', 'hoursworked', 'children']
# li_temp ['population', 'health', 'religion', 'tenure', 'ethnicity', 'hoursworked', 'economic', 'marital']
# li_temp ['population', 'agemed', 'health', 'children', 'religion', 'marital', 'tenure', 'ethnicity', 'household', 'economic', 'hoursworked']
# li_temp ['population', 'agemed', 'care', 'marital', 'ethnicity', 'household', 'religion', 'tenure', 'health', 'children', 'hoursworked']
# li_temp ['population', 'agemed', 'ethnicity', 'tenure', 'religion', 'children', 'health', 'marital', 'hoursworked', 'economic']
# li_temp ['population', 'agemed', 'marital', 'economic', 'health', 'household', 'religion', 'hoursworked', 'tenure']
# li_temp ['population', 'agemed', 'marital', 'health', 'hoursworked', 'children', 'household', 'tenure', 'ethnicity']
# li_temp ['population', 'religion', 'tenure', 'health', 'economic', 'hoursworked']
# indi [{'label': 'population_value_change_all', 'locRank': -17, 'natRank': -49, 'value': 2.95, '2011': 219324.0, 'perccha': 0.0, 'type': ['pop', 'couDiff', 'simiDiff']}, {'label': 'tenure_perc_change_rented_private', 'locRank': 18, 'natRank': -151, 'value': 5.94, '2011': 13.24, 'perccha': 81.37, 'type': ['size']}, {'label': 'religion_perc_change_Noreligion', 'locRank': 3, 'natRank': 131, 'value': 11.46, '2011': 23.56, 'perccha': 94.71, 'type': ['ethrel', 'regDiff']}, {'label': 'health_perc_change_bad', 'locRank': -11, 'natRank': -32, 'value': -4.32, '2011': 7.29, 'perccha': -37.2, 'type': ['size']}, {'label': 'economic_perc_change_unemployed', 'locRank': 4, 'natRank': 26, 'value': 1.73, '2011': 4.99, 'perccha': 53.08, 'type': ['size']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': -7, 'natRank': -130, 'value': 1.02, '2011': 2.27, 'perccha': 81.61, 'type': ['size']}]
# li_temp ['population', 'agemed', 'welsh', 'religion', 'health', 'tenure', 'hoursworked', 'household']
# li_temp ['population', 'household', 'marital', 'ethnicity', 'tenure', 'health', 'religion', 'economic', 'hoursworked']
# li_temp ['population', 'tenure', 'marital', 'children', 'health', 'household', 'hoursworked', 'economic', 'religion']
# li_temp ['population', 'agemed', 'household', 'religion', 'marital', 'tenure', 'health', 'ethnicity', 'economic', 'children', 'hoursworked']
# li_temp ['population', 'hoursworked', 'marital', 'economic', 'religion', 'tenure', 'health', 'household', 'ethnicity']
# li_temp ['population', 'welsh', 'marital', 'tenure', 'health', 'hoursworked', 'household', 'economic']
# li_temp ['population', 'tenure', 'health', 'hoursworked', 'ethnicity', 'economic', 'religion']
# li_temp ['population', 'agemed', 'marital', 'economic', 'religion', 'tenure', 'health', 'children', 'ethnicity', 'hoursworked']
# li_temp ['population', 'economic', 'tenure', 'health', 'hoursworked', 'ethnicity']
# li_temp ['population', 'children', 'tenure', 'health', 'hoursworked']
# li_temp ['population', 'care', 'economic', 'tenure', 'health', 'hoursworked', 'children']
# li_temp ['population', 'ethnicity', 'household', 'tenure', 'health', 'religion', 'children', 'economic', 'hoursworked']
# indi [{'label': 'population_value_change_all', 'locRank': -12, 'natRank': 63, 'value': 10.83, '2011': 275885.0, 'perccha': 0.0, 'type': ['pop', 'couDiff', 'regDiff', 'nearDiff', 'simiDiff']}, {'label': 'household_perc_change_OnePerson', 'locRank': 3, 'natRank': -66, 'value': -0.65, '2011': 34.18, 'perccha': -1.86, 'type': ['locRank', 'regDiff', 'nearDiff', 'simiDiff']}, {'label': 'ethnicity_perc_change_mixed', 'locRank': 1, 'natRank': 2, 'value': 3.24, '2011': 7.42, 'perccha': 77.52, 'type': ['ethrel']}, {'label': 'tenure_perc_change_owned', 'locRank': 15, 'natRank': -51, 'value': -6.93, '2011': 42.4, 'perccha': -14.05, 'type': ['nearDiff']}, {'label': 'health_perc_change_bad', 'locRank': 16, 'natRank': -153, 'value': -3.28, '2011': 5.19, 'perccha': -38.71, 'type': ['size']}, {'label': 'religion_perc_change_Muslim', 'locRank': -14, 'natRank': 63, 'value': 1.82, '2011': 6.44, 'perccha': 39.41, 'type': ['ethrel', 'regDiff']}, {'label': 'children_perc_change_NoKids', 'locRank': 10, 'natRank': -55, 'value': -1.51, '2011': 59.54, 'perccha': -2.47, 'type': ['simiDiff']}, {'label': 'economic_perc_change_student', 'locRank': 6, 'natRank': 28, 'value': 1.47, '2011': 4.9, 'perccha': 42.87, 'type': ['size']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': 10, 'natRank': 38, 'value': 1.46, '2011': 3.35, 'perccha': 77.26, 'type': ['size']}]
# li_temp ['population', 'household', 'religion', 'marital', 'health', 'economic', 'children', 'tenure', 'hoursworked', 'ethnicity']
# li_temp ['population', 'economic', 'household', 'religion', 'tenure', 'health', 'hoursworked', 'ethnicity']
# li_temp ['population', 'tenure', 'health', 'ethnicity', 'hoursworked', 'religion']
# li_temp ['population', 'tenure', 'hoursworked', 'health']
# li_temp ['population', 'economic', 'tenure', 'marital', 'health', 'hoursworked', 'household']
# li_temp ['population', 'household', 'religion', 'tenure', 'health', 'hoursworked', 'economic']
# li_temp ['population', 'agemed', 'household', 'religion', 'tenure', 'health', 'marital', 'hoursworked']
# li_temp ['population', 'tenure', 'health', 'household', 'ethnicity', 'hoursworked', 'children']
# li_temp ['population', 'agemed', 'hoursworked', 'tenure', 'health', 'marital', 'ethnicity', 'children']
# li_temp ['population', 'religion', 'marital', 'hoursworked', 'tenure', 'children', 'health']
# indi [{'label': 'population_value_change_all', 'locRank': 30, 'natRank': 131, 'value': 7.33, '2011': 130875.0, 'perccha': 0.01, 'type': ['pop', 'nearDiff']}, {'label': 'marital_perc_change_Married', 'locRank': 2, 'natRank': 16, 'value': -0.33, '2011': 55.34, 'perccha': -0.59, 'type': ['couDiff', 'regDiff', 'nearDiff']}, {'label': 'religion_perc_change_Christian', 'locRank': 1, 'natRank': 43, 'value': -10.24, '2011': 64.16, 'perccha': -13.76, 'type': ['regDiff']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': 3, 'natRank': 36, 'value': -2.18, '2011': 15.96, 'perccha': -12.01, 'type': ['locRank']}, {'label': 'tenure_perc_change_rented_private', 'locRank': -25, 'natRank': -91, 'value': 4.95, '2011': 15.13, 'perccha': 48.63, 'type': ['size', 'couDiff']}, {'label': 'children_perc_change_NoKids', 'locRank': -4, 'natRank': -23, 'value': -2.7, '2011': 57.86, 'perccha': -4.46, 'type': ['regDiff']}, {'label': 'health_perc_change_bad', 'locRank': 24, 'natRank': 38, 'value': -2.54, '2011': 3.12, 'perccha': -44.85, 'type': ['size']}]
# li_temp ['population', 'agemed', 'religion', 'tenure', 'marital', 'health', 'household', 'ethnicity', 'hoursworked', 'economic']
# li_temp ['population', 'household', 'tenure', 'religion', 'ethnicity', 'marital', 'hoursworked', 'health', 'economic']
# li_temp ['population', 'household', 'religion', 'tenure', 'health', 'marital', 'economic', 'hoursworked']
# li_temp ['population', 'economic', 'tenure', 'ethnicity', 'religion', 'health', 'hoursworked']
# li_temp ['population', 'religion', 'ethnicity', 'hoursworked', 'health', 'children', 'economic', 'household', 'tenure']
# indi [{'label': 'population_value_change_all', 'locRank': -16, 'natRank': -123, 'value': 5.76, '2011': 95598.0, 'perccha': 0.01, 'type': ['pop', 'couDiff', 'regDiff', 'nearDiff', 'simiDiff']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': 18, 'natRank': 98, 'value': -2.77, '2011': 10.13, 'perccha': -21.46, 'type': ['size']}, {'label': 'religion_perc_change_Noreligion', 'locRank': -5, 'natRank': -57, 'value': 8.43, '2011': 22.5, 'perccha': 59.92, 'type': ['ethrel', 'regDiff']}, {'label': 'ethnicity_perc_change_white', 'locRank': -9, 'natRank': -57, 'value': -7.01, '2011': 87.3, 'perccha': -7.43, 'type': ['regDiff']}, {'label': 'health_perc_change_bad', 'locRank': 24, 'natRank': 37, 'value': -2.54, '2011': 4.1, 'perccha': -38.23, 'type': ['size']}, {'label': 'children_perc_change_Kids', 'locRank': 10, 'natRank': 37, 'value': 1.7, '2011': 29.45, 'perccha': 6.13, 'type': ['nearDiff']}, {'label': 'economic_perc_change_unemployed', 'locRank': 16, 'natRank': 79, 'value': 1.31, '2011': 3.26, 'perccha': 67.2, 'type': ['size']}, {'label': 'household_perc_change_OnePerson', 'locRank': -8, 'natRank': -51, 'value': -1.0, '2011': 28.5, 'perccha': -3.39, 'type': ['nearDiff']}, {'label': 'tenure_perc_change_rented_social', 'locRank': 5, 'natRank': 11, 'value': 0.75, '2011': 12.43, 'perccha': 6.43, 'type': ['couBuck']}]
# li_temp ['population', 'ethnicity', 'hoursworked', 'health', 'children', 'tenure']
# indi [{'label': 'population_value_change_all', 'locRank': -9, 'natRank': -79, 'value': 4.21, '2011': 176462.0, 'perccha': 0.0, 'type': ['pop', 'couDiff', 'regDiff', 'nearDiff']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': -18, 'natRank': -103, 'value': -3.39, '2011': 11.13, 'perccha': -23.34, 'type': ['size']}, {'label': 'ethnicity_perc_change_white', 'locRank': 3, 'natRank': 86, 'value': -1.3, '2011': 97.56, 'perccha': -1.31, 'type': ['regDiff']}, {'label': 'health_perc_change_bad', 'locRank': -26, 'natRank': 72, 'value': -2.74, '2011': 4.88, 'perccha': -35.94, 'type': ['size']}, {'label': 'children_perc_change_NoKids', 'locRank': 7, 'natRank': 112, 'value': 1.16, '2011': 66.25, 'perccha': 1.78, 'type': ['regBuck']}, {'label': 'tenure_perc_change_rented_social', 'locRank': 4, 'natRank': 10, 'value': 0.9, '2011': 10.98, 'perccha': 8.94, 'type': ['couBuck']}]
# li_temp ['population', 'household', 'children', 'health', 'ethnicity', 'marital', 'tenure', 'hoursworked', 'economic']
# li_temp ['population', 'agemed', 'tenure', 'marital', 'religion', 'health', 'hoursworked', 'household', 'ethnicity', 'economic']
# li_temp ['population', 'tenure', 'health', 'ethnicity', 'religion', 'household', 'children', 'hoursworked', 'economic']
# li_temp ['population', 'health', 'religion', 'tenure', 'ethnicity', 'children', 'hoursworked', 'economic']
# li_temp ['population', 'household', 'economic', 'tenure', 'health', 'hoursworked', 'ethnicity', 'religion']
# li_temp ['population', 'agemed', 'religion', 'hoursworked', 'tenure', 'health', 'marital', 'ethnicity', 'economic', 'children']
# li_temp ['population', 'tenure', 'marital', 'economic', 'religion', 'hoursworked', 'health', 'household', 'children', 'ethnicity']
# li_temp ['population', 'marital', 'household', 'tenure', 'hoursworked', 'health', 'ethnicity']
# li_temp ['population', 'household', 'tenure', 'health', 'economic', 'hoursworked', 'religion']
# li_temp ['population', 'agemed', 'ethnicity', 'care', 'religion', 'health', 'tenure', 'marital', 'household', 'hoursworked']
# li_temp ['population', 'religion', 'ethnicity', 'tenure', 'health', 'hoursworked', 'marital', 'economic']
# indi [{'label': 'population_value_change_all', 'locRank': 14, 'natRank': 69, 'value': 10.42, '2011': 99198.0, 'perccha': 0.01, 'type': ['pop', 'couDiff', 'regDiff', 'nearDiff', 'simiDiff']}, {'label': 'tenure_perc_change_rented_private', 'locRank': 25, 'natRank': 140, 'value': 6.27, '2011': 15.67, 'perccha': 66.71, 'type': ['size']}, {'label': 'religion_perc_change_Noreligion', 'locRank': -4, 'natRank': -45, 'value': 8.0, '2011': 23.12, 'perccha': 52.91, 'type': ['ethrel', 'regDiff']}, {'label': 'ethnicity_perc_change_white', 'locRank': -7, 'natRank': -45, 'value': -7.67, '2011': 83.6, 'perccha': -8.4, 'type': ['regDiff']}, {'label': 'health_perc_change_bad', 'locRank': 21, 'natRank': 32, 'value': -2.52, '2011': 3.39, 'perccha': -42.62, 'type': ['size']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': 9, 'natRank': 65, 'value': -2.49, '2011': 12.24, 'perccha': -16.9, 'type': ['size']}, {'label': 'marital_perc_change_Single', 'locRank': -10, 'natRank': -28, 'value': 1.88, '2011': 29.93, 'perccha': 6.71, 'type': ['couDiff']}, {'label': 'economic_perc_change_unemployed', 'locRank': 10, 'natRank': 58, 'value': 1.4, '2011': 3.22, 'perccha': 76.94, 'type': ['size']}]
# li_temp ['population', 'agemed', 'religion', 'tenure', 'ethnicity', 'children', 'hoursworked', 'health', 'economic', 'marital']
# li_temp ['population', 'ethnicity', 'tenure', 'health', 'religion', 'hoursworked', 'economic', 'marital']
# indi [{'label': 'population_value_change_all', 'locRank': 5, 'natRank': 7, 'value': 19.6, '2011': 253957.0, 'perccha': 0.01, 'type': ['pop', 'couDiff', 'regDiff', 'nearDiff', 'simiDiff']}, {'label': 'tenure_perc_change_rented_private', 'locRank': -16, 'natRank': 31, 'value': 9.67, '2011': 23.4, 'perccha': 70.43, 'type': ['size', 'couDiff', 'nearDiff']}, {'label': 'ethnicity_perc_change_white', 'locRank': -8, 'natRank': -12, 'value': -13.48, '2011': 51.39, 'perccha': -20.78, 'type': ['regDiff']}, {'label': 'health_perc_change_bad', 'locRank': -14, 'natRank': -141, 'value': -3.36, '2011': 4.69, 'perccha': -41.72, 'type': ['size']}, {'label': 'religion_perc_change_Noreligion', 'locRank': -6, 'natRank': -7, 'value': 2.43, '2011': 15.89, 'perccha': 18.06, 'type': ['ethrel', 'regDiff']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': -9, 'natRank': 74, 'value': -2.56, '2011': 9.53, 'perccha': -21.16, 'type': ['size']}, {'label': 'economic_perc_change_unemployed', 'locRank': 9, 'natRank': 62, 'value': 1.38, '2011': 4.64, 'perccha': 42.35, 'type': ['size']}, {'label': 'marital_perc_change_Single', 'locRank': -9, 'natRank': -13, 'value': 0.82, '2011': 38.52, 'perccha': 2.18, 'type': ['couDiff', 'regDiff']}]
# li_temp ['population', 'household', 'religion', 'tenure', 'health', 'hoursworked', 'ethnicity', 'economic']
# li_temp ['population', 'agemed', 'household', 'religion', 'tenure', 'marital', 'health', 'children', 'ethnicity', 'economic', 'hoursworked']
# li_temp ['population', 'health', 'tenure', 'hoursworked', 'children', 'household', 'ethnicity']
# li_temp ['population', 'tenure', 'religion', 'health', 'economic', 'marital', 'hoursworked', 'ethnicity']
# li_temp ['population', 'agemed', 'children', 'religion', 'ethnicity', 'care', 'health', 'marital', 'tenure', 'hoursworked', 'household']
# li_temp ['population', 'welsh', 'marital', 'children', 'religion', 'tenure', 'health', 'hoursworked', 'household', 'economic']
# li_temp ['population', 'marital', 'care', 'household', 'religion', 'tenure', 'health', 'hoursworked', 'children', 'economic', 'ethnicity']
# li_temp ['population', 'health', 'tenure', 'hoursworked', 'children', 'ethnicity', 'economic', 'religion']
# li_temp ['population', 'agemed', 'marital', 'health', 'household', 'religion', 'tenure', 'ethnicity', 'economic', 'hoursworked', 'children']
# li_temp ['population', 'religion', 'tenure', 'ethnicity', 'health', 'hoursworked', 'marital', 'economic']
# indi [{'label': 'population_value_change_all', 'locRank': -4, 'natRank': -57, 'value': 3.17, '2011': 80510.0, 'perccha': 0.0, 'type': ['pop', 'couDiff', 'regDiff', 'nearDiff', 'simiDiff']}, {'label': 'tenure_perc_change_rented_private', 'locRank': -32, 'natRank': -116, 'value': 5.28, '2011': 15.2, 'perccha': 53.23, 'type': ['size']}, {'label': 'religion_perc_change_Noreligion', 'locRank': -15, 'natRank': -97, 'value': 9.64, '2011': 23.97, 'perccha': 67.27, 'type': ['ethrel']}, {'label': 'ethnicity_perc_change_asian', 'locRank': 10, 'natRank': 43, 'value': 4.26, '2011': 6.91, 'perccha': 160.73, 'type': ['ethrel']}, {'label': 'health_perc_change_bad', 'locRank': 30, 'natRank': 45, 'value': -2.58, '2011': 3.69, 'perccha': -41.13, 'type': ['size']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': 16, 'natRank': 85, 'value': -2.64, '2011': 12.12, 'perccha': -17.88, 'type': ['size']}, {'label': 'marital_perc_change_Single', 'locRank': -20, 'natRank': -52, 'value': 2.39, '2011': 35.49, 'perccha': 7.22, 'type': ['couDiff']}, {'label': 'economic_perc_change_unemployed', 'locRank': -32, 'natRank': 130, 'value': 1.08, '2011': 2.73, 'perccha': 65.48, 'type': ['size']}]
# li_temp ['population', 'agemed', 'religion', 'marital', 'household', 'hoursworked', 'tenure', 'health', 'ethnicity']
# li_temp ['population', 'household', 'care', 'tenure', 'hoursworked', 'health', 'ethnicity', 'economic', 'children']
# li_temp ['population', 'health', 'religion', 'hoursworked', 'tenure', 'household']
# li_temp ['population', 'agemed', 'children', 'religion', 'hoursworked', 'health', 'ethnicity', 'tenure']
# li_temp ['population', 'agemed', 'religion', 'economic', 'children', 'tenure', 'marital', 'health', 'hoursworked', 'household', 'ethnicity']
# li_temp ['population', 'marital', 'care', 'religion', 'tenure', 'health', 'hoursworked', 'children', 'household', 'economic', 'ethnicity']
# li_temp ['population', 'tenure', 'health', 'household', 'hoursworked', 'economic', 'ethnicity']
# li_temp ['population', 'agemed', 'marital', 'tenure', 'ethnicity', 'health', 'hoursworked', 'religion']
# li_temp ['population', 'welsh', 'religion', 'economic', 'hoursworked', 'health', 'marital', 'household', 'tenure']
# li_temp ['population', 'household', 'tenure', 'marital', 'health', 'hoursworked', 'economic']
# li_temp ['population', 'agemed', 'household', 'health', 'marital', 'tenure', 'hoursworked', 'ethnicity', 'economic']
# li_temp ['population', 'children', 'tenure', 'health', 'hoursworked', 'ethnicity', 'economic']
# li_temp ['population', 'welsh', 'household', 'care', 'religion', 'health', 'tenure', 'economic', 'hoursworked']
# li_temp ['population', 'tenure', 'hoursworked', 'health', 'household', 'economic']
# li_temp ['population', 'agemed', 'household', 'ethnicity', 'health', 'hoursworked', 'marital', 'religion', 'economic', 'tenure']
# li_temp ['population', 'religion', 'hoursworked', 'health', 'tenure', 'ethnicity', 'economic']
# indi [{'label': 'population_value_change_all', 'locRank': 12, 'natRank': 58, 'value': 11.28, '2011': 147084.0, 'perccha': 0.01, 'type': ['pop', 'couDiff', 'regDiff', 'nearDiff']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': -11, 'natRank': -37, 'value': -3.84, '2011': 12.28, 'perccha': -23.81, 'type': ['size']}, {'label': 'religion_perc_change_Noreligion', 'locRank': 7, 'natRank': 47, 'value': 13.0, '2011': 29.99, 'perccha': 76.52, 'type': ['ethrel']}, {'label': 'health_perc_change_bad', 'locRank': 13, 'natRank': 55, 'value': -2.66, '2011': 4.36, 'perccha': -37.87, 'type': ['size']}, {'label': 'tenure_perc_change_rented_social', 'locRank': -4, 'natRank': -52, 'value': -2.55, '2011': 16.47, 'perccha': -13.4, 'type': ['nearDiff']}, {'label': 'ethnicity_perc_change_white', 'locRank': 15, 'natRank': 114, 'value': -1.6, '2011': 96.6, 'perccha': -1.63, 'type': ['regDiff']}, {'label': 'economic_perc_change_unemployed', 'locRank': 12, 'natRank': 46, 'value': 1.45, '2011': 3.76, 'perccha': 62.79, 'type': ['size']}]
# li_temp ['population', 'hoursworked', 'economic', 'tenure', 'health']
# li_temp ['population', 'tenure', 'health', 'hoursworked', 'marital']
# li_temp ['population', 'ethnicity', 'religion', 'economic', 'children', 'health', 'marital', 'hoursworked', 'tenure']
# indi [{'label': 'population_value_change_all', 'locRank': 23, 'natRank': 96, 'value': 8.81, '2011': 155698.0, 'perccha': 0.01, 'type': ['pop', 'nearDiff', 'simiDiff']}, {'label': 'economic_perc_change_unemployed', 'locRank': 2, 'natRank': 7, 'value': 2.04, '2011': 4.56, 'perccha': 80.96, 'type': ['size', 'locRank']}, {'label': 'ethnicity_perc_change_white', 'locRank': -2, 'natRank': -18, 'value': -12.07, '2011': 74.75, 'perccha': -13.9, 'type': ['regDiff']}, {'label': 'religion_perc_change_Hindu', 'locRank': 2, 'natRank': 8, 'value': 2.65, '2011': 3.64, 'perccha': 267.51, 'type': ['regDiff']}, {'label': 'children_perc_change_NonDepKids', 'locRank': -3, 'natRank': -13, 'value': -0.67, '2011': 7.84, 'perccha': -7.86, 'type': ['locRank']}, {'label': 'health_perc_change_bad', 'locRank': -28, 'natRank': 67, 'value': -2.72, '2011': 3.75, 'perccha': -42.02, 'type': ['size']}, {'label': 'marital_perc_change_Single', 'locRank': -13, 'natRank': -35, 'value': 2.03, '2011': 43.13, 'perccha': 4.94, 'type': ['couDiff']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': 12, 'natRank': 90, 'value': 1.19, '2011': 3.21, 'perccha': 58.93, 'type': ['size']}, {'label': 'tenure_perc_change_rented_social', 'locRank': 6, 'natRank': 16, 'value': 0.71, '2011': 16.29, 'perccha': 4.56, 'type': ['couBuck']}]
# li_temp ['population', 'tenure', 'ethnicity', 'health', 'hoursworked']
# li_temp ['population', 'agemed', 'ethnicity', 'tenure', 'marital', 'hoursworked', 'health', 'children', 'economic']
# li_temp ['population', 'economic', 'health', 'religion', 'tenure', 'hoursworked', 'ethnicity']
# li_temp ['population', 'health', 'household', 'economic', 'marital', 'tenure', 'hoursworked', 'ethnicity', 'religion']
# li_temp ['population', 'agemed', 'ethnicity', 'children', 'tenure', 'religion', 'health', 'economic', 'hoursworked', 'marital']
# li_temp ['population', 'tenure', 'economic', 'marital', 'health', 'children', 'ethnicity']
# li_temp ['population', 'agemed', 'marital', 'household', 'religion', 'hoursworked', 'tenure', 'ethnicity', 'health', 'economic', 'children']
# li_temp ['population', 'agemed', 'hoursworked', 'health', 'ethnicity', 'marital', 'children', 'tenure']
# li_temp ['population', 'agemed', 'religion', 'health', 'economic', 'children', 'marital', 'tenure', 'hoursworked']
# li_temp ['population', 'household', 'tenure', 'religion', 'health', 'economic', 'hoursworked', 'marital']
# li_temp ['population', 'agemed', 'welsh', 'tenure', 'ethnicity', 'religion', 'household', 'marital', 'health', 'economic', 'hoursworked']
# li_temp ['population', 'agemed', 'economic', 'children', 'hoursworked', 'health', 'marital', 'ethnicity', 'tenure', 'religion']
# li_temp ['population', 'children', 'ethnicity', 'religion', 'tenure', 'hoursworked', 'health']
# li_temp ['population', 'agemed', 'religion', 'ethnicity', 'tenure', 'health', 'children', 'economic', 'household', 'hoursworked']
# li_temp ['population', 'religion', 'tenure', 'ethnicity', 'hoursworked', 'health', 'economic']
# indi [{'label': 'population_value_change_all', 'locRank': -14, 'natRank': -135, 'value': 5.91, '2011': 100031.0, 'perccha': 0.01, 'type': ['pop', 'regDiff', 'nearDiff']}, {'label': 'tenure_perc_change_rented_social', 'locRank': 1, 'natRank': 1, 'value': 1.54, '2011': 17.43, 'perccha': 9.7, 'type': ['locRank', 'natRank', 'couBuck', 'regBuck']}, {'label': 'religion_perc_change_Jewish', 'locRank': 1, 'natRank': 1, 'value': 2.95, '2011': 14.29, 'perccha': 26.02, 'type': ['regDiff']}, {'label': 'ethnicity_perc_change_white', 'locRank': -5, 'natRank': -50, 'value': -7.47, '2011': 85.04, 'perccha': -8.07, 'type': ['regDiff']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': 13, 'natRank': -149, 'value': -3.14, '2011': 11.86, 'perccha': -20.93, 'type': ['size']}, {'label': 'health_perc_change_bad', 'locRank': 8, 'natRank': 26, 'value': -2.47, '2011': 4.15, 'perccha': -37.29, 'type': ['size']}, {'label': 'economic_perc_change_unemployed', 'locRank': 14, 'natRank': 63, 'value': 1.38, '2011': 3.71, 'perccha': 59.24, 'type': ['size']}]
# li_temp ['population', 'agemed', 'health', 'tenure', 'hoursworked', 'children', 'ethnicity']
# li_temp ['population', 'agemed', 'religion', 'marital', 'household', 'tenure', 'economic', 'health', 'hoursworked']
# li_temp ['population', 'agemed', 'children', 'religion', 'tenure', 'hoursworked', 'health', 'ethnicity']
# li_temp ['population', 'hoursworked', 'health', 'household', 'ethnicity', 'children', 'tenure']
# li_temp ['population', 'agemed', 'religion', 'household', 'tenure', 'health', 'marital', 'economic', 'hoursworked', 'ethnicity']
# li_temp ['population', 'religion', 'hoursworked', 'marital', 'health', 'tenure', 'children', 'household', 'ethnicity']
# indi [{'label': 'population_value_change_all', 'locRank': 5, 'natRank': 87, 'value': 9.13, '2011': 83449.0, 'perccha': 0.01, 'type': ['pop', 'regDiff', 'nearDiff', 'simiDiff']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': -2, 'natRank': -34, 'value': -3.88, '2011': 11.69, 'perccha': -24.91, 'type': ['size', 'locRank']}, {'label': 'religion_perc_change_Christian', 'locRank': 1, 'natRank': 41, 'value': -10.21, '2011': 70.92, 'perccha': -12.58, 'type': ['regDiff']}, {'label': 'marital_perc_change_Single', 'locRank': -7, 'natRank': -149, 'value': 3.87, '2011': 26.55, 'perccha': 17.07, 'type': ['nearDiff']}, {'label': 'health_perc_change_bad', 'locRank': 6, 'natRank': -140, 'value': -3.38, '2011': 4.58, 'perccha': -42.44, 'type': ['size']}, {'label': 'tenure_perc_change_owned', 'locRank': 9, 'natRank': 80, 'value': -3.23, '2011': 74.98, 'perccha': -4.13, 'type': ['simiDiff']}, {'label': 'children_perc_change_NoKids', 'locRank': 4, 'natRank': 32, 'value': 2.36, '2011': 60.45, 'perccha': 4.06, 'type': ['couDiff']}, {'label': 'household_perc_change_Cohabiting', 'locRank': 7, 'natRank': 37, 'value': 2.34, '2011': 10.98, 'perccha': 27.09, 'type': ['size']}, {'label': 'ethnicity_perc_change_white', 'locRank': 4, 'natRank': 52, 'value': -0.97, '2011': 98.36, 'perccha': -0.98, 'type': ['regDiff']}]
# li_temp ['population', 'agemed', 'household', 'tenure', 'hoursworked', 'marital', 'children', 'ethnicity', 'religion', 'health', 'economic']
# li_temp ['population', 'religion', 'tenure', 'marital', 'health', 'hoursworked']
# indi [{'label': 'population_value_change_all', 'locRank': 5, 'natRank': 78, 'value': 9.64, '2011': 53553.0, 'perccha': 0.02, 'type': ['pop', 'regDiff', 'nearDiff', 'simiDiff']}, {'label': 'tenure_perc_change_rented_social', 'locRank': 2, 'natRank': 14, 'value': 0.73, '2011': 9.5, 'perccha': 8.33, 'type': ['locRank', 'couBuck']}, {'label': 'religion_perc_change_Noreligion', 'locRank': -2, 'natRank': 149, 'value': 11.21, '2011': 26.62, 'perccha': 72.75, 'type': ['ethrel']}, {'label': 'marital_perc_change_Married', 'locRank': 3, 'natRank': 53, 'value': -2.64, '2011': 54.69, 'perccha': -4.6, 'type': ['locRank']}, {'label': 'health_perc_change_bad', 'locRank': 10, 'natRank': 128, 'value': -3.11, '2011': 5.14, 'perccha': -37.68, 'type': ['size']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': 9, 'natRank': 89, 'value': 1.19, '2011': 3.59, 'perccha': 49.6, 'type': ['size']}]
# li_temp ['population', 'household', 'health', 'tenure', 'hoursworked', 'ethnicity', 'economic']
# li_temp ['population', 'ethnicity', 'religion', 'household', 'tenure', 'health', 'hoursworked', 'economic']
# indi [{'label': 'population_value_change_all', 'locRank': 6, 'natRank': 100, 'value': 8.72, '2011': 422458.0, 'perccha': 0.0, 'type': ['pop', 'regDiff', 'nearDiff', 'simiDiff']}, {'label': 'household_perc_change_OnePerson', 'locRank': -2, 'natRank': -92, 'value': 0.03, '2011': 30.29, 'perccha': 0.1, 'type': ['nearDiff']}, {'label': 'ethnicity_perc_change_asian', 'locRank': 2, 'natRank': 36, 'value': 4.53, '2011': 16.04, 'perccha': 39.36, 'type': ['ethrel']}, {'label': 'religion_perc_change_Muslim', 'locRank': 2, 'natRank': 22, 'value': 4.39, '2011': 14.51, 'perccha': 43.39, 'type': ['ethrel', 'regDiff']}, {'label': 'tenure_perc_change_rented_private', 'locRank': 9, 'natRank': 131, 'value': 6.44, '2011': 15.53, 'perccha': 70.85, 'type': ['size']}, {'label': 'health_perc_change_bad', 'locRank': -10, 'natRank': -67, 'value': -4.01, '2011': 5.76, 'perccha': -41.03, 'type': ['size']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': -10, 'natRank': -106, 'value': -3.35, '2011': 8.81, 'perccha': -27.54, 'type': ['size']}, {'label': 'economic_perc_change_unemployed', 'locRank': 5, 'natRank': 70, 'value': 1.35, '2011': 4.71, 'perccha': 40.2, 'type': ['size']}]
# li_temp ['population', 'agemed', 'tenure', 'marital', 'religion', 'children', 'ethnicity', 'health', 'hoursworked', 'economic']
# li_temp ['population', 'household', 'tenure', 'hoursworked', 'marital', 'health', 'religion']
# li_temp ['population', 'agemed', 'hoursworked', 'tenure', 'ethnicity', 'religion', 'health', 'economic', 'marital']
# li_temp ['population', 'welsh', 'children', 'economic', 'marital', 'health', 'tenure', 'household', 'hoursworked']
# li_temp ['population', 'agemed', 'ethnicity', 'health', 'tenure', 'religion', 'marital', 'economic']
# li_temp ['population', 'agemed', 'religion', 'tenure', 'ethnicity', 'health', 'children', 'marital', 'household', 'economic']
# li_temp ['population', 'agemed', 'tenure', 'marital', 'health', 'household', 'religion', 'economic', 'hoursworked']
# li_temp ['population', 'agemed', 'tenure', 'health', 'ethnicity', 'children', 'economic', 'hoursworked']
# li_temp ['population', 'household', 'marital', 'tenure', 'health', 'hoursworked', 'ethnicity', 'economic', 'religion']
# li_temp ['population', 'agemed', 'welsh', 'economic', 'children', 'health', 'tenure', 'hoursworked', 'household']
# li_temp ['population', 'marital', 'hoursworked', 'tenure', 'health']
# li_temp ['population', 'agemed', 'religion', 'tenure', 'health', 'marital', 'household', 'children', 'hoursworked', 'ethnicity']
# li_temp ['population', 'agemed', 'ethnicity', 'health', 'religion', 'household', 'tenure', 'children', 'marital', 'hoursworked', 'economic']
# li_temp ['population', 'religion', 'ethnicity', 'children', 'tenure', 'health', 'economic', 'hoursworked']
# indi [{'label': 'population_value_change_all', 'locRank': 18, 'natRank': -67, 'value': 3.51, '2011': 224897.0, 'perccha': 0.0, 'type': ['pop', 'couDiff']}, {'label': 'children_perc_change_NoKids', 'locRank': -3, 'natRank': -93, 'value': -0.58, '2011': 55.47, 'perccha': -1.03, 'type': ['locRank', 'regBuck']}, {'label': 'religion_perc_change_Christian', 'locRank': -2, 'natRank': -103, 'value': -12.96, '2011': 59.66, 'perccha': -17.84, 'type': ['regDiff']}, {'label': 'ethnicity_perc_change_white', 'locRank': -3, 'natRank': -41, 'value': -8.63, '2011': 77.51, 'perccha': -10.02, 'type': ['regDiff']}, {'label': 'tenure_perc_change_rented_private', 'locRank': -20, 'natRank': -146, 'value': 5.86, '2011': 12.2, 'perccha': 92.43, 'type': ['size']}, {'label': 'health_perc_change_bad', 'locRank': -13, 'natRank': -36, 'value': -4.29, '2011': 6.94, 'perccha': -38.19, 'type': ['size']}, {'label': 'economic_perc_change_unemployed', 'locRank': 4, 'natRank': 27, 'value': 1.73, '2011': 5.42, 'perccha': 46.9, 'type': ['size']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': 6, 'natRank': 35, 'value': 1.47, '2011': 2.93, 'perccha': 100.68, 'type': ['size']}]
# li_temp ['population', 'agemed', 'children', 'ethnicity', 'tenure', 'hoursworked', 'health', 'household', 'religion']
# li_temp ['population', 'agemed', 'economic', 'religion', 'tenure', 'marital', 'health', 'hoursworked']
# li_temp ['population', 'health', 'tenure', 'hoursworked', 'ethnicity']
# li_temp ['population', 'tenure', 'health', 'ethnicity']
# li_temp ['population', 'agemed', 'ethnicity', 'religion', 'marital', 'household', 'economic', 'health', 'hoursworked', 'tenure', 'children']
# li_temp ['population', 'agemed', 'children', 'tenure', 'health', 'hoursworked', 'economic', 'ethnicity']
# li_temp ['population', 'agemed', 'children', 'care', 'household', 'tenure', 'hoursworked', 'health', 'economic', 'ethnicity', 'religion']
# li_temp ['population', 'agemed', 'hoursworked', 'health', 'tenure', 'economic', 'religion']
# li_temp ['population', 'agemed', 'welsh', 'tenure', 'marital', 'ethnicity', 'health', 'religion', 'children', 'hoursworked', 'household', 'economic']
# li_temp ['population', 'health', 'religion', 'tenure', 'economic', 'hoursworked']
# li_temp ['population', 'agemed', 'welsh', 'hoursworked', 'marital', 'tenure', 'religion', 'health', 'economic']
# li_temp ['population', 'care', 'hoursworked', 'tenure', 'health', 'marital', 'children', 'household', 'ethnicity']
# li_temp ['population', 'economic', 'religion', 'tenure', 'hoursworked', 'marital', 'health']
# li_temp ['population', 'ethnicity', 'tenure', 'religion', 'children', 'marital', 'health', 'household', 'economic', 'hoursworked']
# indi [{'label': 'population_value_change_all', 'locRank': 9, 'natRank': 40, 'value': 13.26, '2011': 90301.0, 'perccha': 0.02, 'type': ['pop', 'couDiff', 'regDiff', 'nearDiff', 'simiDiff']}, {'label': 'tenure_perc_change_rented_private', 'locRank': 2, 'natRank': 18, 'value': 10.37, '2011': 20.09, 'perccha': 106.69, 'type': ['size', 'locRank', 'couDiff', 'regDiff', 'nearDiff', 'simiDiff']}, {'label': 'ethnicity_perc_change_white', 'locRank': -2, 'natRank': -11, 'value': -14.03, '2011': 71.92, 'perccha': -16.32, 'type': ['regDiff']}, {'label': 'religion_perc_change_Hindu', 'locRank': 1, 'natRank': 5, 'value': 3.09, '2011': 4.82, 'perccha': 178.57, 'type': ['regDiff']}, {'label': 'children_perc_change_Kids', 'locRank': 3, 'natRank': 20, 'value': 2.42, '2011': 32.52, 'perccha': 8.04, 'type': ['locRank', 'regDiff']}, {'label': 'marital_perc_change_Married', 'locRank': 3, 'natRank': 42, 'value': -2.28, '2011': 46.18, 'perccha': -4.7, 'type': ['locRank']}, {'label': 'health_perc_change_bad', 'locRank': 16, 'natRank': 65, 'value': -2.71, '2011': 4.14, 'perccha': -39.54, 'type': ['size']}, {'label': 'household_perc_change_LoneParent', 'locRank': 4, 'natRank': 17, 'value': 2.29, '2011': 10.66, 'perccha': 27.37, 'type': ['size']}, {'label': 'economic_perc_change_unemployed', 'locRank': 9, 'natRank': 36, 'value': 1.58, '2011': 4.06, 'perccha': 63.72, 'type': ['size']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': 9, 'natRank': 97, 'value': 1.17, '2011': 2.88, 'perccha': 68.44, 'type': ['size']}]
# li_temp ['population', 'economic', 'religion', 'tenure', 'health', 'hoursworked', 'household', 'children']
# li_temp ['population', 'agemed', 'ethnicity', 'children', 'household', 'health', 'hoursworked', 'religion', 'marital', 'tenure', 'economic']
# li_temp ['population', 'agemed', 'household', 'religion', 'ethnicity', 'health', 'economic', 'tenure', 'marital']
# li_temp ['population', 'agemed', 'children', 'marital', 'hoursworked', 'religion', 'tenure', 'health', 'economic', 'ethnicity']
# li_temp ['population', 'religion', 'tenure', 'health', 'hoursworked', 'ethnicity', 'economic']
# indi [{'label': 'population_value_change_all', 'locRank': 7, 'natRank': 149, 'value': 6.68, '2011': 107155.0, 'perccha': 0.01, 'type': ['pop']}, {'label': 'tenure_perc_change_rented_private', 'locRank': -14, 'natRank': -122, 'value': 5.39, '2011': 10.21, 'perccha': 111.82, 'type': ['size']}, {'label': 'religion_perc_change_Christian', 'locRank': 9, 'natRank': 22, 'value': -8.7, '2011': 75.34, 'perccha': -10.35, 'type': ['regDiff']}, {'label': 'health_perc_change_bad', 'locRank': 19, 'natRank': -56, 'value': -4.07, '2011': 5.53, 'perccha': -42.38, 'type': ['size']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': -4, 'natRank': -58, 'value': -3.59, '2011': 9.89, 'perccha': -26.62, 'type': ['size']}, {'label': 'ethnicity_perc_change_white', 'locRank': 12, 'natRank': 58, 'value': -1.0, '2011': 96.9, 'perccha': -1.02, 'type': ['regDiff']}, {'label': 'economic_perc_change_employee', 'locRank': -12, 'natRank': 128, 'value': -0.02, '2011': 55.92, 'perccha': -0.03, 'type': ['simiDiff']}]
# li_temp ['population', 'children', 'tenure', 'hoursworked', 'health', 'household', 'economic', 'religion']
# li_temp ['population', 'agemed', 'children', 'marital', 'household', 'health', 'tenure', 'hoursworked', 'economic']
# li_temp ['population', 'tenure', 'ethnicity', 'health', 'marital', 'economic', 'children']
# li_temp ['population', 'religion', 'tenure', 'household', 'economic', 'health', 'hoursworked', 'marital']
# indi [{'label': 'population_value_change_all', 'locRank': -16, 'natRank': 39, 'value': 13.3, '2011': 356386.0, 'perccha': 0.0, 'type': ['pop', 'couDiff', 'nearDiff']}, {'label': 'tenure_perc_change_rented_private', 'locRank': -13, 'natRank': 39, 'value': 9.28, '2011': 25.64, 'perccha': 56.73, 'type': ['size', 'couDiff', 'nearDiff', 'simiDiff']}, {'label': 'religion_perc_change_Hindu', 'locRank': -1, 'natRank': -1, 'value': -0.53, '2011': 6.15, 'perccha': -7.92, 'type': ['regBuck']}, {'label': 'household_perc_change_OnePerson', 'locRank': 13, 'natRank': -22, 'value': -3.38, '2011': 27.93, 'perccha': -10.79, 'type': ['nearDiff']}, {'label': 'economic_perc_change_self-employed', 'locRank': 7, 'natRank': 7, 'value': 3.36, '2011': 15.59, 'perccha': 27.48, 'type': ['size']}, {'label': 'health_perc_change_bad', 'locRank': 5, 'natRank': 69, 'value': -2.73, '2011': 4.56, 'perccha': -37.43, 'type': ['size']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': -11, 'natRank': 60, 'value': -2.43, '2011': 11.47, 'perccha': -17.47, 'type': ['size']}, {'label': 'marital_perc_change_Married', 'locRank': -15, 'natRank': 23, 'value': -0.93, '2011': 46.99, 'perccha': -1.94, 'type': ['nearBuck', 'couDiff', 'simiDiff']}]
# li_temp ['population', 'care', 'marital', 'ethnicity', 'tenure', 'health', 'hoursworked', 'household']
# li_temp ['population', 'religion', 'tenure', 'hoursworked', 'health', 'ethnicity', 'economic', 'children']
# indi [{'label': 'population_value_change_all', 'locRank': 6, 'natRank': 45, 'value': 12.31, '2011': 120805.0, 'perccha': 0.01, 'type': ['pop', 'couDiff', 'regDiff', 'nearDiff']}, {'label': 'tenure_perc_change_rented_private', 'locRank': -15, 'natRank': -53, 'value': 4.16, '2011': 10.11, 'perccha': 69.92, 'type': ['size', 'couDiff', 'regDiff', 'nearDiff', 'simiDiff']}, {'label': 'religion_perc_change_Noreligion', 'locRank': 19, 'natRank': 82, 'value': 12.3, '2011': 27.31, 'perccha': 81.95, 'type': ['ethrel']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': -31, 'natRank': -150, 'value': -3.14, '2011': 12.72, 'perccha': -19.79, 'type': ['size']}, {'label': 'health_perc_change_bad', 'locRank': 18, 'natRank': 30, 'value': -2.49, '2011': 3.94, 'perccha': -38.7, 'type': ['size']}, {'label': 'ethnicity_perc_change_white', 'locRank': 25, 'natRank': 148, 'value': -2.36, '2011': 95.92, 'perccha': -2.4, 'type': ['regDiff']}, {'label': 'economic_perc_change_unemployed', 'locRank': -28, 'natRank': 136, 'value': 1.05, '2011': 2.98, 'perccha': 54.43, 'type': ['size']}, {'label': 'children_perc_change_Kids', 'locRank': 30, 'natRank': 92, 'value': 0.21, '2011': 32.83, 'perccha': 0.65, 'type': ['nearDiff']}]
# ...
# li_temp ['population', 'tenure', 'household', 'economic', 'ethnicity', 'health', 'religion', 'hoursworked', 'marital']
# li_temp ['population', 'religion', 'marital', 'economic', 'ethnicity', 'tenure', 'health', 'hoursworked']
# indi [{'label': 'population_value_change_all', 'locRank': 11, 'natRank': -133, 'value': 5.88, '2011': 57132.0, 'perccha': 0.01, 'type': ['pop', 'couDiff', 'nearDiff', 'simiDiff']}, {'label': 'marital_perc_change_Seperated', 'locRank': 2, 'natRank': 21, 'value': 1.97, '2011': 11.22, 'perccha': 21.31, 'type': ['locRank']}, {'label': 'religion_perc_change_Christian', 'locRank': 2, 'natRank': 8, 'value': -7.2, '2011': 78.11, 'perccha': -8.44, 'type': ['regDiff']}, {'label': 'economic_perc_change_self-employed', 'locRank': -3, 'natRank': -13, 'value': 0.53, '2011': 13.28, 'perccha': 4.16, 'type': ['locRank']}, {'label': 'ethnicity_perc_change_white', 'locRank': 3, 'natRank': 9, 'value': -0.56, '2011': 97.85, 'perccha': -0.57, 'type': ['regDiff']}, {'label': 'tenure_perc_change_owned', 'locRank': -15, 'natRank': -154, 'value': -4.39, '2011': 76.62, 'perccha': -5.42, 'type': ['nearDiff']}, {'label': 'health_perc_change_bad', 'locRank': 14, 'natRank': -77, 'value': -3.9, '2011': 4.01, 'perccha': -49.29, 'type': ['size']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': 17, 'natRank': 98, 'value': 1.17, '2011': 3.16, 'perccha': 58.81, 'type': ['size']}]
# li_temp ['population', 'agemed', 'tenure', 'religion', 'children', 'ethnicity', 'health', 'hoursworked', 'economic', 'household', 'marital']
# li_temp ['population', 'agemed', 'marital', 'ethnicity', 'religion', 'tenure', 'health', 'hoursworked', 'economic', 'children']
# li_temp ['population', 'health', 'religion', 'tenure', 'marital', 'hoursworked', 'children', 'household', 'economic']
# li_temp ['population', 'tenure', 'health', 'economic', 'hoursworked', 'ethnicity', 'religion']
# li_temp ['population', 'agemed', 'household', 'marital', 'ethnicity', 'children', 'tenure', 'health', 'hoursworked', 'religion']
# li_temp ['population', 'agemed', 'household', 'children', 'tenure', 'health', 'ethnicity', 'hoursworked', 'economic']
# li_temp ['population', 'children', 'tenure', 'health', 'ethnicity']
# li_temp ['population', 'religion', 'tenure', 'hoursworked', 'health', 'economic']
# indi [{'label': 'population_value_change_all', 'locRank': -19, 'natRank': 138, 'value': 7.15, '2011': 168310.0, 'perccha': 0.0, 'type': ['pop']}, {'label': 'tenure_perc_change_rented_private', 'locRank': -21, 'natRank': -115, 'value': 5.27, '2011': 11.98, 'perccha': 78.54, 'type': ['size']}, {'label': 'religion_perc_change_Noreligion', 'locRank': -23, 'natRank': 117, 'value': 11.73, '2011': 28.16, 'perccha': 71.4, 'type': ['ethrel']}, {'label': 'hoursworked_perc_change_Male49plus', 'locRank': 19, 'natRank': -107, 'value': -3.32, '2011': 11.87, 'perccha': -21.85, 'type': ['size']}, {'label': 'health_perc_change_bad', 'locRank': 6, 'natRank': 20, 'value': -2.41, '2011': 3.65, 'perccha': -39.75, 'type': ['size']}, {'label': 'economic_perc_change_unemployed', 'locRank': 15, 'natRank': 69, 'value': 1.35, '2011': 3.41, 'perccha': 65.55, 'type': ['size']}]
# li_temp ['population', 'agemed', 'health', 'religion', 'ethnicity', 'marital', 'economic', 'children', 'tenure', 'hoursworked']
# li_temp ['population', 'health', 'hoursworked', 'household', 'tenure', 'economic']
# li_temp ['population', 'religion', 'tenure', 'health', 'economic', 'ethnicity', 'hoursworked', 'household', 'children']
# indi [{'label': 'population_value_change_all', 'locRank': -12, 'natRank': -111, 'value': 5.33, '2011': 174497.0, 'perccha': 0.0, 'type': ['pop', 'couDiff', 'regDiff', 'nearDiff', 'simiDiff']}, {'label': 'tenure_perc_change_owned', 'locRank': 16, 'natRank': 125, 'value': -3.93, '2011': 65.94, 'perccha': -5.62, 'type': ['simiDiff']}, {'label': 'religion_perc_change_Noreligion', 'locRank': 10, 'natRank': 51, 'value': 12.91, '2011': 30.33, 'perccha': 74.11, 'type': ['ethrel']}, {'label': 'health_perc_change_bad', 'locRank': -22, 'natRank': 89, 'value': -2.81, '2011': 5.53, 'perccha': -33.68, 'type': ['size']}, {'label': 'economic_perc_change_unemployed', 'locRank': 10, 'natRank': 37, 'value': 1.55, '2011': 4.65, 'perccha': 50.02, 'type': ['size']}, {'label': 'ethnicity_perc_change_asian', 'locRank': 22, 'natRank': 151, 'value': 1.38, '2011': 2.73, 'perccha': 102.22, 'type': ['ethrel']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': 21, 'natRank': -149, 'value': 1.04, '2011': 2.55, 'perccha': 68.89, 'type': ['size']}, {'label': 'household_perc_change_OnePerson', 'locRank': 15, 'natRank': 144, 'value': 0.94, '2011': 29.53, 'perccha': 3.29, 'type': ['nearBuck']}, {'label': 'children_perc_change_Kids', 'locRank': 21, 'natRank': 93, 'value': 0.21, '2011': 30.94, 'perccha': 0.69, 'type': ['nearDiff']}]
# li_temp ['population', 'ethnicity', 'religion', 'children', 'tenure', 'health', 'marital', 'hoursworked', 'economic', 'household']
# indi [{'label': 'population_value_change_all', 'locRank': 5, 'natRank': 132, 'value': 7.29, '2011': 147489.0, 'perccha': 0.01, 'type': ['pop', 'nearBuck', 'regDiff', 'simiDiff']}, {'label': 'children_perc_change_NonDepKids', 'locRank': 3, 'natRank': 35, 'value': 0.87, '2011': 10.01, 'perccha': 9.53, 'type': ['locRank']}, {'label': 'ethnicity_perc_change_white', 'locRank': -2, 'natRank': -40, 'value': -8.77, '2011': 69.16, 'perccha': -11.25, 'type': ['regDiff']}, {'label': 'religion_perc_change_Noreligion', 'locRank': -1, 'natRank': -24, 'value': 5.82, '2011': 13.81, 'perccha': 72.84, 'type': ['regDiff']}, {'label': 'tenure_perc_change_rented_private', 'locRank': 10, 'natRank': 81, 'value': 7.67, '2011': 15.68, 'perccha': 95.76, 'type': ['size']}, {'label': 'health_perc_change_bad', 'locRank': 12, 'natRank': -80, 'value': -3.83, '2011': 7.3, 'perccha': -34.4, 'type': ['size']}, {'label': 'marital_perc_change_Married', 'locRank': 9, 'natRank': 117, 'value': -3.8, '2011': 47.81, 'perccha': -7.36, 'type': ['nearDiff']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': 8, 'natRank': 37, 'value': 1.46, '2011': 3.23, 'perccha': 82.5, 'type': ['size']}, {'label': 'economic_perc_change_student', 'locRank': 7, 'natRank': 49, 'value': 1.05, '2011': 3.19, 'perccha': 49.09, 'type': ['size']}, {'label': 'household_perc_change_OnePerson', 'locRank': -5, 'natRank': -117, 'value': 0.4, '2011': 30.37, 'perccha': 1.34, 'type': ['nearDiff']}]
# li_temp ['population', 'religion', 'tenure', 'health', 'economic', 'hoursworked']
# indi [{'label': 'population_value_change_all', 'locRank': 13, 'natRank': 61, 'value': 11.09, '2011': 173074.0, 'perccha': 0.01, 'type': ['pop', 'couDiff', 'regDiff', 'simiDiff']}, {'label': 'tenure_perc_change_owned', 'locRank': -10, 'natRank': -89, 'value': -5.62, '2011': 66.32, 'perccha': -7.81, 'type': ['simiDiff']}, {'label': 'religion_perc_change_Noreligion', 'locRank': 9, 'natRank': 49, 'value': 12.92, '2011': 31.41, 'perccha': 69.88, 'type': ['ethrel']}, {'label': 'health_perc_change_bad', 'locRank': -18, 'natRank': 99, 'value': -2.93, '2011': 4.25, 'perccha': -40.79, 'type': ['size']}, {'label': 'economic_perc_change_student', 'locRank': 4, 'natRank': 23, 'value': 1.6, '2011': 4.45, 'perccha': 56.16, 'type': ['size']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': 4, 'natRank': 49, 'value': 1.38, '2011': 3.42, 'perccha': 67.66, 'type': ['size']}]
# li_temp ['population', 'tenure', 'ethnicity', 'religion', 'health', 'hoursworked', 'economic']
# li_temp ['population', 'agemed', 'ethnicity', 'tenure', 'religion', 'household', 'hoursworked', 'health', 'marital', 'children', 'economic']
# li_temp ['population', 'religion', 'tenure', 'health', 'ethnicity', 'hoursworked', 'economic']
# indi [{'label': 'population_value_change_all', 'locRank': -21, 'natRank': -134, 'value': 5.91, '2011': 134186.0, 'perccha': 0.0, 'type': ['pop', 'regDiff']}, {'label': 'tenure_perc_change_rented_private', 'locRank': 7, 'natRank': 40, 'value': 9.27, '2011': 23.78, 'perccha': 63.89, 'type': ['size', 'couDiff', 'regDiff', 'nearDiff']}, {'label': 'religion_perc_change_Noreligion', 'locRank': 13, 'natRank': 56, 'value': 12.74, '2011': 28.6, 'perccha': 80.33, 'type': ['ethrel']}, {'label': 'health_perc_change_bad', 'locRank': -7, 'natRank': -106, 'value': -3.65, '2011': 7.5, 'perccha': -32.72, 'type': ['size']}, {'label': 'ethnicity_perc_change_white', 'locRank': 21, 'natRank': 137, 'value': -2.16, '2011': 95.53, 'perccha': -2.21, 'type': ['regDiff']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': 6, 'natRank': 46, 'value': 1.4, '2011': 3.35, 'perccha': 71.81, 'type': ['size']}, {'label': 'economic_perc_change_unemployed', 'locRank': 20, 'natRank': 91, 'value': 1.26, '2011': 5.67, 'perccha': 28.59, 'type': ['size']}]
# li_temp ['population', 'tenure', 'household', 'children', 'ethnicity', 'health', 'hoursworked', 'economic']
# li_temp ['population', 'household', 'marital', 'care', 'religion', 'tenure', 'health', 'economic', 'ethnicity', 'hoursworked']
# li_temp ['population', 'marital', 'care', 'ethnicity', 'economic', 'tenure', 'health', 'hoursworked', 'household']
# li_temp ['population', 'health', 'economic', 'hoursworked', 'tenure', 'children', 'religion']
# li_temp ['population', 'religion', 'marital', 'health', 'tenure', 'household', 'ethnicity', 'hoursworked', 'economic']
# indi [{'label': 'population_value_change_all', 'locRank': -20, 'natRank': -60, 'value': 3.33, '2011': 138375.0, 'perccha': 0.0, 'type': ['pop', 'couDiff', 'simiDiff']}, {'label': 'marital_perc_change_Single', 'locRank': -14, 'natRank': 118, 'value': 4.45, '2011': 37.27, 'perccha': 13.56, 'type': ['simiDiff']}, {'label': 'religion_perc_change_Noreligion', 'locRank': 9, 'natRank': -143, 'value': 10.82, '2011': 24.45, 'perccha': 79.39, 'type': ['ethrel']}, {'label': 'health_perc_change_bad', 'locRank': -18, 'natRank': -53, 'value': -4.11, '2011': 5.79, 'perccha': -41.5, 'type': ['size']}, {'label': 'tenure_perc_change_owned', 'locRank': 16, 'natRank': 97, 'value': -3.49, '2011': 69.18, 'perccha': -4.8, 'type': ['simiDiff']}, {'label': 'household_perc_change_Cohabiting', 'locRank': 12, 'natRank': 48, 'value': 2.2, '2011': 10.01, 'perccha': 28.18, 'type': ['size']}, {'label': 'ethnicity_perc_change_white', 'locRank': -17, 'natRank': 138, 'value': -2.19, '2011': 95.64, 'perccha': -2.24, 'type': ['regDiff']}, {'label': 'hoursworked_perc_change_Male1-15', 'locRank': 10, 'natRank': 43, 'value': 1.41, '2011': 3.87, 'perccha': 57.33, 'type': ['size']}, {'label': 'economic_perc_change_student', 'locRank': 6, 'natRank': 37, 'value': 1.23, '2011': 5.23, 'perccha': 30.77, 'type': ['size']}]
# li_temp ['population', 'welsh', 'marital', 'health', 'household', 'children', 'economic', 'religion', 'tenure', 'hoursworked']
# li_temp ['population', 'agemed', 'health', 'tenure', 'hoursworked', 'ethnicity', 'household', 'economic', 'children']
# li_temp ['population', 'agemed', 'children', 'tenure', 'health', 'hoursworked', 'household', 'ethnicity', 'religion']
# li_temp ['population', 'household', 'tenure', 'health', 'hoursworked', 'ethnicity', 'economic', 'religion']
# li_temp ['population', 'agemed', 'ethnicity', 'health', 'hoursworked', 'children', 'household', 'tenure']
# li_temp ['population', 'household', 'marital', 'care', 'tenure', 'health', 'children', 'economic', 'hoursworked', 'religion']
# li_temp ['population', 'economic', 'household', 'health', 'ethnicity', 'hoursworked', 'tenure', 'religion']
# li_temp ['population', 'children', 'tenure', 'marital', 'health', 'religion', 'household', 'hoursworked', 'economic']
# li_temp ['population', 'agemed', 'tenure', 'children', 'marital', 'religion', 'ethnicity', 'economic', 'health', 'household']
# li_temp ['population', 'tenure', 'hoursworked', 'health', 'ethnicity', 'religion']
# li_temp ['population', 'agemed', 'welsh', 'marital', 'tenure', 'health', 'hoursworked', 'household']
# li_temp ['population', 'agemed', 'ethnicity', 'religion', 'tenure', 'hoursworked', 'health']
# li_temp ['population', 'tenure', 'religion', 'children', 'ethnicity', 'health', 'economic', 'hoursworked', 'marital']
# li_temp ['population', 'agemed', 'welsh', 'marital', 'children', 'care', 'health', 'tenure', 'household', 'economic', 'hoursworked']
# li_temp ['population', 'religion', 'tenure', 'ethnicity', 'health', 'economic', 'marital']
# indi [{'label': 'population_value_change_all', 'locRank': 16, 'natRank': 34, 'value': 13.87, '2011': 303086.0, 'perccha': 0.01, 'type': ['pop', 'couDiff', 'nearDiff', 'simiDiff']}, {'label': 'tenure_perc_change_rented_private', 'locRank': -15, 'natRank': 33, 'value': 9.57, '2011': 29.33, 'perccha': 48.43, 'type': ['size', 'couDiff']}, {'label': 'religion_perc_change_Christian', 'locRank': 2, 'natRank': 3, 'value': -5.72, '2011': 53.1, 'perccha': -9.72, 'type': ['regDiff']}, {'label': 'ethnicity_perc_change_white', 'locRank': 4, 'natRank': -88, 'value': -5.3, '2011': 57.09, 'perccha': -8.49, 'type': ['regDiff']}, {'label': 'health_perc_change_bad', 'locRank': -12, 'natRank': -127, 'value': -3.48, '2011': 4.71, 'perccha': -42.47, 'type': ['size']}, {'label': 'economic_perc_change_self-employed', 'locRank': 15, 'natRank': 15, 'value': 2.66, '2011': 11.29, 'perccha': 30.83, 'type': ['size']}, {'label': 'marital_perc_change_Single', 'locRank': 15, 'natRank': -64, 'value': 2.57, '2011': 58.38, 'perccha': 4.61, 'type': ['nearDiff']}]
# li_temp ['population', 'tenure', 'health', 'hoursworked', 'ethnicity', 'economic']
# li_temp ['population', 'agemed', 'tenure', 'health', 'religion', 'hoursworked', 'economic', 'marital']
# li_temp ['population', 'agemed', 'ethnicity', 'tenure', 'household', 'health', 'children', 'religion', 'economic', 'hoursworked', 'marital']
# li_temp ['population', 'tenure', 'health', 'ethnicity', 'economic', 'hoursworked']
# li_temp ['population', 'hoursworked', 'tenure', 'ethnicity', 'health', 'household', 'religion', 'children']
# li_temp ['population', 'religion', 'health', 'economic', 'marital', 'tenure']
# indi [{'label': 'population_value_change_all', 'locRank': -7, 'natRank': -150, 'value': 6.27, '2011': 199693.0, 'perccha': 0.0, 'type': ['pop', 'regDiff', 'nearDiff', 'simiDiff']}, {'label': 'health_perc_change_bad', 'locRank': 14, 'natRank': 145, 'value': -3.21, '2011': 3.85, 'perccha': -45.45, 'type': ['size']}, {'label': 'religion_perc_change_Christian', 'locRank': 7, 'natRank': 9, 'value': -7.25, '2011': 56.08, 'perccha': -11.45, 'type': ['regDiff']}, {'label': 'economic_perc_change_self-employed', 'locRank': 8, 'natRank': 8, 'value': 3.24, '2011': 12.4, 'perccha': 35.38, 'type': ['size']}, {'label': 'marital_perc_change_Single', 'locRank': -11, 'natRank': -15, 'value': 0.92, '2011': 40.22, 'perccha': 2.34, 'type': ['couDiff']}, {'label': 'tenure_perc_change_rented_social', 'locRank': 11, 'natRank': 81, 'value': -0.04, '2011': 14.1, 'perccha': -0.28, 'type': ['nearDiff']}]
# li_temp ['population', 'agemed', 'economic', 'religion', 'tenure', 'hoursworked', 'health', 'ethnicity', 'household', 'children']
# li_temp ['population', 'agemed', 'ethnicity', 'economic', 'tenure', 'marital', 'health', 'hoursworked']
# li_temp ['population', 'marital', 'ethnicity', 'health', 'religion', 'children', 'household', 'hoursworked', 'tenure', 'economic']
# li_temp ['population', 'care', 'children', 'religion', 'tenure', 'health', 'household', 'economic', 'hoursworked', 'ethnicity']
# li_temp ['population', 'tenure', 'ethnicity', 'marital', 'health', 'religion', 'economic', 'hoursworked']
# li_temp ['population', 'agemed', 'welsh', 'religion', 'marital', 'children', 'tenure', 'health', 'household', 'hoursworked', 'economic']
# li_temp ['population', 'tenure', 'religion', 'children', 'economic', 'marital', 'health', 'ethnicity', 'hoursworked']
# li_temp ['population', 'agemed', 'tenure', 'health', 'marital', 'economic', 'household', 'hoursworked', 'children']
# li_temp ['population', 'agemed', 'children', 'tenure', 'health', 'hoursworked', 'marital']
# li_temp ['population', 'household', 'health', 'tenure', 'religion', 'ethnicity', 'hoursworked']

# %%
# similarData['name'] = this('Somerset West and Taunton')['name']
# similarData['data'] = this('Somerset West and Taunton')['data']

# this('Dorset')['similar'] = similarData


# similarData['name'] = this('Dorset')['name']
# similarData['data'] = this('Dorset')['data']

# this('Somerset West and Taunton')['similar'] = similarData


# similarData['name'] = this('West Devon')['name']
# similarData['data'] = this('West Devon')['data']

# this('Cornwall')['similar'] = similarData


# similarData['name'] = this('Buckinghamshire')['name']
# similarData['data'] = this('Buckinghamshire')['data']

# this('East Suffolk')['similar'] = similarData


# similarData['name'] = this('East Suffolk')['name']
# similarData['data'] = this('East Suffolk')['data']

# this('Buckinghamshire')['similar'] = similarData


# similarData['name'] = this('Bournemouth, Christchurch and Poole')['name']
# similarData['data'] = this('Bournemouth, Christchurch and Poole')['data']

# this('West Suffolk')['similar'] = similarData

# similarData['name'] = this('West Suffolk')['name']
# similarData['data'] = this('West Suffolk')['data']

# this('Bournemouth, Christchurch and Poole')['similar'] = similarData

# similarData['name'] = this('North Northamptonshire')['name']
# similarData['data'] = this('North Northamptonshire')['data']

# this('West Northamptonshire')['similar'] = similarData


# similarData['name'] = this('West Northamptonshire')['name']
# similarData['data'] = this('West Northamptonshire')['data']

# this('North Northamptonshire')['similar'] = similarData

#### West Suffolk, paragraph 3 example of statistically similar

# %%
for region in regions:
    region['data']['welsh'] = {}
    region['data']['welsh']['perc'] = {}
    region['data']['welsh']['value'] = {}
    for k in region['data']['welsh'].keys():
        region['data']['welsh'][k]['2001'] = {}
        region['data']['welsh'][k]['2011'] = {}
        region['data']['welsh'][k]['change'] = {}
        for j in region['data']['welsh'][k].keys():
            region['data']['welsh'][k][j]['SpeaksWelsh'] = 0

# %%
for rgn in regions:
    try:
        with open('/Users/theojolliffe/Documents/Area Reports/census-data-transformed/json/place/'+rgn['code']+'.json', 'w') as outfile:
            json.dump(rgn, outfile)
    except:
        print("Failed: ", rgn['name'])

# %%
for ctry in countries:
    try:
        with open('/Users/theojolliffe/Documents/Area Reports/census-data-transformed/json/place/'+ctry['code']+'.json', 'w') as outfile:
            json.dump(ctry, outfile)
    except:
        print("Failed: ", ctry['name'])

# %%
this("City of London")['gss']['short'] = 'city'
this("City of London")['gss']['long'] = 'City of London'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-32b015c72c96> in <module>
# ----> 1 this("City of London")['gss']['short'] = 'city'
#       2 this("City of London")['gss']['long'] = 'City of London'
#
# NameError: name 'this' is not defined

# %%
for lad in lads:
    try:
        with open('/Users/theojolliffe/Documents/Area Reports/census-data-transformed/json/place/'+lad['code']+'.json', 'w') as outfile:
        # with open('/Users/theojolliffe/Downloads/sk-whats-changed/static/data/json/place/'+lad['code']+'.json', 'w') as outfile:
            json.dump(lad, outfile)
    except:
        print("Failed: ", lad['name'])

for lad in lads:
    try:
        with open('/Users/theojolliffe/Downloads/sk-whats-changed 2/static/data/json/place/'+lad['code']+'.json', 'w') as outfile:
        # with open('/Users/theojolliffe/Downloads/sk-whats-changed/static/data/json/place/'+lad['code']+'.json', 'w') as outfile:
            json.dump(lad, outfile)
    except:
        print("Failed: ", lad['name'])

# %%
this("Manchester")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0884a24b5131> in <module>
# ----> 1 this("Manchester")
#
# NameError: name 'this' is not defined

# %%
# !git add .
# !git commit -m "Add files"
# !git push -u origin main
# Out:
# [main 62dd14d8] Add files
#  333 files changed, 1090 insertions(+), 583 deletions(-)
#  rewrite json/place/E06000001.json (86%)
#  rewrite json/place/E06000002.json (92%)
#  rewrite json/place/E06000003.json (94%)
#  rewrite json/place/E06000004.json (91%)
#  rewrite json/place/E06000005.json (94%)
#  rewrite json/place/E06000006.json (94%)
#  rewrite json/place/E06000007.json (93%)
#  rewrite json/place/E06000008.json (93%)
#  rewrite json/place/E06000009.json (94%)
#  rewrite json/place/E06000010.json (93%)
#  rewrite json/place/E06000011.json (92%)
#  rewrite json/place/E06000012.json (94%)
#  rewrite json/place/E06000013.json (93%)
#  rewrite json/place/E06000014.json (94%)
#  rewrite json/place/E06000015.json (94%)
#  rewrite json/place/E06000016.json (94%)
#  rewrite json/place/E06000017.json (95%)
#  rewrite json/place/E06000018.json (90%)
#  rewrite json/place/E06000019.json (94%)
#  rewrite json/place/E06000020.json (93%)
#  rewrite json/place/E06000021.json (94%)
#  rewrite json/place/E06000022.json (92%)
#  rewrite json/place/E06000023.json (89%)
#  rewrite json/place/E06000024.json (86%)
#  rewrite json/place/E06000025.json (94%)
#  rewrite json/place/E06000026.json (91%)
#  rewrite json/place/E06000027.json (92%)
#  rewrite json/place/E06000030.json (94%)
#  rewrite json/place/E06000031.json (93%)
#  rewrite json/place/E06000032.json (94%)
#  rewrite json/place/E06000033.json (94%)
#  rewrite json/place/E06000034.json (94%)
#  rewrite json/place/E06000035.json (93%)
#  rewrite json/place/E06000036.json (94%)
#  rewrite json/place/E06000037.json (92%)
#  rewrite json/place/E06000038.json (93%)
#  rewrite json/place/E06000039.json (94%)
#  rewrite json/place/E06000040.json (94%)
#  rewrite json/place/E06000041.json (93%)
#  rewrite json/place/E06000042.json (93%)
#  rewrite json/place/E06000043.json (93%)
#  rewrite json/place/E06000044.json (94%)
#  rewrite json/place/E06000045.json (94%)
#  rewrite json/place/E06000046.json (89%)
#  rewrite json/place/E06000047.json (93%)
#  rewrite json/place/E06000049.json (93%)
#  rewrite json/place/E06000050.json (93%)
#  rewrite json/place/E06000051.json (94%)
#  rewrite json/place/E06000052.json (93%)
#  rewrite json/place/E06000053.json (94%)
#  rewrite json/place/E06000054.json (93%)
#  rewrite json/place/E06000055.json (92%)
#  rewrite json/place/E06000056.json (94%)
#  rewrite json/place/E06000057.json (94%)
#  rewrite json/place/E06000058.json (94%)
#  rewrite json/place/E06000059.json (90%)
#  rewrite json/place/E06000060.json (93%)
#  rewrite json/place/E06000061.json (93%)
#  rewrite json/place/E06000062.json (90%)
#  rewrite json/place/E07000008.json (94%)
#  rewrite json/place/E07000009.json (94%)
#  rewrite json/place/E07000010.json (91%)
#  rewrite json/place/E07000011.json (94%)
#  rewrite json/place/E07000012.json (94%)
#  rewrite json/place/E07000026.json (94%)
#  rewrite json/place/E07000027.json (88%)
#  rewrite json/place/E07000028.json (94%)
#  rewrite json/place/E07000029.json (94%)
#  rewrite json/place/E07000030.json (93%)
#  rewrite json/place/E07000031.json (94%)
#  rewrite json/place/E07000032.json (90%)
#  rewrite json/place/E07000033.json (93%)
#  rewrite json/place/E07000034.json (94%)
#  rewrite json/place/E07000035.json (94%)
#  rewrite json/place/E07000036.json (94%)
#  rewrite json/place/E07000037.json (91%)
#  rewrite json/place/E07000038.json (94%)
#  rewrite json/place/E07000039.json (94%)
#  rewrite json/place/E07000040.json (95%)
#  rewrite json/place/E07000041.json (94%)
#  rewrite json/place/E07000042.json (94%)
#  rewrite json/place/E07000043.json (94%)
#  rewrite json/place/E07000044.json (93%)
#  rewrite json/place/E07000045.json (94%)
#  rewrite json/place/E07000046.json (95%)
#  rewrite json/place/E07000047.json (94%)
#  rewrite json/place/E07000061.json (94%)
#  rewrite json/place/E07000062.json (94%)
#  rewrite json/place/E07000063.json (94%)
#  rewrite json/place/E07000064.json (93%)
#  rewrite json/place/E07000065.json (94%)
#  rewrite json/place/E07000066.json (94%)
#  rewrite json/place/E07000067.json (94%)
#  rewrite json/place/E07000068.json (94%)
#  rewrite json/place/E07000069.json (94%)
#  rewrite json/place/E07000070.json (92%)
#  rewrite json/place/E07000071.json (93%)
#  rewrite json/place/E07000072.json (93%)
#  rewrite json/place/E07000073.json (94%)
#  rewrite json/place/E07000074.json (94%)
#  rewrite json/place/E07000075.json (94%)
#  rewrite json/place/E07000076.json (94%)
#  rewrite json/place/E07000077.json (95%)
#  rewrite json/place/E07000078.json (94%)
#  rewrite json/place/E07000079.json (94%)
#  rewrite json/place/E07000080.json (94%)
#  rewrite json/place/E07000081.json (94%)
#  rewrite json/place/E07000082.json (94%)
#  rewrite json/place/E07000083.json (93%)
#  rewrite json/place/E07000084.json (94%)
#  rewrite json/place/E07000085.json (94%)
#  rewrite json/place/E07000086.json (92%)
#  rewrite json/place/E07000087.json (94%)
#  rewrite json/place/E07000088.json (94%)
#  rewrite json/place/E07000089.json (94%)
#  rewrite json/place/E07000090.json (94%)
#  rewrite json/place/E07000091.json (94%)
#  rewrite json/place/E07000092.json (91%)
#  rewrite json/place/E07000093.json (95%)
#  rewrite json/place/E07000094.json (91%)
#  rewrite json/place/E07000095.json (95%)
#  rewrite json/place/E07000096.json (94%)
#  rewrite json/place/E07000098.json (94%)
#  rewrite json/place/E07000099.json (93%)
#  rewrite json/place/E07000102.json (94%)
#  rewrite json/place/E07000103.json (94%)
#  rewrite json/place/E07000105.json (93%)
#  rewrite json/place/E07000106.json (92%)
#  rewrite json/place/E07000107.json (95%)
#  rewrite json/place/E07000108.json (94%)
#  rewrite json/place/E07000109.json (94%)
#  rewrite json/place/E07000110.json (94%)
#  rewrite json/place/E07000111.json (90%)
#  rewrite json/place/E07000112.json (94%)
#  rewrite json/place/E07000113.json (94%)
#  rewrite json/place/E07000114.json (86%)
#  rewrite json/place/E07000115.json (94%)
#  rewrite json/place/E07000116.json (94%)
#  rewrite json/place/E07000117.json (94%)
#  rewrite json/place/E07000118.json (94%)
#  rewrite json/place/E07000119.json (94%)
#  rewrite json/place/E07000120.json (92%)
#  rewrite json/place/E07000121.json (94%)
#  rewrite json/place/E07000122.json (93%)
#  rewrite json/place/E07000123.json (94%)
#  rewrite json/place/E07000124.json (95%)
#  rewrite json/place/E07000125.json (94%)
#  rewrite json/place/E07000126.json (94%)
#  rewrite json/place/E07000127.json (94%)
#  rewrite json/place/E07000128.json (90%)
#  rewrite json/place/E07000129.json (94%)
#  rewrite json/place/E07000130.json (91%)
#  rewrite json/place/E07000131.json (95%)
#  rewrite json/place/E07000132.json (94%)
#  rewrite json/place/E07000133.json (94%)
#  rewrite json/place/E07000134.json (89%)
#  rewrite json/place/E07000135.json (92%)
#  rewrite json/place/E07000136.json (94%)
#  rewrite json/place/E07000137.json (93%)
#  rewrite json/place/E07000138.json (94%)
#  rewrite json/place/E07000139.json (93%)
#  rewrite json/place/E07000140.json (91%)
#  rewrite json/place/E07000141.json (94%)
#  rewrite json/place/E07000142.json (94%)
#  rewrite json/place/E07000143.json (94%)
#  rewrite json/place/E07000144.json (94%)
#  rewrite json/place/E07000145.json (95%)
#  rewrite json/place/E07000146.json (93%)
#  rewrite json/place/E07000147.json (94%)
#  rewrite json/place/E07000148.json (94%)
#  rewrite json/place/E07000149.json (94%)
#  rewrite json/place/E07000163.json (94%)
#  rewrite json/place/E07000164.json (95%)
#  rewrite json/place/E07000165.json (94%)
#  rewrite json/place/E07000166.json (94%)
#  rewrite json/place/E07000167.json (94%)
#  rewrite json/place/E07000168.json (93%)
#  rewrite json/place/E07000169.json (93%)
#  rewrite json/place/E07000170.json (94%)
#  rewrite json/place/E07000171.json (92%)
#  rewrite json/place/E07000172.json (93%)
#  rewrite json/place/E07000173.json (94%)
#  rewrite json/place/E07000174.json (93%)
#  rewrite json/place/E07000175.json (94%)
#  rewrite json/place/E07000176.json (94%)
#  rewrite json/place/E07000177.json (94%)
#  rewrite json/place/E07000178.json (91%)
#  rewrite json/place/E07000179.json (94%)
#  rewrite json/place/E07000180.json (95%)
#  rewrite json/place/E07000181.json (94%)
#  rewrite json/place/E07000187.json (94%)
#  rewrite json/place/E07000188.json (94%)
#  rewrite json/place/E07000189.json (94%)
#  rewrite json/place/E07000192.json (93%)
#  rewrite json/place/E07000193.json (94%)
#  rewrite json/place/E07000194.json (94%)
#  rewrite json/place/E07000195.json (94%)
#  rewrite json/place/E07000196.json (88%)
#  rewrite json/place/E07000197.json (94%)
#  rewrite json/place/E07000198.json (93%)
#  rewrite json/place/E07000199.json (90%)
#  rewrite json/place/E07000200.json (94%)
#  rewrite json/place/E07000202.json (93%)
#  rewrite json/place/E07000203.json (93%)
#  rewrite json/place/E07000207.json (94%)
#  rewrite json/place/E07000208.json (94%)
#  rewrite json/place/E07000209.json (87%)
#  rewrite json/place/E07000210.json (94%)
#  rewrite json/place/E07000211.json (94%)
#  rewrite json/place/E07000212.json (94%)
#  rewrite json/place/E07000213.json (94%)
#  rewrite json/place/E07000214.json (94%)
#  rewrite json/place/E07000215.json (93%)
#  rewrite json/place/E07000216.json (94%)
#  rewrite json/place/E07000217.json (95%)
#  rewrite json/place/E07000218.json (94%)
#  rewrite json/place/E07000219.json (94%)
#  rewrite json/place/E07000220.json (94%)
#  rewrite json/place/E07000221.json (94%)
#  rewrite json/place/E07000222.json (94%)
#  rewrite json/place/E07000223.json (95%)
#  rewrite json/place/E07000224.json (89%)
#  rewrite json/place/E07000225.json (94%)
#  rewrite json/place/E07000226.json (94%)
#  rewrite json/place/E07000227.json (95%)
#  rewrite json/place/E07000228.json (93%)
#  rewrite json/place/E07000229.json (94%)
#  rewrite json/place/E07000234.json (94%)
#  rewrite json/place/E07000235.json (94%)
#  rewrite json/place/E07000236.json (93%)
#  rewrite json/place/E07000237.json (94%)
#  rewrite json/place/E07000238.json (94%)
#  rewrite json/place/E07000239.json (93%)
#  rewrite json/place/E07000240.json (93%)
#  rewrite json/place/E07000241.json (94%)
#  rewrite json/place/E07000242.json (94%)
#  rewrite json/place/E07000243.json (91%)
#  rewrite json/place/E07000244.json (94%)
#  rewrite json/place/E07000245.json (93%)
#  rewrite json/place/E07000246.json (94%)
#  rewrite json/place/E08000001.json (93%)
#  rewrite json/place/E08000002.json (94%)
#  rewrite json/place/E08000003.json (93%)
#  rewrite json/place/E08000004.json (94%)
#  rewrite json/place/E08000005.json (93%)
#  rewrite json/place/E08000006.json (92%)
#  rewrite json/place/E08000007.json (93%)
#  rewrite json/place/E08000008.json (94%)
#  rewrite json/place/E08000009.json (93%)
#  rewrite json/place/E08000010.json (94%)
#  rewrite json/place/E08000011.json (93%)
#  rewrite json/place/E08000012.json (91%)
#  rewrite json/place/E08000013.json (94%)
#  rewrite json/place/E08000014.json (94%)
#  rewrite json/place/E08000015.json (94%)
#  rewrite json/place/E08000016.json (94%)
#  rewrite json/place/E08000017.json (94%)
#  rewrite json/place/E08000018.json (93%)
#  rewrite json/place/E08000019.json (93%)
#  rewrite json/place/E08000021.json (94%)
#  rewrite json/place/E08000022.json (94%)
#  rewrite json/place/E08000023.json (93%)
#  rewrite json/place/E08000024.json (93%)
#  rewrite json/place/E08000025.json (92%)
#  rewrite json/place/E08000026.json (94%)
#  rewrite json/place/E08000027.json (94%)
#  rewrite json/place/E08000028.json (85%)
#  rewrite json/place/E08000029.json (94%)
#  rewrite json/place/E08000030.json (94%)
#  rewrite json/place/E08000031.json (94%)
#  rewrite json/place/E08000032.json (93%)
#  rewrite json/place/E08000033.json (94%)
#  rewrite json/place/E08000034.json (88%)
#  rewrite json/place/E08000035.json (92%)
#  rewrite json/place/E08000036.json (93%)
#  rewrite json/place/E08000037.json (93%)
#  rewrite json/place/E09000001.json (94%)
#  rewrite json/place/E09000002.json (91%)
#  rewrite json/place/E09000003.json (94%)
#  rewrite json/place/E09000004.json (91%)
#  rewrite json/place/E09000005.json (93%)
#  rewrite json/place/E09000006.json (94%)
#  rewrite json/place/E09000007.json (92%)
#  rewrite json/place/E09000008.json (94%)
#  rewrite json/place/E09000009.json (92%)
#  rewrite json/place/E09000010.json (94%)
#  rewrite json/place/E09000011.json (93%)
#  rewrite json/place/E09000012.json (94%)
#  rewrite json/place/E09000013.json (94%)
#  rewrite json/place/E09000014.json (94%)
#  rewrite json/place/E09000015.json (94%)
#  rewrite json/place/E09000016.json (93%)
#  rewrite json/place/E09000017.json (93%)
#  rewrite json/place/E09000018.json (94%)
#  rewrite json/place/E09000019.json (94%)
#  rewrite json/place/E09000020.json (94%)
#  rewrite json/place/E09000021.json (92%)
#  rewrite json/place/E09000022.json (89%)
#  rewrite json/place/E09000023.json (94%)
#  rewrite json/place/E09000024.json (94%)
#  rewrite json/place/E09000025.json (93%)
#  rewrite json/place/E09000026.json (94%)
#  rewrite json/place/E09000027.json (90%)
#  rewrite json/place/E09000028.json (93%)
#  rewrite json/place/E09000029.json (93%)
#  rewrite json/place/E09000030.json (94%)
#  rewrite json/place/E09000031.json (94%)
#  rewrite json/place/E09000032.json (94%)
#  rewrite json/place/E09000033.json (94%)
#  rewrite json/place/W06000001.json (93%)
#  rewrite json/place/W06000002.json (94%)
#  rewrite json/place/W06000003.json (94%)
#  rewrite json/place/W06000004.json (94%)
#  rewrite json/place/W06000005.json (93%)
#  rewrite json/place/W06000006.json (94%)
#  rewrite json/place/W06000008.json (94%)
#  rewrite json/place/W06000009.json (94%)
#  rewrite json/place/W06000010.json (94%)
#  rewrite json/place/W06000011.json (94%)
#  rewrite json/place/W06000012.json (94%)
#  rewrite json/place/W06000013.json (94%)
#  rewrite json/place/W06000014.json (94%)
#  rewrite json/place/W06000015.json (93%)
#  rewrite json/place/W06000016.json (93%)
#  rewrite json/place/W06000018.json (94%)
#  rewrite json/place/W06000019.json (94%)
#  rewrite json/place/W06000020.json (94%)
#  rewrite json/place/W06000021.json (94%)
#  rewrite json/place/W06000022.json (94%)
#  rewrite json/place/W06000023.json (94%)
#  rewrite json/place/W06000024.json (94%)
# Enumerating objects: 576, done.
# Counting objects: 100% (576/576), done.
# Delta compression using up to 16 threads
# Compressing objects: 100% (337/337), done.
# Writing objects: 100% (337/337), 7.62 MiB | 610.00 KiB/s, done.
# Total 337 (delta 335), reused 0 (delta 0)
# remote: Resolving deltas: 100% (335/335), completed with 238 local objects.
# To https://github.com/theojolliffe/census-data.git
#    6443239c..62dd14d8  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !pwd
# Out:
# /Users/theojolliffe/Documents/census-data-transformed

# %%
df[df['topic'].split("_")[0] == 'care']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-4e7352f16a17> in <module>
# ----> 1 df[df['topic'].split("_")[0] == 'care']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'
